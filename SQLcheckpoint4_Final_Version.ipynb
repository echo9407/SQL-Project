# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv("ted_main.csv")

transcripts = pd.read_csv("transcripts.csv")

# %%
data.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# 1           Al Gore: Averting the climate crisis            1      1151367060
# 2                  David Pogue: Simplicity sells            1      1151367060
# 3             Majora Carter: Greening the ghetto            1      1151367060
# 4  Hans Rosling: The best stats you've ever seen            1      1151440680
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2  [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3  [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4  [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
#
#                                        related_talks  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 1  [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...
# 2  [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...
# 3  [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
# 4  [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...
#
#                      speaker_occupation  \
# 0                       Author/educator
# 1                      Climate advocate
# 2                  Technology columnist
# 3    Activist for environmental justice
# 4  Global health expert; data visionary
#
#                                                 tags  \
# 0  ['children', 'creativity', 'culture', 'dance',...
# 1  ['alternative energy', 'cars', 'climate change...
# 2  ['computers', 'entertainment', 'interface desi...
# 3  ['MacArthur grant', 'activism', 'business', 'c...
# 4  ['Africa', 'Asia', 'Google', 'demo', 'economic...
#
#                              title  \
# 0      Do schools kill creativity?
# 1      Averting the climate crisis
# 2                 Simplicity sells
# 3              Greening the ghetto
# 4  The best stats you've ever seen
#
#                                                  url     views
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 1  https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 2  https://www.ted.com/talks/david_pogue_says_sim...   1636292
# 3  https://www.ted.com/talks/majora_carter_s_tale...   1697550
# 4  https://www.ted.com/talks/hans_rosling_shows_t...  12005869

# %%
data.shape
# Out:
# (2550, 17)

# %%
transcripts.head()
# Out:
#                                           transcript  \
# 0  Good morning. How are you?(Laughter)It's been ...
# 1  Thank you so much, Chris. And it's truly a gre...
# 2  (Music: "The Sound of Silence," Simon & Garfun...
# 3  If you're here today — and I'm very happy that...
# 4  About 10 years ago, I took on the task to teac...
#
#                                                  url
# 0  https://www.ted.com/talks/ken_robinson_says_sc...
# 1  https://www.ted.com/talks/al_gore_on_averting_...
# 2  https://www.ted.com/talks/david_pogue_says_sim...
# 3  https://www.ted.com/talks/majora_carter_s_tale...
# 4  https://www.ted.com/talks/hans_rosling_shows_t...

# %%
transcripts.shape
# Out:
# (2467, 2)

# %%
transcripts.drop_duplicates().shape
# Out:
# (2464, 2)

# %%
# 3 duplicates - remove from data

transcripts.drop_duplicates(inplace=True)

# %%
# join transcripts to data

data = pd.merge(left = data, right = transcripts, on = "url", how = "left")

data.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# 1           Al Gore: Averting the climate crisis            1      1151367060
# 2                  David Pogue: Simplicity sells            1      1151367060
# 3             Majora Carter: Greening the ghetto            1      1151367060
# 4  Hans Rosling: The best stats you've ever seen            1      1151440680
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2  [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3  [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4  [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
#
#                                        related_talks  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 1  [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...
# 2  [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...
# 3  [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
# 4  [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...
#
#                      speaker_occupation  \
# 0                       Author/educator
# 1                      Climate advocate
# 2                  Technology columnist
# 3    Activist for environmental justice
# 4  Global health expert; data visionary
#
#                                                 tags  \
# 0  ['children', 'creativity', 'culture', 'dance',...
# 1  ['alternative energy', 'cars', 'climate change...
# 2  ['computers', 'entertainment', 'interface desi...
# 3  ['MacArthur grant', 'activism', 'business', 'c...
# 4  ['Africa', 'Asia', 'Google', 'demo', 'economic...
#
#                              title  \
# 0      Do schools kill creativity?
# 1      Averting the climate crisis
# 2                 Simplicity sells
# 3              Greening the ghetto
# 4  The best stats you've ever seen
#
#                                                  url     views  \
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 1  https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 2  https://www.ted.com/talks/david_pogue_says_sim...   1636292
# 3  https://www.ted.com/talks/majora_carter_s_tale...   1697550
# 4  https://www.ted.com/talks/hans_rosling_shows_t...  12005869
#
#                                           transcript
# 0  Good morning. How are you?(Laughter)It's been ...
# 1  Thank you so much, Chris. And it's truly a gre...
# 2  (Music: "The Sound of Silence," Simon & Garfun...
# 3  If you're here today — and I'm very happy that...
# 4  About 10 years ago, I took on the task to teac...

# %%
data.shape
# Out:
# (2550, 18)

# %%
data = pd.DataFrame(data)

data.dtypes
# Out:
# comments               int64
# description           object
# duration               int64
# event                 object
# film_date              int64
# languages              int64
# main_speaker          object
# name                  object
# num_speaker            int64
# published_date         int64
# ratings               object
# related_talks         object
# speaker_occupation    object
# tags                  object
# title                 object
# url                   object
# views                  int64
# transcript            object
# dtype: object

# %%
data['film_date'].head()
# Out:
# 0    1140825600
# 1    1140825600
# 2    1140739200
# 3    1140912000
# 4    1140566400
# Name: film_date, dtype: int64

# %%
data['published_date'].head()
# Out:
# 0    1151367060
# 1    1151367060
# 2    1151367060
# 3    1151367060
# 4    1151440680
# Name: published_date, dtype: int64

# %%
# clean dates

from datetime import datetime

data['film_date'] = data['film_date'].apply(lambda x: datetime.fromtimestamp( int(x)).strftime('%d-%m-%Y'))

data['published_date'] = data['published_date'].apply(lambda x: datetime.fromtimestamp( int(x)).strftime('%d-%m-%Y'))

# %%
sum(data["transcript"].isnull())
# Out:
# 86

# %%
data["transcript"][data["transcript"].isnull()].head()
# Out:
# 58     NaN
# 115    NaN
# 135    NaN
# 209    NaN
# 237    NaN
# Name: transcript, dtype: object

# %%
# make blank instead

data["transcript"][data["transcript"].isnull()] = ""
# Out:
# C:\Users\casey\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
sum(data["transcript"].isnull())
# Out:
# 0

# %%
data.columns
# Out:
# Index(['comments', 'description', 'duration', 'event', 'film_date',
#        'languages', 'main_speaker', 'name', 'num_speaker', 'published_date',
#        'ratings', 'related_talks', 'speaker_occupation', 'tags', 'title',
#        'url', 'views', 'transcript'],
#       dtype='object')

# %%
# make tables

# videos

video_titles = ["title", "description"]

videos = data[video_titles].drop_duplicates()

videos.head()
# Out:
#                              title  \
# 0      Do schools kill creativity?
# 1      Averting the climate crisis
# 2                 Simplicity sells
# 3              Greening the ghetto
# 4  The best stats you've ever seen
#
#                                          description
# 0  Sir Ken Robinson makes an entertaining and pro...
# 1  With the same humor and humanity he exuded in ...
# 2  New York Times columnist David Pogue takes aim...
# 3  In an emotionally charged talk, MacArthur-winn...
# 4  You've never seen data presented like this. Wi...

# %%
# use index to create id column

videos.reset_index(inplace = True)

videos['id'] = videos.index

videos = videos[['id', 'title', 'description']]

videos.head()
# Out:
#    id                            title  \
# 0   0      Do schools kill creativity?
# 1   1      Averting the climate crisis
# 2   2                 Simplicity sells
# 3   3              Greening the ghetto
# 4   4  The best stats you've ever seen
#
#                                          description
# 0  Sir Ken Robinson makes an entertaining and pro...
# 1  With the same humor and humanity he exuded in ...
# 2  New York Times columnist David Pogue takes aim...
# 3  In an emotionally charged talk, MacArthur-winn...
# 4  You've never seen data presented like this. Wi...

# %%
# videos table is ready - join IDs back to data

data = pd.merge(left = data, right = videos, how = 'left', on = ['title', 'description'])

data.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  24-02-2006         60   Ken Robinson
# 1  TED2006  24-02-2006         43        Al Gore
# 2  TED2006  23-02-2006         26    David Pogue
# 3  TED2006  25-02-2006         35  Majora Carter
# 4  TED2006  21-02-2006         48   Hans Rosling
#
#                                             name  num_speaker published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1     26-06-2006
# 1           Al Gore: Averting the climate crisis            1     26-06-2006
# 2                  David Pogue: Simplicity sells            1     26-06-2006
# 3             Majora Carter: Greening the ghetto            1     26-06-2006
# 4  Hans Rosling: The best stats you've ever seen            1     27-06-2006
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2  [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3  [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4  [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
#
#                                        related_talks  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 1  [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...
# 2  [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...
# 3  [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
# 4  [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...
#
#                      speaker_occupation  \
# 0                       Author/educator
# 1                      Climate advocate
# 2                  Technology columnist
# 3    Activist for environmental justice
# 4  Global health expert; data visionary
#
#                                                 tags  \
# 0  ['children', 'creativity', 'culture', 'dance',...
# 1  ['alternative energy', 'cars', 'climate change...
# 2  ['computers', 'entertainment', 'interface desi...
# 3  ['MacArthur grant', 'activism', 'business', 'c...
# 4  ['Africa', 'Asia', 'Google', 'demo', 'economic...
#
#                              title  \
# 0      Do schools kill creativity?
# 1      Averting the climate crisis
# 2                 Simplicity sells
# 3              Greening the ghetto
# 4  The best stats you've ever seen
#
#                                                  url     views  \
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 1  https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 2  https://www.ted.com/talks/david_pogue_says_sim...   1636292
# 3  https://www.ted.com/talks/majora_carter_s_tale...   1697550
# 4  https://www.ted.com/talks/hans_rosling_shows_t...  12005869
#
#                                           transcript  id
# 0  Good morning. How are you?(Laughter)It's been ...   0
# 1  Thank you so much, Chris. And it's truly a gre...   1
# 2  (Music: "The Sound of Silence," Simon & Garfun...   2
# 3  If you're here today — and I'm very happy that...   3
# 4  About 10 years ago, I took on the task to teac...   4

# %%
data.rename(columns = {'id':'video_id'}, inplace = True)

data.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  24-02-2006         60   Ken Robinson
# 1  TED2006  24-02-2006         43        Al Gore
# 2  TED2006  23-02-2006         26    David Pogue
# 3  TED2006  25-02-2006         35  Majora Carter
# 4  TED2006  21-02-2006         48   Hans Rosling
#
#                                             name  num_speaker published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1     26-06-2006
# 1           Al Gore: Averting the climate crisis            1     26-06-2006
# 2                  David Pogue: Simplicity sells            1     26-06-2006
# 3             Majora Carter: Greening the ghetto            1     26-06-2006
# 4  Hans Rosling: The best stats you've ever seen            1     27-06-2006
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2  [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3  [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4  [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
#
#                                        related_talks  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 1  [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...
# 2  [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...
# 3  [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
# 4  [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...
#
#                      speaker_occupation  \
# 0                       Author/educator
# 1                      Climate advocate
# 2                  Technology columnist
# 3    Activist for environmental justice
# 4  Global health expert; data visionary
#
#                                                 tags  \
# 0  ['children', 'creativity', 'culture', 'dance',...
# 1  ['alternative energy', 'cars', 'climate change...
# 2  ['computers', 'entertainment', 'interface desi...
# 3  ['MacArthur grant', 'activism', 'business', 'c...
# 4  ['Africa', 'Asia', 'Google', 'demo', 'economic...
#
#                              title  \
# 0      Do schools kill creativity?
# 1      Averting the climate crisis
# 2                 Simplicity sells
# 3              Greening the ghetto
# 4  The best stats you've ever seen
#
#                                                  url     views  \
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 1  https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 2  https://www.ted.com/talks/david_pogue_says_sim...   1636292
# 3  https://www.ted.com/talks/majora_carter_s_tale...   1697550
# 4  https://www.ted.com/talks/hans_rosling_shows_t...  12005869
#
#                                           transcript  video_id
# 0  Good morning. How are you?(Laughter)It's been ...         0
# 1  Thank you so much, Chris. And it's truly a gre...         1
# 2  (Music: "The Sound of Silence," Simon & Garfun...         2
# 3  If you're here today — and I'm very happy that...         3
# 4  About 10 years ago, I took on the task to teac...         4

# %%
# video IDs successfully added to data

# events

# to make events, we need to make start dates and end dates

by_event = data.groupby('event')

min_by_event = by_event.agg({'film_date':"min"})

min_by_event
# Out:
#                               film_date
# event
# AORN Congress                14-03-2009
# Arbejdsglaede Live           04-05-2009
# BBC TV                       08-07-1983
# Bowery Poetry Club           12-11-2005
# Business Innovation Factory  06-10-2009
# ...                                 ...
# The Do Lectures              17-09-2009
# Toronto Youth Corps          13-05-1972
# University of California     12-10-2004
# Web 2.0 Expo 2008            19-09-2008
# World Science Festival       09-06-2009
#
# [355 rows x 1 columns]

# %%
max_by_event = by_event.agg({'film_date':"max"})

max_by_event
# Out:
#                               film_date
# event
# AORN Congress                14-03-2009
# Arbejdsglaede Live           04-05-2009
# BBC TV                       08-07-1983
# Bowery Poetry Club           12-11-2005
# Business Innovation Factory  09-10-2009
# ...                                 ...
# The Do Lectures              17-09-2009
# Toronto Youth Corps          13-05-1972
# University of California     15-05-2001
# Web 2.0 Expo 2008            19-09-2008
# World Science Festival       09-06-2009
#
# [355 rows x 1 columns]

# %%
dates = pd.concat([min_by_event, max_by_event], axis = 1)

dates.head()
# Out:
#                               film_date   film_date
# event
# AORN Congress                14-03-2009  14-03-2009
# Arbejdsglaede Live           04-05-2009  04-05-2009
# BBC TV                       08-07-1983  08-07-1983
# Bowery Poetry Club           12-11-2005  12-11-2005
# Business Innovation Factory  06-10-2009  09-10-2009

# %%
dates.columns = ['start_date', 'end_date']

dates.head(15)
# Out:
#                                start_date    end_date
# event
# AORN Congress                  14-03-2009  14-03-2009
# Arbejdsglaede Live             04-05-2009  04-05-2009
# BBC TV                         08-07-1983  08-07-1983
# Bowery Poetry Club             12-11-2005  12-11-2005
# Business Innovation Factory    06-10-2009  09-10-2009
# Carnegie Mellon University     17-09-2007  17-09-2007
# Chautauqua Institution         30-09-2009  30-09-2009
# DICE Summit 2010               17-02-2010  17-02-2010
# DLD 2007                       31-12-2006  31-12-2006
# EG 2007                        01-12-2007  11-12-2007
# EG 2008                        04-12-2008  11-12-2008
# Elizabeth G. Anderson School   03-04-2009  03-04-2009
# Eric Whitacre's Virtual Choir  10-03-2010  10-03-2010
# Fort Worth City Council        11-10-2010  11-10-2010
# Full Spectrum Auditions        23-05-2011  23-05-2011

# %%
sum(dates['start_date'] == dates['end_date'])/len(dates)
# Out:
# 0.5295774647887324

# %%
# 53% of events were one day only

events = dates.copy()

events['event'] = events.index

events.index = range(1, len(events) + 1)

events.head()
# Out:
#    start_date    end_date                        event
# 1  14-03-2009  14-03-2009                AORN Congress
# 2  04-05-2009  04-05-2009           Arbejdsglaede Live
# 3  08-07-1983  08-07-1983                       BBC TV
# 4  12-11-2005  12-11-2005           Bowery Poetry Club
# 5  06-10-2009  09-10-2009  Business Innovation Factory

# %%
# make separate id column with index numbers

events['id'] = events.index

events = events[['id', 'event', 'start_date', 'end_date']]

events.head()
# Out:
#    id                        event  start_date    end_date
# 1   1                AORN Congress  14-03-2009  14-03-2009
# 2   2           Arbejdsglaede Live  04-05-2009  04-05-2009
# 3   3                       BBC TV  08-07-1983  08-07-1983
# 4   4           Bowery Poetry Club  12-11-2005  12-11-2005
# 5   5  Business Innovation Factory  06-10-2009  09-10-2009

# %%
# add event IDs to data

data = pd.merge(left = data, right = events, how = 'left', on = 'event')

data.rename(columns = {'id':'event_id'}, inplace = True)

data.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  24-02-2006         60   Ken Robinson
# 1  TED2006  24-02-2006         43        Al Gore
# 2  TED2006  23-02-2006         26    David Pogue
# 3  TED2006  25-02-2006         35  Majora Carter
# 4  TED2006  21-02-2006         48   Hans Rosling
#
#                                             name  num_speaker published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1     26-06-2006
# 1           Al Gore: Averting the climate crisis            1     26-06-2006
# 2                  David Pogue: Simplicity sells            1     26-06-2006
# 3             Majora Carter: Greening the ghetto            1     26-06-2006
# 4  Hans Rosling: The best stats you've ever seen            1     27-06-2006
#
#    ...                    speaker_occupation  \
# 0  ...                       Author/educator
# 1  ...                      Climate advocate
# 2  ...                  Technology columnist
# 3  ...    Activist for environmental justice
# 4  ...  Global health expert; data visionary
#
#                                                 tags  \
# 0  ['children', 'creativity', 'culture', 'dance',...
# 1  ['alternative energy', 'cars', 'climate change...
# 2  ['computers', 'entertainment', 'interface desi...
# 3  ['MacArthur grant', 'activism', 'business', 'c...
# 4  ['Africa', 'Asia', 'Google', 'demo', 'economic...
#
#                              title  \
# 0      Do schools kill creativity?
# 1      Averting the climate crisis
# 2                 Simplicity sells
# 3              Greening the ghetto
# 4  The best stats you've ever seen
#
#                                                  url     views  \
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 1  https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 2  https://www.ted.com/talks/david_pogue_says_sim...   1636292
# 3  https://www.ted.com/talks/majora_carter_s_tale...   1697550
# 4  https://www.ted.com/talks/hans_rosling_shows_t...  12005869
#
#                                           transcript  video_id event_id  \
# 0  Good morning. How are you?(Laughter)It's been ...         0       57
# 1  Thank you so much, Chris. And it's truly a gre...         1       57
# 2  (Music: "The Sound of Silence," Simon & Garfun...         2       57
# 3  If you're here today — and I'm very happy that...         3       57
# 4  About 10 years ago, I took on the task to teac...         4       57
#
#    start_date    end_date
# 0  01-02-2006  27-02-2006
# 1  01-02-2006  27-02-2006
# 2  01-02-2006  27-02-2006
# 3  01-02-2006  27-02-2006
# 4  01-02-2006  27-02-2006
#
# [5 rows x 22 columns]

# %%
# occupations

occupations = pd.DataFrame(data['speaker_occupation'].unique())

occupations.head()
# Out:
#                                       0
# 0                       Author/educator
# 1                      Climate advocate
# 2                  Technology columnist
# 3    Activist for environmental justice
# 4  Global health expert; data visionary

# %%
occupations['id'] = occupations.index 

occupations.head()
# Out:
#                                       0  id
# 0                       Author/educator   0
# 1                      Climate advocate   1
# 2                  Technology columnist   2
# 3    Activist for environmental justice   3
# 4  Global health expert; data visionary   4

# %%
occupations.columns = ['occupation', 'id']

occupations = occupations[['id', 'occupation']]

# %%
occupations.head()
# Out:
#    id                            occupation
# 0   0                       Author/educator
# 1   1                      Climate advocate
# 2   2                  Technology columnist
# 3   3    Activist for environmental justice
# 4   4  Global health expert; data visionary

# %%
# add occupation IDs back to data

data = pd.merge(left = data, right = occupations, how = 'left', 
                left_on = 'speaker_occupation', right_on = 'occupation')

data.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  24-02-2006         60   Ken Robinson
# 1  TED2006  24-02-2006         43        Al Gore
# 2  TED2006  23-02-2006         26    David Pogue
# 3  TED2006  25-02-2006         35  Majora Carter
# 4  TED2006  21-02-2006         48   Hans Rosling
#
#                                             name  num_speaker published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1     26-06-2006
# 1           Al Gore: Averting the climate crisis            1     26-06-2006
# 2                  David Pogue: Simplicity sells            1     26-06-2006
# 3             Majora Carter: Greening the ghetto            1     26-06-2006
# 4  Hans Rosling: The best stats you've ever seen            1     27-06-2006
#
#    ...                            title  \
# 0  ...      Do schools kill creativity?
# 1  ...      Averting the climate crisis
# 2  ...                 Simplicity sells
# 3  ...              Greening the ghetto
# 4  ...  The best stats you've ever seen
#
#                                                  url     views  \
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 1  https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 2  https://www.ted.com/talks/david_pogue_says_sim...   1636292
# 3  https://www.ted.com/talks/majora_carter_s_tale...   1697550
# 4  https://www.ted.com/talks/hans_rosling_shows_t...  12005869
#
#                                           transcript video_id event_id  \
# 0  Good morning. How are you?(Laughter)It's been ...        0       57
# 1  Thank you so much, Chris. And it's truly a gre...        1       57
# 2  (Music: "The Sound of Silence," Simon & Garfun...        2       57
# 3  If you're here today — and I'm very happy that...        3       57
# 4  About 10 years ago, I took on the task to teac...        4       57
#
#    start_date    end_date  id                            occupation
# 0  01-02-2006  27-02-2006   0                       Author/educator
# 1  01-02-2006  27-02-2006   1                      Climate advocate
# 2  01-02-2006  27-02-2006   2                  Technology columnist
# 3  01-02-2006  27-02-2006   3    Activist for environmental justice
# 4  01-02-2006  27-02-2006   4  Global health expert; data visionary
#
# [5 rows x 24 columns]

# %%
# delete occupation column and rename occpation_id

data.drop('occupation', axis = 1, inplace = True)

data.rename(columns={'id':'occupation_id'}, inplace=True)

data.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  24-02-2006         60   Ken Robinson
# 1  TED2006  24-02-2006         43        Al Gore
# 2  TED2006  23-02-2006         26    David Pogue
# 3  TED2006  25-02-2006         35  Majora Carter
# 4  TED2006  21-02-2006         48   Hans Rosling
#
#                                             name  num_speaker published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1     26-06-2006
# 1           Al Gore: Averting the climate crisis            1     26-06-2006
# 2                  David Pogue: Simplicity sells            1     26-06-2006
# 3             Majora Carter: Greening the ghetto            1     26-06-2006
# 4  Hans Rosling: The best stats you've ever seen            1     27-06-2006
#
#    ...                                               tags  \
# 0  ...  ['children', 'creativity', 'culture', 'dance',...
# 1  ...  ['alternative energy', 'cars', 'climate change...
# 2  ...  ['computers', 'entertainment', 'interface desi...
# 3  ...  ['MacArthur grant', 'activism', 'business', 'c...
# 4  ...  ['Africa', 'Asia', 'Google', 'demo', 'economic...
#
#                              title  \
# 0      Do schools kill creativity?
# 1      Averting the climate crisis
# 2                 Simplicity sells
# 3              Greening the ghetto
# 4  The best stats you've ever seen
#
#                                                  url     views  \
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 1  https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 2  https://www.ted.com/talks/david_pogue_says_sim...   1636292
# 3  https://www.ted.com/talks/majora_carter_s_tale...   1697550
# 4  https://www.ted.com/talks/hans_rosling_shows_t...  12005869
#
#                                           transcript video_id  event_id  \
# 0  Good morning. How are you?(Laughter)It's been ...        0        57
# 1  Thank you so much, Chris. And it's truly a gre...        1        57
# 2  (Music: "The Sound of Silence," Simon & Garfun...        2        57
# 3  If you're here today — and I'm very happy that...        3        57
# 4  About 10 years ago, I took on the task to teac...        4        57
#
#    start_date    end_date  occupation_id
# 0  01-02-2006  27-02-2006              0
# 1  01-02-2006  27-02-2006              1
# 2  01-02-2006  27-02-2006              2
# 3  01-02-2006  27-02-2006              3
# 4  01-02-2006  27-02-2006              4
#
# [5 rows x 23 columns]

# %%
# languages

# we only have numbers, so combining video IDs and languages columns

languages = data[['video_id', 'languages']]

languages.head()
# Out:
#    video_id  languages
# 0         0         60
# 1         1         43
# 2         2         26
# 3         3         35
# 4         4         48

# %%
# main_speakers

main_speakers = data[['main_speaker', 'occupation_id']]

main_speakers.head()
# Out:
#     main_speaker  occupation_id
# 0   Ken Robinson              0
# 1        Al Gore              1
# 2    David Pogue              2
# 3  Majora Carter              3
# 4   Hans Rosling              4

# %%
main_speakers.shape
# Out:
# (2550, 2)

# %%
main_speakers.drop_duplicates(inplace=True)

main_speakers.shape
# Out:
# C:\Users\casey\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# (2159, 2)

# %%
# create main speaker IDs

main_speakers.reset_index(inplace=True)

main_speakers['id'] = main_speakers.index

main_speakers = main_speakers[['id', 'main_speaker', 'occupation_id']]

main_speakers.head()
# Out:
# C:\Users\casey\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#    id   main_speaker  occupation_id
# 0   0   Ken Robinson              0
# 1   1        Al Gore              1
# 2   2    David Pogue              2
# 3   3  Majora Carter              3
# 4   4   Hans Rosling              4

# %%
# add IDs back to data

data = pd.merge(left = data, right = main_speakers, how = 'left', on = ['main_speaker', 'occupation_id'])

data.rename(columns = {'id':'speaker_id'}, inplace = True)

data.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  24-02-2006         60   Ken Robinson
# 1  TED2006  24-02-2006         43        Al Gore
# 2  TED2006  23-02-2006         26    David Pogue
# 3  TED2006  25-02-2006         35  Majora Carter
# 4  TED2006  21-02-2006         48   Hans Rosling
#
#                                             name  num_speaker published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1     26-06-2006
# 1           Al Gore: Averting the climate crisis            1     26-06-2006
# 2                  David Pogue: Simplicity sells            1     26-06-2006
# 3             Majora Carter: Greening the ghetto            1     26-06-2006
# 4  Hans Rosling: The best stats you've ever seen            1     27-06-2006
#
#    ...                            title  \
# 0  ...      Do schools kill creativity?
# 1  ...      Averting the climate crisis
# 2  ...                 Simplicity sells
# 3  ...              Greening the ghetto
# 4  ...  The best stats you've ever seen
#
#                                                  url     views  \
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 1  https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 2  https://www.ted.com/talks/david_pogue_says_sim...   1636292
# 3  https://www.ted.com/talks/majora_carter_s_tale...   1697550
# 4  https://www.ted.com/talks/hans_rosling_shows_t...  12005869
#
#                                           transcript video_id event_id  \
# 0  Good morning. How are you?(Laughter)It's been ...        0       57
# 1  Thank you so much, Chris. And it's truly a gre...        1       57
# 2  (Music: "The Sound of Silence," Simon & Garfun...        2       57
# 3  If you're here today — and I'm very happy that...        3       57
# 4  About 10 years ago, I took on the task to teac...        4       57
#
#    start_date    end_date  occupation_id  speaker_id
# 0  01-02-2006  27-02-2006              0           0
# 1  01-02-2006  27-02-2006              1           1
# 2  01-02-2006  27-02-2006              2           2
# 3  01-02-2006  27-02-2006              3           3
# 4  01-02-2006  27-02-2006              4           4
#
# [5 rows x 24 columns]

# %%
# presentations - all unique combos of videos events and speakers

presentations = data[['video_id', 'event_id', 'speaker_id']].drop_duplicates()

presentations.head()
# Out:
#    video_id  event_id  speaker_id
# 0         0        57           0
# 1         1        57           1
# 2         2        57           2
# 3         3        57           3
# 4         4        57           4

# %%
# url_links

url_links = data[['video_id', 'url']].drop_duplicates()

url_links.head()
# Out:
#    video_id                                                url
# 0         0  https://www.ted.com/talks/ken_robinson_says_sc...
# 1         1  https://www.ted.com/talks/al_gore_on_averting_...
# 2         2  https://www.ted.com/talks/david_pogue_says_sim...
# 3         3  https://www.ted.com/talks/majora_carter_s_tale...
# 4         4  https://www.ted.com/talks/hans_rosling_shows_t...

# %%
# transcripts

transcripts = data[['video_id', 'transcript']].drop_duplicates()

transcripts.head()
# Out:
#    video_id                                         transcript
# 0         0  Good morning. How are you?(Laughter)It's been ...
# 1         1  Thank you so much, Chris. And it's truly a gre...
# 2         2  (Music: "The Sound of Silence," Simon & Garfun...
# 3         3  If you're here today — and I'm very happy that...
# 4         4  About 10 years ago, I took on the task to teac...

# %%
# dates

dates = data[['video_id', 'film_date', 'published_date']].drop_duplicates()

dates.head()
# Out:
#    video_id   film_date published_date
# 0         0  24-02-2006     26-06-2006
# 1         1  24-02-2006     26-06-2006
# 2         2  23-02-2006     26-06-2006
# 3         3  25-02-2006     26-06-2006
# 4         4  21-02-2006     27-06-2006

# %%
# video stats

video_stats = data[['video_id', 'duration', 'num_speaker', 'views', 'comments']].drop_duplicates()

video_stats.head()
# Out:
#    video_id  duration  num_speaker     views  comments
# 0         0      1164            1  47227110      4553
# 1         1       977            1   3200520       265
# 2         2      1286            1   1636292       124
# 3         3      1116            1   1697550       200
# 4         4      1190            1  12005869       593

# %%
# video tags

video_tags = data[['video_id', 'tags']]

video_tags.head()
# Out:
#    video_id                                               tags
# 0         0  ['children', 'creativity', 'culture', 'dance',...
# 1         1  ['alternative energy', 'cars', 'climate change...
# 2         2  ['computers', 'entertainment', 'interface desi...
# 3         3  ['MacArthur grant', 'activism', 'business', 'c...
# 4         4  ['Africa', 'Asia', 'Google', 'demo', 'economic...

# %%
# clean tags

vid_tags = video_tags['tags'].apply(lambda x: str.split(x,sep=","))

video_tags['tags'] = vid_tags

video_tags.head()
# Out:
# C:\Users\casey\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#    video_id                                               tags
# 0         0  [['children',  'creativity',  'culture',  'dan...
# 1         1  [['alternative energy',  'cars',  'climate cha...
# 2         2  [['computers',  'entertainment',  'interface d...
# 3         3  [['MacArthur grant',  'activism',  'business',...
# 4         4  [['Africa',  'Asia',  'Google',  'demo',  'eco...

# %%
video_tags = video_tags.explode('tags')

video_tags.head(15)
# Out:
#    video_id                   tags
# 0         0            ['children'
# 0         0           'creativity'
# 0         0              'culture'
# 0         0                'dance'
# 0         0            'education'
# 0         0            'parenting'
# 0         0            'teaching']
# 1         1  ['alternative energy'
# 1         1                 'cars'
# 1         1       'climate change'
# 1         1              'culture'
# 1         1          'environment'
# 1         1        'global issues'
# 1         1              'science'
# 1         1       'sustainability'

# %%
# clean brackets in tag names

video_tags['tags'].replace('[^\w\s]', '', regex = True, inplace = True)

video_tags.head(15)
# Out:
#    video_id                tags
# 0         0            children
# 0         0          creativity
# 0         0             culture
# 0         0               dance
# 0         0           education
# 0         0           parenting
# 0         0            teaching
# 1         1  alternative energy
# 1         1                cars
# 1         1      climate change
# 1         1             culture
# 1         1         environment
# 1         1       global issues
# 1         1             science
# 1         1      sustainability

# %%
# create tags table

video_tags.rename(columns = {'tags':'tag'}, inplace = True)

tags = video_tags['tag'].drop_duplicates()

tags = pd.DataFrame(tags)

tags.reset_index(drop = True, inplace = True)

tags['id'] = tags.index

tags.head(15)
# Out:
#                    tag  id
# 0             children   0
# 1           creativity   1
# 2              culture   2
# 3                dance   3
# 4            education   4
# 5            parenting   5
# 6             teaching   6
# 7   alternative energy   7
# 8                 cars   8
# 9       climate change   9
# 10         environment  10
# 11       global issues  11
# 12             science  12
# 13      sustainability  13
# 14          technology  14

# %%
# join tag IDs back to video tags

video_tags = pd.merge(left = video_tags, right = tags, how = 'left', on = 'tag')

video_tags.rename(columns = {'id':'tag_id'}, inplace = True)

video_tags.head(10)
# Out:
#    video_id                 tag  tag_id
# 0         0            children       0
# 1         0          creativity       1
# 2         0             culture       2
# 3         0               dance       3
# 4         0           education       4
# 5         0           parenting       5
# 6         0            teaching       6
# 7         1  alternative energy       7
# 8         1                cars       8
# 9         1      climate change       9

# %%
# delete tag from video tags

video_tags.drop(columns = 'tag', inplace = True)

video_tags.head()
# Out:
#    video_id  tag_id
# 0         0       0
# 1         0       1
# 2         0       2
# 3         0       3
# 4         0       4

# %%
video_tags.shape
# Out:
# (19154, 2)

# %%
# related talks

import ast

# %%
data['related_talks'] = data['related_talks'].apply(lambda x: ast.literal_eval(x))

data['related_talks'].head()
# Out:
# 0    [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 1    [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...
# 2    [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...
# 3    [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
# 4    [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...
# Name: related_talks, dtype: object

# %%
s = data.apply(lambda x: pd.Series(x['related_talks']),axis=1).stack().reset_index(level=1, drop=True)

s.name = 'related'

# %%
s.head()
# Out:
# 0    {'id': 865, 'hero': 'https://pe.tedcdn.com/ima...
# 0    {'id': 1738, 'hero': 'https://pe.tedcdn.com/im...
# 0    {'id': 2276, 'hero': 'https://pe.tedcdn.com/im...
# 0    {'id': 892, 'hero': 'https://pe.tedcdn.com/ima...
# 0    {'id': 1232, 'hero': 'https://pe.tedcdn.com/im...
# Name: related, dtype: object

# %%
related_df = data.drop('related_talks', axis=1).join(s)

# %%
related_df.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  24-02-2006         60  Ken Robinson
# 0  TED2006  24-02-2006         60  Ken Robinson
# 0  TED2006  24-02-2006         60  Ken Robinson
# 0  TED2006  24-02-2006         60  Ken Robinson
# 0  TED2006  24-02-2006         60  Ken Robinson
#
#                                         name  num_speaker published_date  ...  \
# 0  Ken Robinson: Do schools kill creativity?            1     26-06-2006  ...
# 0  Ken Robinson: Do schools kill creativity?            1     26-06-2006  ...
# 0  Ken Robinson: Do schools kill creativity?            1     26-06-2006  ...
# 0  Ken Robinson: Do schools kill creativity?            1     26-06-2006  ...
# 0  Ken Robinson: Do schools kill creativity?            1     26-06-2006  ...
#
#                                                  url     views  \
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
#
#                                           transcript video_id event_id  \
# 0  Good morning. How are you?(Laughter)It's been ...        0       57
# 0  Good morning. How are you?(Laughter)It's been ...        0       57
# 0  Good morning. How are you?(Laughter)It's been ...        0       57
# 0  Good morning. How are you?(Laughter)It's been ...        0       57
# 0  Good morning. How are you?(Laughter)It's been ...        0       57
#
#    start_date    end_date  occupation_id  speaker_id  \
# 0  01-02-2006  27-02-2006              0           0
# 0  01-02-2006  27-02-2006              0           0
# 0  01-02-2006  27-02-2006              0           0
# 0  01-02-2006  27-02-2006              0           0
# 0  01-02-2006  27-02-2006              0           0
#
#                                              related
# 0  {'id': 865, 'hero': 'https://pe.tedcdn.com/ima...
# 0  {'id': 1738, 'hero': 'https://pe.tedcdn.com/im...
# 0  {'id': 2276, 'hero': 'https://pe.tedcdn.com/im...
# 0  {'id': 892, 'hero': 'https://pe.tedcdn.com/ima...
# 0  {'id': 1232, 'hero': 'https://pe.tedcdn.com/im...
#
# [5 rows x 24 columns]

# %%
dic = related_df.reset_index()['related'][0]

# %%
for i in dic.keys():
    
    related_df['related_'+i] = related_df['related'].apply(lambda x: x[i])

# %%
related_df.drop('related', axis=1, inplace=True)

# %%
related_df.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  24-02-2006         60  Ken Robinson
# 0  TED2006  24-02-2006         60  Ken Robinson
# 0  TED2006  24-02-2006         60  Ken Robinson
# 0  TED2006  24-02-2006         60  Ken Robinson
# 0  TED2006  24-02-2006         60  Ken Robinson
#
#                                         name  num_speaker published_date  ...  \
# 0  Ken Robinson: Do schools kill creativity?            1     26-06-2006  ...
# 0  Ken Robinson: Do schools kill creativity?            1     26-06-2006  ...
# 0  Ken Robinson: Do schools kill creativity?            1     26-06-2006  ...
# 0  Ken Robinson: Do schools kill creativity?            1     26-06-2006  ...
# 0  Ken Robinson: Do schools kill creativity?            1     26-06-2006  ...
#
#      end_date occupation_id speaker_id related_id  \
# 0  27-02-2006             0          0        865
# 0  27-02-2006             0          0       1738
# 0  27-02-2006             0          0       2276
# 0  27-02-2006             0          0        892
# 0  27-02-2006             0          0       1232
#
#                                         related_hero      related_speaker  \
# 0  https://pe.tedcdn.com/images/ted/172559_800x60...         Ken Robinson
# 0  https://pe.tedcdn.com/images/ted/de98b161ad143...         Ken Robinson
# 0  https://pe.tedcdn.com/images/ted/3821f3728e0b7...  Linda Cliatt-Wayman
# 0  https://pe.tedcdn.com/images/ted/e79958940573c...   Charles Leadbeater
# 0  https://pe.tedcdn.com/images/ted/0e3e4e92d5ee8...         Geoff Mulgan
#
#                                        related_title  related_duration  \
# 0                  Bring on the learning revolution!              1008
# 0             How to escape education's death valley              1151
# 0  How to fix a broken school? Lead fearlessly, l...              1027
# 0                  Education innovation in the slums              1138
# 0                 A short intro to the Studio School               376
#
#                                         related_slug related_viewed_count
# 0           sir_ken_robinson_bring_on_the_revolution              7266103
# 0  ken_robinson_how_to_escape_education_s_death_v...              6657572
# 0  linda_cliatt_wayman_how_to_fix_a_broken_school...              1617101
# 0                    charles_leadbeater_on_education               772296
# 0    geoff_mulgan_a_short_intro_to_the_studio_school               667971
#
# [5 rows x 30 columns]

# %%
related_videos = related_df[['video_id', 'related_id']].drop_duplicates()

# %%
related_videos.head()
# Out:
#    video_id  related_id
# 0         0         865
# 0         0        1738
# 0         0        2276
# 0         0         892
# 0         0        1232

# %%
related_videos.shape
# Out:
# (15010, 2)

# %%
# ratings

data['ratings'] = data['ratings'].apply(lambda x: ast.literal_eval(x))

# %%
s = data.apply(lambda x: pd.Series(x['ratings']),axis=1).stack().reset_index(level=1, drop=True)

s.name = 'ratings'

# %%
main_df = data.drop('ratings', axis=1).join(s)

main_df.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  24-02-2006         60  Ken Robinson
# 0  TED2006  24-02-2006         60  Ken Robinson
# 0  TED2006  24-02-2006         60  Ken Robinson
# 0  TED2006  24-02-2006         60  Ken Robinson
# 0  TED2006  24-02-2006         60  Ken Robinson
#
#                                         name  num_speaker published_date  ...  \
# 0  Ken Robinson: Do schools kill creativity?            1     26-06-2006  ...
# 0  Ken Robinson: Do schools kill creativity?            1     26-06-2006  ...
# 0  Ken Robinson: Do schools kill creativity?            1     26-06-2006  ...
# 0  Ken Robinson: Do schools kill creativity?            1     26-06-2006  ...
# 0  Ken Robinson: Do schools kill creativity?            1     26-06-2006  ...
#
#                                                  url     views  \
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
#
#                                           transcript video_id event_id  \
# 0  Good morning. How are you?(Laughter)It's been ...        0       57
# 0  Good morning. How are you?(Laughter)It's been ...        0       57
# 0  Good morning. How are you?(Laughter)It's been ...        0       57
# 0  Good morning. How are you?(Laughter)It's been ...        0       57
# 0  Good morning. How are you?(Laughter)It's been ...        0       57
#
#    start_date    end_date  occupation_id  speaker_id  \
# 0  01-02-2006  27-02-2006              0           0
# 0  01-02-2006  27-02-2006              0           0
# 0  01-02-2006  27-02-2006              0           0
# 0  01-02-2006  27-02-2006              0           0
# 0  01-02-2006  27-02-2006              0           0
#
#                                           ratings
# 0      {'id': 7, 'name': 'Funny', 'count': 19645}
# 0   {'id': 1, 'name': 'Beautiful', 'count': 4573}
# 0   {'id': 9, 'name': 'Ingenious', 'count': 6073}
# 0  {'id': 3, 'name': 'Courageous', 'count': 3253}
# 0  {'id': 11, 'name': 'Longwinded', 'count': 387}
#
# [5 rows x 24 columns]

# %%
dic = main_df.reset_index()['ratings'][0]

# %%
for i in dic.keys():
    
    main_df['ratings_'+i] = main_df['ratings'].apply(lambda x: x[i])

# %%
main_df.drop('ratings', axis=1, inplace=True)

main_df.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  24-02-2006         60  Ken Robinson
# 0  TED2006  24-02-2006         60  Ken Robinson
# 0  TED2006  24-02-2006         60  Ken Robinson
# 0  TED2006  24-02-2006         60  Ken Robinson
# 0  TED2006  24-02-2006         60  Ken Robinson
#
#                                         name  num_speaker published_date  ...  \
# 0  Ken Robinson: Do schools kill creativity?            1     26-06-2006  ...
# 0  Ken Robinson: Do schools kill creativity?            1     26-06-2006  ...
# 0  Ken Robinson: Do schools kill creativity?            1     26-06-2006  ...
# 0  Ken Robinson: Do schools kill creativity?            1     26-06-2006  ...
# 0  Ken Robinson: Do schools kill creativity?            1     26-06-2006  ...
#
#                                           transcript video_id event_id  \
# 0  Good morning. How are you?(Laughter)It's been ...        0       57
# 0  Good morning. How are you?(Laughter)It's been ...        0       57
# 0  Good morning. How are you?(Laughter)It's been ...        0       57
# 0  Good morning. How are you?(Laughter)It's been ...        0       57
# 0  Good morning. How are you?(Laughter)It's been ...        0       57
#
#    start_date    end_date  occupation_id speaker_id  ratings_id  ratings_name  \
# 0  01-02-2006  27-02-2006              0          0           7         Funny
# 0  01-02-2006  27-02-2006              0          0           1     Beautiful
# 0  01-02-2006  27-02-2006              0          0           9     Ingenious
# 0  01-02-2006  27-02-2006              0          0           3    Courageous
# 0  01-02-2006  27-02-2006              0          0          11    Longwinded
#
#   ratings_count
# 0         19645
# 0          4573
# 0          6073
# 0          3253
# 0           387
#
# [5 rows x 26 columns]

# %%
ratings_df = pd.DataFrame(main_df, columns = ['ratings_id', 'ratings_name'])

ratings_df.rename(columns = {'ratings_id':'id', 'ratings_name':'rating'}, inplace = True)

ratings_df.head()
# Out:
#    id      rating
# 0   7       Funny
# 0   1   Beautiful
# 0   9   Ingenious
# 0   3  Courageous
# 0  11  Longwinded

# %%
ratings_df = ratings_df.drop_duplicates()

ratings_df
# Out:
#    id        rating
# 0   7         Funny
# 0   1     Beautiful
# 0   9     Ingenious
# 0   3    Courageous
# 0  11    Longwinded
# 0   2     Confusing
# 0   8   Informative
# 0  22   Fascinating
# 0  21  Unconvincing
# 0  24    Persuasive
# 0  23  Jaw-dropping
# 0  25            OK
# 0  26     Obnoxious
# 0  10     Inspiring

# %%
# video_ratings

video_ratings = main_df[['video_id', 'ratings_id']].drop_duplicates()

video_ratings.head()
# Out:
#    video_id  ratings_id
# 0         0           7
# 0         0           1
# 0         0           9
# 0         0           3
# 0         0          11

# %%
video_ratings.shape
# Out:
# (35700, 2)

# %%
video_ratings.rename(columns = {'ratings_id':'rating_id'}, inplace = True)

video_ratings.head()
# Out:
#    video_id  rating_id
# 0         0          7
# 0         0          1
# 0         0          9
# 0         0          3
# 0         0         11

# %%
# SQL

from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
import psycopg2

# %%
conn_url = "postgres://postgres:password@localhost/ted_talks"

# %%
engine = create_engine(conn_url)

if not database_exists(engine.url):
    create_database(engine.url)

# %%
connection = engine.connect()

# %%
stmt = '''
    
CREATE TABLE videos (
    id integer,
    title varchar(150) NOT NULL,
    description text,
    PRIMARY KEY (id)
);

CREATE TABLE events (
    id integer,
    event_name varchar(150),
    start_date date,
    end_date date,
    PRIMARY KEY (id)
);

CREATE TABLE occupations (
    id integer,
    occupation_name varchar(100),
    PRIMARY KEY (id)
);

CREATE TABLE languages (
    video_id integer,
    languages integer,
    PRIMARY KEY (video_id, languages),
    FOREIGN KEY (video_id) REFERENCES videos (id) ON UPDATE CASCADE ON
    DELETE CASCADE
);

CREATE TABLE main_speakers (
    id integer,
    speaker_name varchar(100),
    speaker_occupation_id integer,
    PRIMARY KEY (id),
    FOREIGN KEY (speaker_occupation_id) REFERENCES occupations (id) ON UPDATE
    CASCADE ON DELETE CASCADE
);

CREATE TABLE presentations (
    video_id integer,
    event_id integer,
    speaker_id integer,
    PRIMARY KEY (video_id, speaker_id),
    FOREIGN KEY (video_id) REFERENCES videos (id) ON UPDATE CASCADE ON
    DELETE CASCADE,
    FOREIGN KEY (event_id) REFERENCES events (id) ON UPDATE CASCADE ON
    DELETE CASCADE,
    FOREIGN KEY (speaker_id) REFERENCES main_speakers (id) ON UPDATE
    CASCADE ON DELETE CASCADE
);

CREATE TABLE url_links (
    video_id integer,
    url_link text,
    PRIMARY KEY(video_id, url_link),
    FOREIGN KEY (video_id) REFERENCES videos (id) ON UPDATE CASCADE ON
    DELETE CASCADE
);

CREATE TABLE transcripts (
    video_id integer,
    transcript text,
    PRIMARY KEY(video_id, transcript),
    FOREIGN KEY (video_id) REFERENCES videos (id) ON UPDATE CASCADE ON
    DELETE CASCADE
);

CREATE TABLE dates (
    video_id integer,
    film_date date,
    published_date date,
    PRIMARY KEY(video_id, film_date, published_date),
    FOREIGN KEY (video_id) REFERENCES videos (id) ON UPDATE CASCADE ON
    DELETE CASCADE
);

CREATE TABLE video_stats (
    video_id integer,
    duration numeric NOT NULL,
    number_views numeric,
    number_comments numeric,
    PRIMARY KEY (video_id, duration),
    FOREIGN KEY (video_id) REFERENCES videos (id) ON UPDATE CASCADE ON
    DELETE CASCADE
);

CREATE TABLE related_videos (
    video_id integer,
    related_id integer,
    PRIMARY KEY (video_id, related_video_id),
    FOREIGN KEY (video_id) REFERENCES videos (id) ON UPDATE CASCADE ON
    DELETE CASCADE,
    FOREIGN KEY (related_video_id) REFERENCES videos (id) ON UPDATE CASCADE
    ON DELETE CASCADE
);

CREATE TABLE tags (
    id integer,
    tag varchar (30),
    PRIMARY KEY (id)
);

CREATE TABLE video_tags (
    video_id integer,
    tag_id integer,
    PRIMARY KEY (video_id ,tag_id),
    FOREIGN KEY (video_id) REFERENCES videos (id) ON UPDATE CASCADE ON
    DELETE CASCADE,
    FOREIGN KEY (tag_id) REFERENCES tags (id) ON UPDATE CASCADE ON DELETE
    CASCADE
);

CREATE TABLE ratings (
    id integer,
    rating text,
    PRIMARY KEY (id)
);

CREATE TABLE video_ratings (
    video_id integer,
    rating_id integer,
    PRIMARY KEY (video_id , rating_id),
    FOREIGN KEY (video_id) REFERENCES videos (id) ON UPDATE CASCADE ON
    DELETE CASCADE,
    FOREIGN KEY (rating_id) REFERENCES ratings (id) ON UPDATE CASCADE ON
    DELETE CASCADE
);
    
'''

# %%
# videos

videos.to_sql('videos', engine, if_exists='replace', index = False)

# %%
# events

events.to_sql('events', engine, if_exists='replace', index = False)

# %%
# occupations

occupations.to_sql('occupations', engine, if_exists='replace', index = False)

# %%
# languages

languages.to_sql('languages', engine, if_exists='replace', index = False)

# %%
# main_speakers

main_speakers.to_sql('main_speakers', engine, if_exists='replace', index = False)

# %%
# presentations

presentations.to_sql('presentations', engine, if_exists='replace', index = False)

# %%
# url_links

url_links.to_sql('url_links', engine, if_exists='replace', index = False)

# %%
# transcripts

transcripts.to_sql('transcripts', engine, if_exists='replace', index = False)

# %%
# dates

dates.to_sql('dates', engine, if_exists='replace', index = False)

# %%
# video_stats

video_stats.to_sql('video_stats', engine, if_exists='replace', index = False)

# %%
# related_videos

related_videos.to_sql('related_videos', engine, if_exists='replace', index = False)

# %%
# tags

tags.to_sql('tags', engine, if_exists='replace', index = False)

# %%
# video_tags

video_tags.to_sql('video_tags', engine, if_exists='replace', index = False)

# %%
# ratings

ratings_df.to_sql('ratings', engine, if_exists='replace', index = False)

# %%
# video_ratings

video_ratings.to_sql('video_ratings', engine, if_exists='replace', index = False)

# %%
# test queries

stmt = ''' SELECT * FROM videos; '''

connection.execute(stmt).fetchall()
# Out:
# [(0, 'Do schools kill creativity?', 'Sir Ken Robinson makes an entertaining and profoundly moving case for creating an education system that nurtures (rather than undermines) creativity.'),
#  (1, 'Averting the climate crisis', 'With the same humor and humanity he exuded in "An Inconvenient Truth," Al Gore spells out 15 ways that individuals can address climate change immediately, from buying a hybrid to inventing a new, hotter brand name for global warming.'),
#  (2, 'Simplicity sells', 'New York Times columnist David Pogue takes aim at technology’s worst interface-design offenders, and provides encouraging examples of products that get it right. To funny things up, he bursts into song.'),
#  (3, 'Greening the ghetto', 'In an emotionally charged talk, MacArthur-winning activist Majora Carter details her fight for environmental justice in the South Bronx -- and shows how minority neighborhoods suffer most from flawed urban policy.'),
#  (4, "The best stats you've ever seen", 'You\'ve never seen data presented like this. With the drama and urgency of a sportscaster, statistics guru Hans Rosling debunks myths about the so-called "developing world."'),
#  (5, 'Why we do what we do', 'Tony Robbins discusses the "invisible forces" that motivate everyone\'s actions -- and high-fives Al Gore in the front row.'),
#  (6, 'Letting go of God', 'When two young Mormon missionaries knock on Julia Sweeney\'s door one day, it touches off a quest to completely rethink her own beliefs, in this excerpt from Sweeney\'s solo show "Letting Go of God."  '),
#  (7, "Behind the design of Seattle's library", 'Architect Joshua Prince-Ramus takes the audience on dazzling, dizzying virtual tours of three recent projects: the Central Library in Seattle, the Museum Plaza in Louisville and the Charles Wyly Theater in Dallas.'),
#  (8, "Let's teach religion -- all religion -- in schools", 'Philosopher Dan Dennett calls for religion -- all religion -- to be taught in schools, so we can understand its nature as a natural phenomenon. Then he takes on The Purpose-Driven Life, disputing its claim that, to be moral, one must deny evolution.'),
#  (9, 'A life of purpose', 'Pastor Rick Warren, author of "The Purpose-Driven Life," reflects on his own crisis of purpose in the wake of his book\'s wild success. He explains his belief that God\'s intention is for each of us to use our talents and influence to do good.'),
#  (10, 'My wish: A call for open-source architecture', 'Accepting his 2006 TED Prize, Cameron Sinclair demonstrates how passionate designers and architects can respond to world housing crises. He unveils his TED Prize wish for a network to improve global living standards through collaborative design.'),
#  (11, 'My wish: A global day of film', 'Jehane Noujaim unveils her 2006 TED Prize wish: to bring the world together for one day a year through the power of film.'),
#  (12, 'My wish: Help me stop pandemics', 'Accepting the 2006 TED Prize, Dr. Larry Brilliant talks about how smallpox was eradicated from the planet, and calls for a new global system that can identify and contain pandemics before they spread.'),
#  (13, 'The radical promise of the multi-touch interface', 'Jeff Han shows off a cheap, scalable multi-touch and pressure-sensitive computer screen interface that may spell the end of point-and-click.'),
#  (14, 'One Laptop per Child', 'Nicholas Negroponte, founder of the MIT Media Laboratory, describes how the One Laptop Per Child project will build and distribute the "$100 laptop."'),
#  (15, "An 11-year-old's magical violin", 'Violinist Sirena Huang gives a technically brilliant and emotionally nuanced performance. In a charming interlude, the 11-year-old praises the timeless design of her instrument.'),
#  (16, 'Improvising on piano, aged 14', 'Pianist and composer Jennifer Lin gives a magical performance, talks about the process of creativity and improvises a moving solo piece based on a random sequence of notes.'),
#  (17, 'Simple designs to save a life', 'Fumes from indoor cooking fires kill more than 2 million children a year in the developing world. MIT engineer Amy Smith details an exciting but simple solution: a tool for turning farm waste into clean-burning charcoal.'),
#  (18, 'Organic design, inspired by nature', 'Designer Ross Lovegrove expounds his philosophy of "fat-free" design and offers insight into several of his extraordinary products, including the Ty Nant water bottle and the Go chair.'),
#  (19, 'The birth of Wikipedia', 'Jimmy Wales recalls how he assembled "a ragtag band of volunteers," gave them tools for collaborating and created Wikipedia, the self-organizing, self-correcting, never-finished online encyclopedia.'),
#  (20, 'The birth of the open-source learning revolution', 'In 2006, open-learning visionary Richard Baraniuk explains the vision behind Connexions (now called OpenStax), an open-source, online education system. It cuts out the textbook, allowing teachers to share and modify course materials freely, anywhere in the world.'),
#  (21, 'Nerdcore comedy', "Performer and web toymaker Ze Frank delivers a hilarious nerdcore standup routine, then tells us what he's seriously passionate about: helping people create and interact using simple, addictive web tools."),
#  (22, 'Meet the founder of the blog revolution', "The founding mother of the blog revolution, Movable Type's Mena Trott, talks about the early days of blogging, when she realized that giving regular people the power to share our lives online is the key to building a friendlier, more connected world."),
#  (23, 'Why we love, why we cheat', 'Anthropologist Helen Fisher takes on a tricky topic – love – and explains its evolution, its biochemical foundations and its social importance. She closes with a warning about the potential disaster inherent in antidepressant abuse.'),
#  (24, 'Happiness in body and soul', 'Eve Ensler, creator of "The Vagina Monologues," shares how a discussion about menopause with her friends led to talking about all sorts of sexual acts onstage, waging a global campaign to end violence toward women and finding her own happiness.'),
#  (25, 'Chemical scum that dream of distant quasars', 'Legendary scientist David Deutsch puts theoretical physics on the back burner to discuss a more urgent matter: the survival of our species. The first step toward solving global warming, he says, is to admit that we have a problem.'),
#  (26, 'Why the universe seems so strange', 'Biologist Richard Dawkins makes a case for "thinking the improbable" by looking at how the human frame of reference limits our understanding of the universe.'),
#  (27, 'The freakonomics of crack dealing', '"Freakonomics" author Steven Levitt presents new data on the finances of drug dealing. Contrary to popular myth, he says, being a street-corner crack dealer isn\'t lucrative: It pays below minimum wage. And your boss can kill you.'),
#  (28, 'Choice, happiness and spaghetti sauce', '"Tipping Point" author Malcolm Gladwell gets inside the food industry\'s pursuit of the perfect spaghetti sauce -- and makes a larger argument about the nature of choice and happiness.'),
#  (29, 'The surprising science of happiness', 'Dan Gilbert, author of "Stumbling on Happiness," challenges the idea that we’ll be miserable if we don’t get what we want. Our "psychological immune system" lets us feel truly happy even when things don’t go as planned.'),
#  (30, 'The paradox of choice', "Psychologist Barry Schwartz takes aim at a central tenet of western societies: freedom of choice. In Schwartz's estimation, choice has made us not freer but more paralyzed, not happier but more dissatisfied."),
#  (31, 'Meet the future of cancer research', 'Eva Vertes -- only 19 when she gave this talk -- discusses her journey toward studying medicine and her drive to understand the roots of cancer and Alzheimer’s.'),
#  (32, 'A roadmap to end aging', 'Cambridge researcher Aubrey de Grey argues that aging is merely a disease -- and a curable one at that. Humans age in seven basic ways, he says, all of which can be averted.'),
#  (33, 'How mobile phones can fight poverty', 'Iqbal Quadir tells how his experiences as a kid in poor Bangladesh, and later as a banker in New York, led him to start a mobile phone operator connecting 80 million rural Bangladeshi -- and to become a champion of bottom-up development.'),
#  (34, "Invest in Africa's own solutions", "Jacqueline Novogratz applauds the world's heightened interest in Africa and poverty, but argues persuasively for a new approach."),
#  (35, 'Why we should invest in a free press', 'A free press -- papers, magazines, radio, TV, blogs -- is the backbone of any true democracy (and a vital watchdog on business). Sasa Vucinic, a journalist from Belgrade, talks about his new fund, which supports media by selling "free press bonds."'),
#  (36, 'How to rebuild a broken state', "Ashraf Ghani's passionate and powerful 10-minute talk, emphasizing the necessity of both economic investment and design ingenuity to rebuild broken states, is followed by a conversation with TED curator Chris Anderson on the future of Afghanistan."),
#  (37, 'The real future of space exploration', 'In this passionate talk, legendary spacecraft designer Burt Rutan lambasts the US government-funded space program for stagnating and asks entrepreneurs to pick up where NASA has left off.'),
#  (38, 'Why did I ski to the North Pole?', 'Arctic explorer Ben Saunders recounts his harrowing solo ski trek to the North Pole, complete with engaging anecdotes, gorgeous photos and never-before-seen video.'),
#  (39, 'My wish: Three actions for Africa', "Musician and activist Bono accepts the 2005 TED Prize with a riveting talk, arguing that aid to Africa isn't just another celebrity cause; it's a global emergency."),
#  (40, 'My wish: Manufactured landscapes and green education', "Accepting his 2005 TED Prize, photographer Edward Burtynsky makes a wish: that his images -- stunning landscapes that document humanity's impact on the world -- help persuade millions to join a global conversation on sustainability."),
#  (41, 'My wish: Three unusual medical inventions', 'Accepting his 2005 TED Prize, inventor Robert Fischell makes three wishes: redesigning a portable device that treats migraines, finding new cures for clinical depression and reforming the medical malpractice system.'),
#  (42, 'How juries are fooled by statistics', 'Oxford mathematician Peter Donnelly reveals the common mistakes humans make in interpreting statistics -- and the devastating impact these errors can have on the outcome of criminal trials.'),
#  (43, 'Why people believe weird things', 'Why do people see the Virgin Mary on a cheese sandwich or hear demonic lyrics in "Stairway to Heaven"? Using video and music, skeptic Michael Shermer shows how we convince ourselves to believe -- and overlook the facts.'),
#  (44, 'The accelerating power of technology', 'Inventor, entrepreneur and visionary Ray Kurzweil explains in abundant, grounded detail why, by the 2020s, we will have reverse-engineered the human brain and nanobots will be operating your consciousness.'),
#  (45, 'How technology evolves', 'Tech enthusiast Kevin Kelly asks "What does technology want?" and discovers that its movement toward ubiquity and complexity is much like the evolution of life.'),
#  (46, 'Fight injustice with raw video', 'Musician and activist Peter Gabriel shares his very personal motivation for standing up for human rights with the watchdog group WITNESS -- and tells stories of citizen journalists in action.'),
#  (47, '8 secrets of success', "Why do people succeed? Is it because they're smart? Or are they just lucky? Neither. Analyst Richard St. John condenses years of interviews into an unmissable 3-minute slideshow on the real secrets of success."),
#  (48, 'If I controlled the Internet', "How many poets could cram eBay, Friendster and Monster.com into 3-minute poem worthy of a standing ovation? Enjoy Rives' unique talent."),
#  (49, "The killer American diet that's sweeping the planet", 'Forget the latest disease in the news: Cardiovascular disease kills more people than everything else combined -- and it’s mostly preventable. Dr. Dean Ornish explains how changing our eating habits can save lives.'),
#  (50, 'The hidden world of shadow cities', 'Robert Neuwirth, author of "Shadow Cities," finds the world\'s squatter sites -- where a billion people now make their homes -- to be thriving centers of ingenuity and innovation. He takes us on a tour.'),
#  (51, 'Global priorities bigger than climate change', 'Given $50 billion to spend, which would you solve first, AIDS or global warming? Danish political scientist Bjorn Lomborg comes up with surprising answers.'),
#  (52, 'Dreams from endangered cultures', "With stunning photos and stories, National Geographic Explorer Wade Davis celebrates the extraordinary diversity of the world's indigenous cultures, which are disappearing from the planet at an alarming rate."),
#  (53, 'Photos of endangered cultures', 'Photographer Phil Borges shows rarely seen images of people from the mountains of Dharamsala, India, and the jungles of the Ecuadorean Amazon. In documenting these endangered cultures, he intends to help preserve them.'),
#  (54, 'Is this our final century?', 'Speaking as both an astronomer and "a concerned member of the human race," Sir Martin Rees examines our planet and its future from a cosmic perspective. He urges action to prevent dark consequences from our scientific and technological development.'),
#  (55, 'Progress is not a zero-sum game', 'Author Robert Wright explains "non-zero-sumness" -- the network of linked fortunes and cooperation that has guided our evolution to this point -- and how we can use it to help save humanity today.'),
#  (56, 'How the "ghost map" helped end a killer disease', 'Author Steven Johnson takes us on a 10-minute tour of <i>The Ghost Map</i>, his book about a cholera outbreak in 1854 London and the impact it had on science, cities and modern society.'),
#  (57, 'The era of open innovation', "In this deceptively casual talk, Charles Leadbeater weaves a tight argument  that innovation isn't just for professionals anymore. Passionate amateurs, using new tools, are creating products and paradigms that companies can't."),
#  (58, 'A dance of "Symbiosis"', 'Two Pilobolus dancers perform "Symbiosis." Does it trace the birth of a relationship? Or the co-evolution of symbiotic species? Music: "God Music," George Crumb; "Fratres," Arvo Part; "Morango...Almost a Tango," Thomas Oboe Lee.'),
#  (59, 'Four American characters', 'Writer and actor Anna Deavere Smith gives life to author Studs Terkel, convict Paulette Jenkins, a Korean shopkeeper and a bull rider, excerpts from her solo show "On the Road: A Search for American Character."'),
#  (60, 'Everyday inventions', 'Inventor and MacArthur fellow Saul Griffith shares some innovative ideas from his lab -- from "smart rope" to a house-sized kite for towing large loads.'),
#  (61, 'Unleash your creativity in a Fab Lab', "MIT professor Neil Gershenfeld talks about his Fab Lab -- a low-cost lab that lets people build things they need using digital and analog tools. It's a simple idea with powerful results."),
#  (62, 'In praise of slowness', "Journalist Carl Honore believes the Western world's emphasis on speed erodes health, productivity and quality of life. But there's a backlash brewing, as everyday people start putting the brakes on their all-too-modern lives."),
#  (63, 'My wish: Rebuilding Rwanda', 'Accepting the 2007 TED Prize, Bill Clinton asks for help in bringing health care to Rwanda -- and the rest of the world.'),
#  (64, 'My wish: Build the Encyclopedia of Life', "As E.O. Wilson accepts his 2007 TED Prize, he makes a plea on behalf of all creatures that we learn more about our biosphere -- and build a networked encyclopedia of all the world's knowledge about life."),
#  (65, 'My wish: Let my photographs bear witness', "Accepting his 2007 TED Prize, war photographer James Nachtwey shows his life's work and asks TED to help him continue telling the story with innovative, exciting uses of news photography in the digital era."),
#  (66, 'What separates us from chimpanzees?', "Jane Goodall hasn't found the missing link, but she's come closer than nearly anyone else. The primatologist says the only real difference between humans and chimps is our sophisticated language. She urges us to start using it to change the world."),
#  (67, 'How to get your ideas to spread', 'In a world of too many options and too little time, our obvious choice is to just ignore the ordinary stuff. Marketing guru Seth Godin spells out why, when it comes to getting our attention, bad or bizarre ideas are more successful than boring ones.'),
#  (68, 'How we discovered DNA', 'Nobel laureate James Watson opens TED2005 with the frank and funny story of how he and his research partner, Francis Crick, discovered the structure of DNA.'),
#  (69, 'Visual illusions that show how we (mis)think', 'Al Seckel, a cognitive neuroscientist, explores the perceptual illusions that fool our brains. Loads of eye tricks help him prove that not only are we easily fooled, we kind of like it.'),
#  (70, 'To invent is to give', 'Inventor Dean Kamen lays out his argument for the Segway and offers a peek into his next big ideas (portable energy and water purification for developing countries).'),
#  (71, 'The life code that will reshape the future', 'Scientific discoveries, futurist Juan Enriquez notes, demand a shift in code, and our ability to thrive depends on our mastery of that code. Here, he applies this notion to the field of genomics.'),
#  (72, 'Happiness by design', 'Graphic designer Stefan Sagmeister takes the audience on a whimsical journey through moments of his life that made him happy -- and notes how many of these moments have to do with good design.'),
#  (73, 'The route to a sustainable future', 'Worldchanging.com founder Alex Steffen argues that reducing humanity’s ecological footprint is incredibly vital now, as the western consumer lifestyle spreads to developing countries.'),
#  (74, 'How architecture can connect us', "Architect Thom Mayne has never been one to take the easy option, and this whistle-stop tour of the buildings he's created makes you glad for it. These are big ideas cast in material form."),
#  (75, 'Great cars are great art', "American designer Chris Bangle explains his philosophy that car design is an art form in its own right, with an entertaining -- and ultimately moving -- account of the BMW Group's Deep Blue project, intended to create the SUV of the future."),
#  (76, 'Singing "What I Want"', 'Nora York gives a stunning performance of her song "What I Want," with Jamie Lawrence (keyboards), Steve Tarshis (guitar) and Arthur Kell (bass).'),
#  (77, 'Design is in the details', "Showing a series of inspiring, unusual and playful products, British branding and design guru Paul Bennett explains that design doesn't have to be about grand gestures, but can solve small, universal and overlooked problems."),
#  (78, 'Art with wire, sugar, chocolate and string', 'Vik Muniz makes art from pretty much anything, be it shredded paper, wire, clouds or diamonds. Here he describes the thinking behind his work and takes us on a tour of his incredible images.'),
#  (79, 'A philosophical quest for our biggest problems', 'Oxford philosopher and transhumanist Nick Bostrom examines the future of humankind and asks whether we might alter the fundamental nature of humanity to solve our most intrinsic problems.'),
#  (80, "Biomimicry's surprising lessons from nature's engineers", 'In this inspiring talk about recent developments in biomimicry, Janine Benyus provides heartening examples of ways in which nature is already influencing the products and systems we build.'),
#  (81, "Sampling the ocean's DNA", "Genomics pioneer Craig Venter takes a break from his epic round-the-world expedition to talk about the millions of genes his team has discovered so far in its quest to map the ocean's biodiversity."),
#  (82, 'Software (as) art', "Engineer and artist Golan Levin pushes the boundaries of what's possible with audiovisuals and technology. In an amazing TED display, he shows two programs he wrote to perform his original compositions."),
#  (83, 'The gentle genius of bonobos', "Savage-Rumbaugh's work with bonobo apes, which can understand spoken language and learn tasks by watching, forces the audience to rethink how much of what a species can do is determined by biology -- and how much by cultural exposure."),
#  (84, 'The story of life in photographs', 'In this stunning slideshow, celebrated nature photographer Frans Lanting presents The LIFE Project, a poetic collection of photographs that tell the story of our planet, from its eruptive beginnings to its present diversity. Soundtrack by Philip Glass.'),
#  (85, 'The shrimp with a kick!', 'Biologist Sheila Patek talks about her work measuring the feeding strike of the mantis shrimp, one of the fastest movements in the animal world, using video cameras recording at 20,000 frames per second.'),
#  (86, 'Global warming\'s theme song, "Manhattan in January"', 'A happy song about global warming, from Jill Sobule.'),
#  (87, 'Casting a spell on the cello', 'Caroline Lavelle plays the cello like a sorceress casting a spell, occasionally hiding behind her wild mane of blond hair as she sings of pastoral themes. She performs "Farther than the Sun," backed by Thomas Dolby on keyboards.'),
#  (88, 'The illusion of consciousness', "Philosopher Dan Dennett makes a compelling argument that not only don't we understand our own consciousness, but that half the time our brains are actively fooling us."),
#  (89, 'How to truly listen', 'In this soaring demonstration, deaf percussionist Evelyn Glennie illustrates how listening to music involves much more than simply letting sound waves hit your eardrums.'),
#  (90, 'Cradle to cradle design', 'Green-minded architect and designer William McDonough asks what our buildings and products would look like if designers took into account "all children, all species, for all time."'),
#  (91, "The electricity metaphor for the web's future", 'The dot-com boom and bust is often compared to the Gold Rush. But Amazon.com founder Jeff Bezos says it’s more like the early days of the electric industry.'),
#  (92, 'A mockingbird remix of TED2006', 'Rives recaps the most memorable moments of TED2006 in the free-spirited rhyming verse of a fantastical mockingbird lullaby.'),
#  (93, '"Kiteflyer\'s Hill"', 'Singer/songwriter Eddi Reader performs "Kiteflyer\'s Hill," a tender look back at a lost love. With Thomas Dolby on piano.'),
#  (94, '"What You\'ve Got"', 'Singer/songwriter Eddi Reader performs "What You Do With What You\'ve Got," a meditation on a very TED theme: how to use your gifts and talents to make a difference. With Thomas Dolby on piano.'),
#  (95, 'Why would God create a tsunami?', 'In the days following the tragic South Asian tsunami of 2004, the Rev. Tom Honey pondered the question, "How could a loving God have done this?" Here is his answer.'),
#  (96, 'Militant atheism', 'Richard Dawkins urges all atheists to openly state their position -- and to fight the incursion of the church into politics and science. A fiery, funny, powerful talk.'),
#  (97, 'A comic sendup of TED2006', 'Satirist Tom Rielly delivers a wicked parody of the 2006 TED conference, taking down the $100 laptop, the plight of the polar bear, and people who mention, one too many times, that they work at Harvard. Watch for a special moment between Tom and Al Gore.'),
#  (98, '"La Vie en Rose"', 'Featuring the vocals and mischievous bell-playing of accordionist and singer Rachelle Garniez, the TED House Band -- led by Thomas Dolby on keyboard -- delivers this delightful rendition of the Edith Piaf standard "La Vie en Rose."'),
#  (99, "Technology's long tail", 'Chris Anderson, then the editor of Wired, explores the four key stages of any viable technology: setting the right price, gaining market share, displacing an established technology and, finally, becoming ubiquitous.'),
#  (100, 'Cape Breton fiddling in reel time', 'Violinist Natalie MacMaster and TED Musical Director Thomas Dolby play Dolby\'s original song "Blue Is a River" in this ethereal duet -- with a little dancing.'),
#  (101, 'The genesis of Google', "Google co-founders Larry Page and Sergey Brin offer a peek inside the Google machine, sharing tidbits about international search patterns, the philanthropic Google Foundation, and the company's dedication to innovation and employee happiness."),
#  (102, '"Black Men Ski"', 'What happens when a black man visits Aspen? Singer/songwriter Stew and his band are about to let you know.'),
#  (103, 'The ghastly tragedy of the suburbs', "In James Howard Kunstler's view, public spaces should be inspired centers of civic life and the physical manifestation of the common good. Instead, he argues, what we have in America is a nation of places not worth caring about."),
#  (104, 'Human-centered design', "IDEO's David Kelley says that product design has become much less about the hardware and more about the user experience. He shows video of this new, broader approach, including footage from the Prada store in New York."),
#  (105, 'What squatter cities can teach us', 'Rural villages worldwide are being deserted, as billions of people flock to cities to live in teeming squatter camps and slums. Stewart Brand says this is a good thing. Why? It’ll take you 3 minutes to find out.'),
#  (106, 'How brain science will change computing', 'Treo creator Jeff Hawkins urges us to take a new look at the brain -- to see it not as a fast processor, but as a memory system that stores and plays back experiences to help us predict, intelligently, what will happen next.'),
#  (107, 'Swim with the giant sunfish', 'Marine biologist Tierney Thys asks us to step into the water to visit the world of the Mola mola, or giant ocean sunfish. Basking, eating jellyfish and getting massages, this behemoth offers clues to life in the open sea.'),
#  (108, "How PhotoSynth can connect the world's images", 'Blaise Aguera y Arcas leads a dazzling demo of Photosynth, software that could transform the way we look at digital images. Using still photos culled from the Web, Photosynth builds breathtaking dreamscapes and lets us navigate them.'),
#  (109, 'Salvation (and profit) in greentech', '"I don\'t think we\'re going to make it," John Doerr says in an emotional talk about climate change and investment. To create a world fit for his daughter to live in, he says, we need to invest now in clean, green energy.'),
#  (110, 'Want to help Africa? Do business here', "We know the negative images of Africa -- famine and disease, conflict and corruption. But, says Ngozi Okonjo-Iweala, there's another, less-told story happening in many African nations: one of reform, economic growth and business opportunity."),
#  (111, 'Rethink the desktop with BumpTop', 'Anand Agarawala presents BumpTop, a user interface that takes the usual desktop metaphor to a glorious, 3-D extreme, transforming file navigation into a freewheeling playground of crumpled documents and clipping-covered "walls."'),
#  (112, 'We can be Buddhas', 'In our hyperlinked world, we can know anything, anytime. And this mass enlightenment, says Buddhist scholar Bob Thurman, is our first step toward Buddha nature.'),
#  (113, 'A memorial at Ground Zero', 'In this emotionally charged conversation with journalist Kurt Andersen, designer David Rockwell discusses the process of building a viewing platform at Ground Zero shortly after 9/11.'),
#  (114, "Let's rethink America's military strategy", 'In this bracingly honest talk, international security strategist Thomas Barnett outlines a post-Cold War solution for the foundering U.S. military that is both sensible and breathtaking in its simplicity: Break it in two.'),
#  (115, 'A string quartet plays "Blue Room"', 'The avant-garde string quartet Ethel performs the third movement from Phil Kline\'s four-part suite "The Blue Room and Other Stories." Searching melodic lines show off the deep, emotional musicality of these passionate players.'),
#  (116, "Tour Microsoft's Virtual Earth", "Microsoft's Stephen Lawler gives a whirlwind tour of Virtual Earth, moving up, down and through its hyper-real cityscapes with dazzlingly fluidity, a remarkable feat that requires staggering amounts of data to bring into focus."),
#  (117, 'New insights on poverty', 'Researcher Hans Rosling uses his cool data tools to show how countries are pulling themselves out of poverty. He demos Dollar Street, comparing households of varying income levels worldwide. Then he does something really amazing.'),
#  (118, "I'm going to the moon. Who's with me?", 'Bill Stone, a maverick cave explorer who has plumbed Earth’s deepest abysses, discusses his efforts to mine lunar ice for space fuel and to build an autonomous robot for studying Jupiter’s moon Europa.'),
#  (119, 'Dangerous memes', 'Starting with the simple tale of an ant, philosopher Dan Dennett unleashes a devastating salvo of ideas, making a powerful case for the existence of memes -- concepts that are literally alive.'),
#  (120, 'The potential of regenerative medicine', 'Alan Russell studies regenerative medicine -- a breakthrough way of thinking about disease and injury, using a process that can signal the body to rebuild itself.'),
#  (121, "The Web's secret stories", "Jonathan Harris wants to make sense of the emotional world of the Web. With deep compassion for the human condition, his projects troll the Internet to find out what we're all feeling and looking for."),
#  (122, 'Flip your thinking on AIDS in Africa', 'Emily Oster re-examines the stats on AIDS in Africa from an economic perspective and reaches a stunning conclusion: Everything we know about the spread of HIV on the continent is wrong.'),
#  (123, 'Spore, birth of a game', 'In a friendly, high-speed presentation, Will Wright demos his newest game, Spore, which promises to dazzle users even more than his previous masterpieces.'),
#  (124, 'The  4 a.m. mystery', "Poet Rives does 8 minutes of lyrical origami, folding history into a series of coincidences surrounding that most surreal of hours, 4 o'clock in the morning."),
#  (125, 'Visualizing the wonder of a living cell', 'Medical animator David Bolinsky presents 3 minutes of stunning animation that show the bustling life inside a cell.'),
#  (126, 'How to get (a new) hip', 'When Allison Hunt found out that she needed a new hip -- and that Canada’s national health care system would require her to spend nearly 2 years on a waiting list (and in pain) -- she took matters into her own hands.'),
#  (127, "Africa's cheetahs versus hippos", 'Ghanaian economist George Ayittey unleashes a torrent of controlled anger toward corrupt leaders in Africa -- and calls on the "Cheetah generation" to take back the continent.'),
#  (128, 'Aid versus trade', 'Ngozi Okonjo-Iweala, the former finance minister of Nigeria, sums up four days of intense discussion on aid versus trade on the closing day of TEDGlobal 2007, and shares a personal story explaining her own commitment to this cause.'),
#  (129, 'How I built a windmill', 'When he was just 14 years old, Malawian inventor William Kamkwamba built his family an electricity-generating windmill from spare parts, working from rough plans he found in a library book.'),
#  (130, 'Why invest in Africa', 'South African investment banker Euvin Naidoo explains why investing in Africa can make great business sense.'),
#  (131, 'How to educate leaders? Liberal arts', 'A liberal arts education is critical to forming true leaders, says university head Patrick Awuah -- because it builds decision-making skills, an ethi ... (78 characters truncated) ... the US to found a liberal arts school in Africa: Ashesi University, in his home nation of Ghana. A passionate talk about dreaming, doing and leading.'),
#  (132, 'Telling stories from Africa', 'In this deeply personal talk, Nigerian writer Chris Abani says that "what we know about how to be who we are" comes from stories. He searches for the heart of Africa through its poems and narrative, including his own.'),
#  (133, 'Patient capitalism', 'Jacqueline Novogratz shares stories of how "patient capital" can bring sustainable jobs, goods, services -- and dignity -- to the world\'s poorest.'),
#  (134, '"Thula Mama"', 'South African singer-songwriter Vusi Mahlasela dedicates his song, "Thula Mama," to all women -- and especially his grandmother.'),
#  (135, '"Woza"', 'After Vusi Mahlasela\'s 3-song set at TEDGlobal, the audience wouldn\'t let him go. His encore, "Woza," showcases his brilliant guitar playing and multilingual lyrics.'),
#  (136, 'My journey into movies that matter', "Film producer Jeff Skoll (An Inconvenient Truth) talks about his film company, Participant Productions, and the people who've inspired him to do good."),
#  (137, 'Luke, a new prosthetic arm for soldiers', 'Inventor Dean Kamen previews the prosthetic arm he’s developing at the request of the US Department of Defense. His quiet commitment to using technology to solve problems -- while honoring the human spirit -- has never been more clear.'),
#  (138, 'The joy of lexicography', "Is the beloved paper dictionary doomed to extinction? In this infectiously exuberant talk, leading lexicographer Erin McKean looks at the many ways today's print dictionary is poised for transformation."),
#  (139, 'Aid for Africa? No thanks.', 'In this provocative talk, journalist Andrew Mwenda asks us to reframe the "African question" -- to look beyond the media\'s stories of poverty, civil war and helplessness and see the opportunities for creating wealth and happiness throughout the continent.'),
#  (140, 'My creations, a new form of life', 'Artist Theo Jansen demonstrates the amazingly lifelike kinetic sculptures he builds from plastic tubes and lemonade bottles. His creatures are designed to move -- and even survive -- on their own.'),
#  (141, 'What our language habits reveal', 'In an exclusive preview of his book <i>The Stuff of Thought</i>, Steven Pinker looks at language and how it expresses what goes on in our minds -- and how the words we choose communicate much more than we realize.'),
#  (142, 'The surprising decline in violence', "Steven Pinker charts the decline of violence from Biblical times to the present, and argues that, though it may seem illogical and even obscene, given Iraq and Darfur, we are living in the most peaceful time in our species' existence."),
#  (143, 'An Iraq war movie crowd-sourced from soldiers', 'Filmmaker Deborah Scranton talks about and shows clips from her documentary The War Tapes, which puts cameras in the hands of soldiers fighting in Iraq.'),
#  (144, "The search for humanity's roots", "Paleoanthropologist Zeresenay Alemseged looks for the roots of humanity in Ethiopia's badlands. Here he talks about finding the oldest skeleton of a humanoid child -- and how Africa holds the clues to our humanity."),
#  (145, 'Designing for simplicity', "The MIT Media Lab's John Maeda lives at the intersection of technology and art, a place that can get very complicated. Here he talks about paring down to basics."),
#  (146, '10 ways the world could end', 'How might the human race end? Stephen Petranek lays out 10 terrible options and the science behind them. Will we be wiped out by an asteroid? Eco-collapse? How about a particle collider gone wild?'),
#  (147, 'A flight on solar wings', 'Paul MacCready -- aircraft designer, environmentalist, and lifelong lover of flight -- talks about his long career.'),
#  (148, 'This is Saturn', 'Planetary scientist Carolyn Porco shows images from the Cassini voyage to Saturn, focusing on its largest moon, Titan, and on frozen Enceladus, which seems to shoot jets of ice.'),
#  (149, 'My magic moves', 'Kenichi Ebina moves his body in a manner that appears to defy the limits imposed by the human skeleton. He combines breakdancing and hip-hop with mime using movements that are simultaneously precise and fluid.'),
#  (150, 'Life at 30,000 feet', "Richard Branson talks to TED's Chris Anderson about the ups and the downs of his career, from his multibillionaire success to his multiple near-death experiences -- and reveals some of his (very surprising) motivations."),
#  (151, 'Building "self-aware" robots', 'Hod Lipson demonstrates a few of his cool little robots, which have the ability to learn, understand themselves and even self-replicate.'),
#  (152, 'The illustrated woman', 'Author and illustrator Maira Kalman talks about her life and work, from her covers for The New Yorker to her books for children and grown-ups. She is as wonderful, as wise and as deliciously off-kilter in person as she is on paper.'),
#  (153, 'The anthropology of mobile phones', "Nokia researcher Jan Chipchase's investigation into the ways we interact with technology has led him from the villages of Uganda to the insides of our pockets. He's made some unexpected discoveries along the way."),
#  (154, '3 clues to understanding your brain', 'Vilayanur Ramachandran tells us what brain damage can reveal about the connection between celebral tissue and the mind, using three startling delusions as examples.'),
#  (155, 'A commodities exchange for Ethiopia', "Economist Eleni Gabre-Madhin outlines her ambitious vision to found the first commodities market in Ethiopia. Her plan would create wealth, minimize risk for farmers and turn the world's largest recipient of food aid into a regional food basket."),
#  (156, 'How electroshock therapy changed me', 'Surgeon and author Sherwin Nuland discusses the development of electroshock therapy as a cure for severe, life-threatening depression -- including his own. It’s a moving and heartfelt talk about relief, redemption and second chances.'),
#  (157, 'The habits of happiness', 'What is happiness, and how can we all get some? Biochemist turned Buddhist monk Matthieu Ricard says we can train our minds in habits of well-being, to generate a true sense of serenity and fulfillment.'),
#  (158, 'Laws that choke creativity', 'Lawrence Lessig, the Net’s most celebrated lawyer, cites John Philip Sousa, celestial copyrights and the "ASCAP cartel" in his argument for reviving our creative culture.'),
#  (159, 'Playing with DNA that self-assembles', "Paul Rothemund writes code that causes DNA to arrange itself into a star, a smiley face and more. Sure, it's a stunt, but it's also a demonstration of self-assembly at the smallest of scales -- with vast implications for the future of making things."),
#  (160, 'A critical look at geoengineering against climate change', 'Environmental scientist David Keith proposes a cheap, effective, shocking means to address climate change: What if we injected a huge cloud of ash into the atmosphere to deflect sunlight and heat?'),
#  (161, 'Using biology to rethink the energy challenge', 'Juan Enriquez challenges our definition of bioenergy. Oil, coal, gas and other hydrocarbons are not chemical but biological products, based on plant matter -- and thus, growable. Our whole approach to fuel, he argues, needs to change.'),
#  (162, 'The case for optimism', "We've known about global warming for 50 years and done little about it, says Google.org director Larry Brilliant. In spite of this and other depressing trends, he's optimistic and tells us why. From Skoll World Forum, Oxford, UK, www.skollfoundation.org"),
#  (163, 'The sticky wonder of gecko feet', 'Biologist Robert Full shares slo-mo video of some captivating critters. Take a closer look at the spiny legs that allow cockroaches to scuttle across mesh and the nanobristle-packed feet that let geckos to run straight up walls.'),
#  (164, 'The fractals at the heart of African designs', "'I am a mathematician, and I would like to stand on your roof.' That is how Ron Eglash greeted many African families he met while researching the fractal patterns he'd noticed in villages across the continent."),
#  (165, 'Design and destiny', 'Designer Philippe Starck -- with no pretty slides to show -- spends 18 minutes reaching for the very roots of the question "Why design?" Listen carefully for one perfect mantra for all of us, genius or not.'),
#  (166, 'Beauty, truth and ... physics?', "Armed with a sense of humor and laypeople's terms, Nobel winner Murray Gell-Mann drops some knowledge on TEDsters about particle physics, asking questions like, Are elegant equations more likely to be right than inelegant ones?"),
#  (167, 'Winning the oil endgame', 'In this energizing talk, Amory Lovins lays out his simple plan for weaning the US off oil and revitalizing the economy.'),
#  (168, 'A performance of "Mathemagic"', 'In a lively show, mathemagician Arthur Benjamin races a team of calculators to figure out 3-digit squares, solves another massive mental equation and guesses a few birthdays. How does he do it? He’ll tell you.'),
#  (169, "Why aren't we more compassionate?", 'Daniel Goleman, author of "Emotional Intelligence," asks why we aren\'t more compassionate more of the time.'),
#  (170, 'The lost art of letter-writing', 'Lakshmi Pratury remembers the lost art of letter-writing and shares a series of notes her father wrote to her before he died. Her short but heartfelt talk may inspire you to set pen to paper, too.'),
#  (171, '5 dangerous things you should let your kids do', 'At TED U, Gever Tulley, founder of the Tinkering School, spells out 5 dangerous things you should let your kids do -- and why a little danger is good for both kids and grownups.'),
#  (172, 'Tales of passion', 'Author and activist Isabel Allende discusses women, creativity, the definition of feminism -- and, of course, passion -- in this talk.'),
#  (173, "We're worried about local warming ... in your lap", 'Investor and prankster Yossi Vardi delivers a ballsy lecture on the dangers of blogging. Specifically, for men.'),
#  (174, 'The emergent genius of ant colonies', 'Deborah Gordon studies ant colonies in the Arizona desert to understand their complex social system. She asks: How do these chitinous creatures get d ... (71 characters truncated) ... uage, memory or visible leadership? Her answers could lead to a better understanding of all complex systems, from the brain to the Web. Thanks, ants.'),
#  (175, 'The mystery box', "J.J. Abrams traces his love for the unseen mystery –- a passion that's evident in his films and TV shows, including Lost, Star Trek and the upcoming Star Wars VII -- back to its magical beginnings."),
#  (176, 'Underwater astonishments', "David Gallo shows jaw-dropping footage of amazing sea creatures, including a color-shifting cuttlefish, a perfectly camouflaged octopus, and a Times  ... (46 characters truncated) ... h who live in the blackest depths of the ocean. This short talk celebrates the pioneering work of ocean explorers like Edith Widder and Roger Hanlon."),
#  (177, 'Treat design as art', "Paola Antonelli, design curator at New York's Museum of Modern Art, wants to spread her appreciation of design -- in all shapes and forms -- around the world."),
#  (178, 'A master architect asks, Now what?', 'In a wildly entertaining discussion with Richard Saul Wurman, architect Frank Gehry gives TEDsters his take on the power of failure, his recent buildings, and the all-important "Then what?" factor.'),
#  (179, '"Tembererana"', 'Singer/guitarist Raúl Midón performs "All the Answers" in a world premiere at TED2007, followed by the sprightly "Tembererana."'),
#  (180, 'Rebuilding a neighborhood with beauty, dignity, hope', 'Bill Strickland tells a quiet and astonishing tale of redemption through arts, music, and unlikely partnerships.'),
#  (181, 'The life-long learner', 'Wofford College president Bernie Dunlap tells the story of Sandor Teszler, a Hungarian Holocaust survivor who taught him about passionate living and lifelong learning.'),
#  (182, 'The music wars', 'New York Times tech columnist David Pogue performs a satirical mini-medley about iTunes and the downloading wars, borrowing a few notes from Sonny and Cher and the Village People.'),
#  (183, 'An unusual glimpse at celebrity', 'By making photographs that seem to show our favorite celebs (Diana, Elton John) doing what we really, secretly, want to see them doing, Alison Jackson explores our desire to get personal with celebs. Contains graphic images.'),
#  (184, "TED's nonprofit transition", "Chris Anderson gave this talk in 2002, prior to taking over leadership of TED. Co-founder Richard Saul Wurman was leaving, and TED's future was in the balance. He seeks to persuade TEDsters that what was then a for-profit conference had a secure future as an idea-based nonprofit endeavor."),
#  (185, 'The idea behind Zipcar (and what comes next)', 'Robin Chase founded Zipcar, the world’s biggest car-sharing business. That was one of her smaller ideas. Here she travels much farther, contemplating road-pricing schemes that will shake up our driving habits and a mesh network vast as the Interstate.'),
#  (186, 'A song of the city', "Jaime Lerner reinvented urban space in his native Curitiba, Brazil. Along the way, he changed the way city planners worldwide see what's possible in the metropolitan landscape."),
#  (187, 'An illustrated journey through Rome', 'David Macaulay relives the winding and sometimes surreal journey toward the completion of Rome Antics, his illustrated homage to the historic city.'),
#  (188, "A plant's-eye view", "What if human consciousness isn't the end-all and be-all of Darwinism? What if we are all just pawns in corn's clever strategy game to rule the Earth? Author Michael Pollan asks us to see the world from a plant's-eye view."),
#  (189, 'The new power of collaboration', 'Howard Rheingold talks about the coming world of collaboration, participatory media and collective action -- and how Wikipedia is really an outgrowth of our natural human instinct to work as a group.'),
#  (190, 'The untouchable music of the theremin', 'Virtuoso Pamelia Kurstin performs and discusses her theremin, the not-just-for-sci-fi electronic instrument that is played without being touched. Songs include "Autumn Leaves," "Lush Life" and David Mash’s "Listen, Words Are Gone."'),
#  (191, 'The story of Project Orion', 'Author George Dyson spins the story of Project Orion, a massive, nuclear-powered spacecraft that could have taken us to Saturn in five years. His insider’s perspective and a secret cache of documents bring an Atomic Age dream to life.'),
#  (192, 'Building uniqueness', 'Looking back over his long career, architect Moshe Safdie delves into four of his design projects and explains how he labored to make each one truly unique for its site and its users.'),
#  (193, 'The Jill and Julia Show', 'Two TED favorites, Jill Sobule and Julia Sweeney, team up for a delightful set that mixes witty songwriting with a little bit of social commentary.'),
#  (194, 'Juggle and jest', "Illustrious jugglers the Raspyni Brothers show off their uncanny balance, agility, coordination and willingness to sacrifice (others). Now, if you'll just stand completely still..."),
#  (195, 'A parable for Kenya', 'Joseph Lekuton, a member of parliament in Kenya, starts with the story of his remarkable education, then offers a parable of how Africa can grow. His message of hope has never been more relevant.'),
#  (196, 'Model rocketry', 'Moneyman Steve Jurvetson takes TEDsters inside his awesome hobby -- launching model rockets –- by sharing some gorgeous photos, his infectious glee and just a whiff of danger.'),
#  (197, 'A preview of the WorldWide Telescope', "Educator Roy Gould and researcher Curtis Wong show a sneak preview of Microsoft's WorldWide Telescope, which compiles images from telescopes and satellites to build a comprehensive, interactive view of our universe."),
#  (198, 'A powerful idea about ideas', 'With all the intensity and brilliance for which he is known, Alan Kay envisions better techniques for teaching kids by using computers to illustrate experience in ways -– mathematically and scientifically -- that only computers can.'),
# ...
#  (951, 'Wearing nothing new', "Designer Jessi Arrington packed nothing for TEDActive but 7 pairs of undies, buying the rest of her clothes in thrift stores around LA. It's a meditation on conscious consumption -- wrapped in a rainbow of color and creativity."),
#  (952, 'We need a "moral operating system"', "Damon Horowitz reviews the enormous new powers that technology gives us: to know more -- and more about each other -- than ever before. Drawing the a ... (106 characters truncated) ... -- the ethical principles -- behind the burst of invention remaking our world. Where's the moral operating system that allows us to make sense of it?"),
#  (953, 'Building a dinosaur from a chicken', 'Renowned paleontologist Jack Horner has spent his career trying to reconstruct a dinosaur. He\'s found fossils with extraordinarily well-preserved bl ... (119 characters truncated) ... aur (chickens) and genetically engineering them to reactivate ancestral traits — including teeth, tails, and even hands — to make a "Chickenosaurus".'),
#  (954, 'Taking imagination seriously', 'Janet Echelman found her true voice as an artist when her paints went missing -- which forced her to look to an unorthodox new art material. Now she makes billowing, flowing, building-sized sculpture with a surprisingly geeky edge. A transporting 10 minutes of pure creativity.'),
#  (955, "The world's first charter city?", 'Back in 2009, Paul Romer unveiled the idea for a "charter city" -- a new kind of city with rules that favor democracy and trade. This year, at TED2011, he tells the story of how such a city might just happen in Honduras ... with a little help from his TEDTalk.'),
#  (956, 'Is anatomy destiny?', "Alice Dreger works with people at the edge of anatomy, such as conjoined twins and intersexed people. In her observation, it's often a fuzzy line between male and female, among other anatomical distinctions. Which brings up a huge question: Why do we let our anatomy determine our fate?"),
#  (957, 'Break the silence for suicide attempt survivors', 'Even when our lives appear fine from the outside, locked within can be a world of quiet suffering, leading some to the decision to end their life. At ... (68 characters truncated) ...  and suicide attempts, and to create much-needed resources to help people who reclaim their life after escaping death. Resources: http://t.co/wsNrY9C'),
#  (958, "Medicine's future? There's an app for that", "Daniel Kraft offers a fast-paced look at the next few years of innovations in medicine, powered by new tools, tests and apps that bring diagnostic information right to the patient's bedside."),
#  (959, 'How I became 100 artists', "How do you stage an international art show with work from 100 different artists? If you're Shea Hembrey, you invent all of the artists and artwork yo ... (77 characters truncated) ...  a single-haired brush. Watch this funny, mind-bending talk to see the explosion of creativity and diversity of skills a single artist is capable of."),
#  (960, 'A manifesto for play, for Bulgaria and beyond', 'Steve Keil fights the "serious meme" that has infected his home of Bulgaria -- and calls for a return to play to revitalize the economy, education and society. A sparkling talk with a universal message for people everywhere who are reinventing their workplaces, schools, lives.'),
#  (961, 'Haunting photos of polar ice', 'Photographer Camille Seaman shoots icebergs, showing the world the complex beauty of these massive, ancient chunks of ice. Dive in to her photo slideshow, "The Last Iceberg."'),
#  (962, 'This is beatjazz', 'Musician and inventor Onyx Ashanti demonstrates "beatjazz" -- his music created with two handheld controllers, an iPhone and a mouthpiece, and played ... (19 characters truncated) ... dy. At TED\'s Full Spectrum Auditions, after locking in his beats and loops, he plays a 3-minute song that shares his vision for the future of music.'),
#  (963, 'A cello with many voices', 'Cellist Maya Beiser plays a gorgeous eight-part modern etude with seven copies of herself, and segues into a meditative music/video hybrid -- using t ... (52 characters truncated) ... ve sound. Music is Steve Reich\'s "Cello Counterpoint," with video from Bill Morrison, then David Lang\'s "World to Come," with video by Irit Batsry.'),
#  (964, 'A future beyond traffic gridlock', 'Bill Ford is a car guy -- his great-grandfather was Henry Ford, and he grew up inside the massive Ford Motor Co. So when he worries about cars\' impa ... (69 characters truncated) ...  it\'s worth a listen. His vision for the future of mobility includes "smart roads," even smarter public transport and going green like never before.'),
#  (965, 'Different ways of knowing', 'Daniel Tammet has linguistic, numerical and visual synesthesia -- meaning that his perception of words, numbers and colors are woven together into a  ... (30 characters truncated) ... rstanding the world. The author of "Born on a Blue Day," Tammet shares his art and his passion for languages in this glimpse into his beautiful mind.'),
#  (966, 'A circle of caring', 'Did you ever have a teacher who cared for you when no one else did? Jok Church tells a short, moving story of the teacher who sheltered him as a young gay teen and helped him grow -- and how, many years later, he and his partner had the privilege of returning the favor.'),
#  (967, 'A history of the universe in sound', 'Artist-technologist Honor Harger listens to the weird and wonderful noises of stars and planets and pulsars. In her work, she tracks the radio waves  ... (16 characters truncated) ... nt celestial objects and turns them into sound, including "the oldest song you will ever hear," the sound of cosmic rays left over from the Big Bang.'),
#  (968, 'On being just crazy enough', 'At TED\'s Full Spectrum Auditions, comedian Joshua Walters, who\'s bipolar, walks the line between mental illness and mental "skillness." In this funny, thought-provoking talk, he asks: What\'s the right balance between medicating craziness away and riding the manic edge of creativity and drive?'),
#  (969, 'A civil response to violence', "In this passionate talk that's already caused a sensation in Mexico, Emiliano Salinas, son of former president Carlos Salinas de Gortari, confronts t ... (84 characters truncated) ... to it. He calls on ordinary citizens to move from denial and fear to peaceful, community-based action. (Delivered in Spanish with English subtitles.)"),
#  (970, 'A Rosetta Stone for a lost language', 'Rajesh Rao is fascinated by "the mother of all crossword puzzles": how to decipher the 4000-year-old Indus script. He\'s enlisting modern computation to try to read this lost language, the key to understanding this ancient civilization.'),
#  (971, 'Meet e-Patient Dave', 'When Dave deBronkart learned he had a rare and terminal cancer, he turned to a group of fellow patients online -- and found the medical treatment tha ... (4 characters truncated) ... ved his life. Now he calls on all patients to talk with one another, know their own health data, and make health care better one e-Patient at a time.'),
#  (972, 'Building a park in the sky', 'New York was planning to tear down the High Line, an abandoned elevated railroad in Manhattan, when Robert Hammond and a few friends suggested: Why not make it a park? He shares how it happened in this tale of local cultural activism.'),
#  (973, 'Try something new for 30 days', "Is there something you've always meant to do, wanted to do, but just ... haven't? Matt Cutts suggests: Try it for 30 days. This short, lighthearted talk offers a neat way to think about setting and achieving goals."),
#  (974, 'Cooking as never seen before', 'Cookbook author (and geek) Nathan Myhrvold talks about his magisterial work, "Modernist Cuisine" -- and shares the secret of its cool photographic illustrations, which show cross-sections of food in the very act of being cooked.'),
#  (975, 'The beautiful tricks of flowers', "In this visually dazzling talk, Jonathan Drori shows the extraordinary ways flowering plants -- over a quarter million species -- have evolved to att ... (29 characters truncated) ... pollen: growing 'landing-strips' to guide the insects in, shining in ultraviolet, building elaborate traps, and even mimicking other insects in heat."),
#  (976, "Don't take consciousness for granted", 'After a catastrophic car accident that left him in a coma, Simon Lewis found ways to recover -- physically and mentally -- beyond all expectations. At the INK Conference he tells how this remarkable story led him to concern over all threats to consciousness, and how to overcome them.'),
#  (977, 'Caring for engineered tissue', "Tissue engineer and TED Fellow Nina Tandon is growing artificial hearts and bones. To do that, she needs new ways of caring for artificially grown cells -- techniques she's developed by the simple but powerful method of copying their natural environments."),
#  (978, "Let's take back the Internet!", 'In this powerful talk from TEDGlobal, Rebecca MacKinnon describes the expanding struggle for freedom and control in cyberspace, and asks: How do we d ... (128 characters truncated) ...  is headed for a "Magna Carta" moment when citizens around the world demand that their governments protect free speech and their right to connection.'),
#  (979, 'A global culture to fight extremism', 'Why do transnational extremist organizations succeed where democratic movements have a harder time taking hold? Maajid Nawaz, a former Islamist extremist, asks for new grassroots stories and global social activism to spread democracy in the face of nationalism and xenophobia.'),
#  (980, 'Trial, error and the God complex', 'Economics writer Tim Harford studies complex systems -- and finds a surprising link among the successful ones: they were built through trial and error. In this sparkling talk from TEDGlobal 2011, he asks us to embrace our randomness and start making better mistakes.'),
#  (981, 'See Yemen through my eyes', "As political turmoil in Yemen continues, the editor of the Yemen Times, Nadia Al-Sakkaf, talks at TEDGlobal with host Pat Mitchell. Al-Sakkaf's indep ... (14 characters truncated) ... h-language paper is vital for sharing news -- and for sharing a new vision of Yemen and of that country's women as equal partners in work and change."),
#  (982, 'Fighting viruses, defending the net', "It's been 25 years since the first PC virus (Brain A) hit the net, and what was once an annoyance has become a sophisticated tool for crime and espionage. Computer security expert Mikko Hyppönen tells us how we can stop these new viruses from threatening the internet as we know it."),
#  (983, 'Embracing otherness, embracing myself', 'Actor Thandie Newton tells the story of finding her "otherness" -- first, as a child growing up in two distinct cultures, and then as an actor playing with many different selves. A warm, wise talk, fresh from stage at TEDGlobal 2011.'),
#  (984, 'How algorithms shape our world', 'We live in a world run by algorithms, computer programs that make decisions or solve problems for us. In this riveting, funny talk, Kevin Slavin show ... (60 characters truncated) ... ctics, even the movies you watch. But, he asks: If we depend on complex algorithms to manage our daily decisions -- when do we start to lose control?'),
#  (985, 'A robot that flies like a bird', 'Plenty of robots can fly -- but none can fly like a real bird. That is, until Markus Fischer and his team at Festo built SmartBird, a large, lightweight robot, modeled on a seagull, that flies by flapping its wings. A soaring demo fresh from TEDGlobal 2011.'),
#  (986, 'Time to end the war in Afghanistan', 'British MP Rory Stewart walked across Afghanistan after 9/11, talking with citizens and warlords alike. Now, a decade later, he asks: Why are Western ... (53 characters truncated) ...  lessons from past military interventions that worked -- Bosnia, for instance -- and shows that humility and local expertise are the keys to success.'),
#  (987, 'The surprising math of cities and corporations', "Physicist Geoffrey West has found that simple, mathematical laws govern the properties of cities -- that wealth, crime rate, walking speed and many o ... (54 characters truncated) ... mber: the city's population. In this mind-bending talk from TEDGlobal he shows how it works and how similar laws hold for organisms and corporations."),
#  (988, 'The origins of pleasure', 'Why do we like an original painting better than a forgery? Psychologist Paul Bloom argues that human beings are essentialists -- that our beliefs about the history of an object change how we experience it, not simply as an illusion, but as a deep feature of what pleasure (and pain) is.'),
#  (989, 'Ending hunger now', 'Josette Sheeran, the head of the UN\'s World Food Program, talks about why, in a world with enough food for everyone, people still go hungry, still d ... (2 characters truncated) ...  of starvation, still use food as a weapon of war. Her vision: "Food is one issue that cannot be solved person by person. We have to stand together."'),
#  (990, '5 ways to listen better', 'In our louder and louder world, says sound expert Julian Treasure, "We are losing our listening." In this short, fascinating talk, Treasure shares five ways to re-tune your ears for conscious listening -- to other people and the world around you.'),
#  (991, 'After your final status update', "Many of us have a social media presence -- a virtual personality made up of status updates, tweets and connections, stored in the cloud. Adam Ostrow asks a big question: What happens to that personality after you've died? Could it ... live on?"),
#  (992, 'Wireless data from every light bulb', "What if every light bulb in the world could also transmit data? At TEDGlobal, Harald Haas demonstrates, for the first time, a device that could do ex ... (73 characters truncated) ...  for the human eye to detect, he can transmit far more data than a cellular tower -- and do it in a way that's more efficient, secure and widespread."),
#  (993, 'How language transformed humanity', 'Biologist Mark Pagel shares an intriguing theory about why humans evolved our complex system of language. He suggests that language is a piece of "social technology" that allowed early human tribes to access a powerful new tool: cooperation.'),
#  (994, 'Are we filtering the wrong microbes?', 'Should we keep the outdoors out of hospitals? Ecologist and TED Fellow Jessica Green has found that mechanical ventilation does get rid of many types of microbes, but the wrong kinds: the ones left in the hospital are much more likely to be pathogens.'),
#  (995, 'The demise of guys?', 'Psychologist Philip Zimbardo asks, "Why are boys struggling?" He shares some stats (lower graduation rates, greater worries about intimacy and relati ... (37 characters truncated) ... - and challenges the TED community to think about solutions. NOTE: Statements in this talk have been challenged by scientists working in this field. '),
#  (996, 'Suddenly, my body', 'Poet, writer, activist Eve Ensler lived in her head. In this powerful talk from TEDWomen, she talks about her lifelong disconnection from her body -- and how two shocking events helped her to connect with the reality, the physicality of being human.'),
#  (997, 'The shareable future of cities', 'How can cities help save the future? Alex Steffen shows some cool neighborhood-based green projects that expand our access to things we want and need -- while reducing the time we spend in cars.'),
#  (998, 'The great penguin rescue', "The world's largest volunteer animal rescue, saved more than 40,000 penguins after an oil spill off the coast of South Africa. Dyan deNapoli tells the triumphant story. How does a job this big get done? Penguin by penguin by penguin ..."),
#  ...]

# %%
stmt = ''' SELECT * FROM ratings; '''

connection.execute(stmt).fetchall()
# Out:
# [(7, 'Funny'),
#  (1, 'Beautiful'),
#  (9, 'Ingenious'),
#  (3, 'Courageous'),
#  (11, 'Longwinded'),
#  (2, 'Confusing'),
#  (8, 'Informative'),
#  (22, 'Fascinating'),
#  (21, 'Unconvincing'),
#  (24, 'Persuasive'),
#  (23, 'Jaw-dropping'),
#  (25, 'OK'),
#  (26, 'Obnoxious'),
#  (10, 'Inspiring')]

# %%
stmt = ''' SELECT * FROM related_videos; '''

connection.execute(stmt).fetchall()
# Out:
# [(0, 865),
#  (0, 1738),
#  (0, 2276),
#  (0, 892),
#  (0, 1232),
#  (0, 2616),
#  (1, 243),
#  (1, 547),
#  (1, 2093),
#  (1, 2784),
#  (1, 2339),
#  (1, 2331),
#  (2, 1725),
#  (2, 2274),
#  (2, 172),
#  (2, 2664),
#  (2, 436),
#  (2, 1546),
#  (3, 1041),
#  (3, 1892),
#  (3, 2078),
#  (3, 2873),
#  (3, 2840),
#  (3, 2839),
#  (4, 2056),
#  (4, 2296),
#  (4, 620),
#  (4, 974),
#  (4, 140),
#  (4, 912),
#  (5, 229),
#  (5, 70),
#  (5, 97),
#  (5, 1094),
#  (5, 2861),
#  (5, 2279),
#  (6, 22),
#  (6, 94),
#  (6, 856),
#  (6, 112),
#  (6, 71),
#  (6, 308),
#  (7, 750),
#  (7, 2092),
#  (7, 2183),
#  (7, 359),
#  (7, 231),
#  (7, 31),
#  (8, 71),
#  (8, 2011),
#  (8, 234),
#  (8, 113),
#  (8, 301),
#  (8, 1327),
#  (9, 94),
#  (9, 676),
#  (9, 2011),
#  (9, 301),
#  (9, 86),
#  (9, 308),
#  (10, 1749),
#  (10, 2183),
#  (10, 31),
#  (10, 646),
#  (10, 2532),
#  (10, 266),
#  (11, 2228),
#  (11, 1476),
#  (11, 800),
#  (11, 403),
#  (11, 170),
#  (11, 282),
#  (12, 1153),
#  (12, 869),
#  (12, 1905),
#  (12, 529),
#  (12, 177),
#  (12, 2185),
#  (13, 685),
#  (13, 872),
#  (13, 1984),
#  (13, 2410),
#  (13, 260),
#  (13, 230),
#  (14, 2043),
#  (14, 255),
#  (14, 1678),
#  (14, 288),
#  (14, 423),
#  (14, 230),
#  (15, 2273),
#  (15, 2242),
#  (15, 1156),
#  (15, 805),
#  (15, 1440),
#  (15, 2033),
#  (16, 2273),
#  (16, 2100),
#  (16, 1298),
#  (16, 1526),
#  (16, 883),
#  (16, 246),
#  (17, 1561),
#  (17, 1072),
#  (17, 1184),
#  (17, 1020),
#  (17, 1041),
#  (17, 85),
#  (18, 2251),
#  (18, 174),
#  (18, 614),
#  (18, 5),
#  (18, 431),
#  (18, 207),
#  (19, 640),
#  (19, 362),
#  (19, 1295),
#  (19, 247),
#  (19, 783),
#  (19, 1091),
#  (20, 1913),
#  (20, 1531),
#  (20, 1570),
#  (20, 346),
#  (20, 2382),
#  (20, 2180),
#  (21, 148),
#  (21, 981),
#  (21, 2049),
#  (21, 2792),
#  (21, 1152),
#  (21, 2838),
#  (22, 144),
#  (22, 1282),
#  (22, 1379),
#  (22, 118),
#  (22, 641),
#  (22, 1416),
#  (23, 307),
#  (23, 374),
#  (23, 1669),
#  (23, 2590),
#  (23, 2661),
#  (23, 2330),
#  (24, 217),
#  (24, 751),
#  (24, 1753),
#  (24, 1205),
#  (24, 2175),
#  (24, 842),
#  (25, 2237),
#  (25, 701),
#  (25, 1095),
#  (25, 42),
#  (25, 1426),
#  (25, 242),
#  (26, 1276),
#  (26, 1160),
#  (26, 516),
#  (26, 2862),
#  (26, 42),
#  (26, 394),
#  (27, 20),
#  (27, 2247),
#  (27, 1897),
#  (27, 1859),
#  (27, 2261),
#  (27, 2299),
#  (28, 93),
#  (28, 28),
#  (28, 1831),
#  (28, 263),
#  (28, 1306),
#  (28, 765),
#  (29, 944),
#  (29, 1880),
#  (29, 2162),
#  (29, 1607),
#  (29, 570),
#  (29, 779),
#  (30, 2023),
#  (30, 924),
#  (30, 2044),
#  (30, 1330),
#  (30, 2799),
#  (30, 420),
#  (31, 2109),
#  (31, 859),
#  (31, 1498),
#  (31, 1229),
#  (31, 2599),
#  (31, 1343),
#  (32, 252),
#  (32, 142),
#  (32, 12),
#  (32, 2315),
#  (32, 44),
#  (32, 515),
#  (33, 270),
#  (33, 157),
#  (33, 288),
#  (33, 1599),
#  (33, 2105),
#  (33, 2114),
#  (34, 2213),
#  (34, 154),
#  (34, 127),
#  (34, 157),
#  (34, 847),
#  (34, 644),
#  (35, 91),
#  (35, 170),
#  (35, 23),
#  (35, 1066),
#  (35, 983),
#  (35, 2835),
#  (36, 127),
#  (36, 1929),
#  (36, 584),
#  (36, 1196),
#  (36, 270),
#  (36, 2806),
#  (37, 141),
#  (37, 264),
#  (37, 335),
#  (37, 1260),
#  (37, 1402),
#  (37, 176),
#  (38, 2292),
#  (38, 627),
#  (38, 2255),
#  (38, 2143),
#  (38, 1631),
#  (38, 2165),
#  (39, 156),
#  (39, 157),
#  (39, 127),
#  (39, 330),
#  (39, 154),
#  (39, 2560),
#  (40, 279),
#  (40, 84),
#  (40, 40),
#  (40, 1236),
#  (40, 1554),
#  (40, 634),
#  (41, 82),
#  (41, 142),
#  (41, 280),
#  (41, 1717),
#  (41, 1297),
#  (41, 2555),
#  (42, 92),
#  (42, 22),
#  (42, 143),
#  (42, 571),
#  (42, 2004),
#  (42, 2835),
#  (43, 666),
#  (43, 2178),
#  (43, 333),
#  (43, 426),
#  (43, 2032),
#  (43, 1827),
#  (44, 19),
#  (44, 129),
#  (44, 351),
#  (44, 560),
#  (44, 2858),
#  (44, 1346),
#  (45, 319),
#  (45, 38),
#  (45, 190),
#  (45, 770),
#  (45, 1131),
#  (45, 72),
#  (46, 75),
#  (46, 170),
#  (46, 84),
#  (46, 171),
#  (46, 2142),
#  (46, 386),
#  (47, 66),
#  (47, 202),
#  (47, 93),
#  (47, 572),
#  (47, 2638),
#  (47, 2182),
#  (48, 148),
#  (48, 383),
#  (48, 981),
#  (48, 1693),
#  (48, 640),
#  (48, 1436),
#  (49, 263),
#  (49, 348),
#  (49, 248),
#  (49, 377),
#  (49, 727),
#  (49, 1900),
#  (50, 643),
#  (50, 1846),
#  (50, 2128),
#  (50, 2873),
#  (50, 53),
#  (50, 2840),
#  (51, 248),
#  (51, 92),
#  (51, 143),
#  (51, 85),
#  (51, 2480),
#  (51, 2806),
#  (52, 273),
#  (52, 40),
#  (52, 34),
#  (52, 2141),
#  (52, 2551),
#  (52, 2088),
#  (53, 2264),
#  (53, 2141),
#  (53, 1789),
#  (53, 651),
#  (53, 2152),
#  (53, 538),
#  (54, 167),
#  (54, 68),
#  (54, 365),
#  (54, 47),
#  (54, 468),
#  (54, 876),
#  (55, 163),
#  (55, 42),
#  (55, 341),
#  (55, 801),
#  (55, 2669),
#  (55, 1463),
#  (56, 58),
#  (56, 29),
#  (56, 20),
#  (56, 1582),
#  (56, 655),
#  (56, 2591),
#  (57, 216),
#  (57, 247),
#  (57, 274),
#  (57, 1492),
#  (57, 2470),
#  (57, 661),
#  (58, 40),
#  (58, 188),
#  (58, 60),
#  (59, 86),
#  (59, 26),
#  (59, 374),
#  (59, 2801),
#  (59, 2887),
#  (59, 2769),
#  (60, 90),
#  (60, 2),
#  (60, 266),
#  (60, 1215),
#  (60, 1707),
#  (60, 843),
#  (61, 2),
#  (61, 48),
#  (61, 288),
#  (61, 2664),
#  (61, 1570),
#  (61, 872),
#  (62, 93),
#  (62, 263),
#  (62, 201),
#  (62, 2025),
#  (62, 2815),
#  (62, 1069),
#  (63, 59),
#  (63, 127),
#  (63, 268),
#  (63, 2806),
#  (63, 249),
#  (63, 2789),
#  (64, 340),
#  (64, 40),
#  (64, 299),
#  (64, 2833),
#  (64, 1131),
#  (64, 509),
#  (65, 56),
#  (65, 69),
#  (65, 279),
#  (65, 1651),
#  (65, 395),
#  (65, 1003),
#  (66, 76),
#  (66, 145),
#  (66, 77),
#  (66, 340),
#  (66, 2307),
#  (66, 1417),
#  (67, 20),
#  (67, 72),
#  (67, 266),
#  (67, 2274),
#  (67, 848),
#  (67, 353),
#  (68, 83),
#  (68, 194),
#  (68, 147),
#  (68, 1322),
#  (68, 2570),
#  (68, 2354),
#  (69, 32),
#  (69, 22),
#  (69, 310),
#  (69, 1334),
#  (69, 1607),
#  (69, 97),
#  (70, 2),
#  (70, 54),
#  (70, 90),
#  (70, 1559),
#  (70, 2839),
#  (70, 1174),
#  (71, 227),
#  (71, 35),
#  (71, 331),
#  (71, 6),
#  (71, 1274),
#  (71, 863),
#  (72, 356),
#  (72, 182),
#  (72, 172),
#  (72, 97),
#  (72, 1607),
#  (72, 570),
#  (73, 104),
#  (73, 18),
#  (73, 266),
#  (73, 2855),
#  (73, 174),
#  (73, 439),
#  (74, 27),
#  (74, 359),
#  (74, 54),
#  (74, 2375),
#  (74, 2797),
#  (74, 589),
#  (75, 4),
#  (75, 266),
#  (75, 27),
#  (75, 1506),
#  (75, 1724),
#  (75, 2443),
#  (76, 158),
#  (76, 110),
#  (76, 117),
#  (76, 241),
#  (76, 298),
#  (76, 2770),
#  (77, 392),
#  (77, 266),
#  (77, 172),
#  (77, 646),
#  (77, 2810),
#  (77, 122),
#  (78, 162),
#  (78, 267),
#  (78, 78),
#  (78, 210),
#  (78, 488),
#  (78, 2264),
#  (79, 42),
#  (79, 19),
#  (79, 68),
#  (79, 2858),
#  (79, 39),
#  (79, 515),
#  (80, 280),
#  (80, 198),
#  (80, 258),
#  (80, 614),
#  (80, 1072),
#  (80, 1561),
#  (81, 227),
#  (81, 323),
#  (81, 331),
#  (81, 437),
#  (81, 863),
#  (81, 1223),
#  (82, 144),
#  (82, 241),
#  (82, 32),
#  (82, 427),
#  (82, 1571),
#  (82, 606),
#  (83, 340),
#  (83, 77),
#  (83, 145),
#  (83, 1102),
#  (83, 2539),
#  (83, 11),
#  (84, 69),
#  (84, 324),
#  (84, 147),
#  (84, 573),
#  (84, 2088),
#  (84, 2471),
#  (85, 126),
#  (85, 76),
#  (85, 145),
#  (85, 280),
#  (85, 1959),
#  (85, 2014),
#  (86, 222),
#  (86, 119),
#  (86, 1),
#  (86, 1073),
#  (86, 688),
#  (86, 1797),
#  (87, 117),
#  (87, 109),
#  (87, 218),
#  (87, 849),
#  (87, 1001),
#  (87, 2849),
#  (88, 116),
#  (88, 125),
#  (88, 229),
#  (88, 1794),
#  (88, 2045),
#  (88, 2817),
#  (89, 286),
#  (89, 246),
#  (89, 218),
#  (89, 2033),
#  (89, 883),
#  (89, 1526),
#  (90, 74),
#  (90, 359),
#  (90, 174),
#  (90, 2855),
#  (90, 2128),
#  (90, 1072),
#  (91, 319),
#  (91, 118),
#  (91, 362),
#  (91, 619),
#  (91, 566),
#  (91, 1695),
#  (92, 148),
#  (92, 2281),
#  (92, 2049),
#  (92, 981),
#  (92, 413),
#  (92, 114),
#  (93, 109),
#  (93, 101),
#  (93, 117),
#  (93, 2345),
#  (93, 2801),
#  (93, 849),
#  (94, 110),
#  (94, 81),
#  (94, 186),
#  (94, 1959),
#  (94, 1121),
#  (94, 482),
#  (95, 234),
#  (95, 308),
#  (95, 71),
#  (95, 86),
#  (95, 673),
#  (95, 676),
#  (96, 86),
#  (96, 94),
#  (96, 22),
#  (96, 2011),
#  (96, 1327),
#  (96, 2643),
#  (97, 108),
#  (97, 87),
#  (97, 99),
#  (97, 22),
#  (97, 426),
#  (97, 2855),
#  (98, 108),
#  (98, 87),
#  (98, 99),
#  (98, 2256),
#  (98, 110),
#  (98, 1605),
#  (99, 319),
#  (99, 118),
#  (99, 216),
#  (99, 770),
#  (99, 19),
#  (99, 1574),
#  (100, 45),
#  (100, 296),
#  (100, 138),
#  (100, 2424),
#  (100, 2814),
#  (100, 2064),
#  (101, 319),
#  (101, 1109),
#  (101, 1113),
#  (101, 2369),
#  (101, 362),
#  (101, 1091),
#  (102, 158),
#  (102, 99),
#  (102, 254),
#  (102, 2151),
#  (102, 2691),
#  (102, 2634),
#  (103, 123),
#  (103, 36),
#  (103, 33),
#  (103, 2797),
#  (103, 2092),
#  (103, 1854),
#  (104, 266),
#  (104, 43),
#  (104, 172),
#  (104, 646),
#  (104, 372),
#  (104, 2039),
#  (105, 36),
#  (105, 121),
#  (105, 213),
#  (105, 1865),
#  (105, 1429),
#  (105, 1892),
#  (106, 184),
#  (106, 236),
#  (106, 320),
#  (106, 2798),
#  (106, 2015),
#  (106, 2495),
#  (107, 206),
#  (107, 77),
#  (107, 145),
#  (107, 973),
#  (107, 1373),
#  (107, 2389),
#  (108, 147),
#  (108, 245),
#  (108, 131),
#  (108, 139),
#  (108, 826),
#  (108, 766),
#  (109, 192),
#  (109, 243),
#  (109, 91),
#  (109, 2784),
#  (109, 1),
#  (109, 2339),
#  (110, 185),
#  (110, 270),
#  (110, 91),
#  (110, 2560),
#  (110, 154),
#  (110, 151),
#  (111, 129),
#  (111, 245),
#  (111, 224),
#  (111, 65),
#  (111, 685),
#  (111, 872),
#  (112, 234),
#  (112, 191),
#  (112, 208),
#  (112, 677),
#  (112, 1074),
#  (112, 1216),
#  (113, 49),
#  (113, 359),
#  (113, 31),
#  (113, 2797),
#  (113, 1182),
#  (113, 121),
#  (114, 121),
#  (114, 167),
#  (114, 39),
#  (114, 1999),
#  (114, 2515),
#  (114, 2008),
#  (115, 103),
#  (115, 117),
#  (115, 218),
#  (116, 245),
#  (116, 129),
#  (116, 131),
#  (116, 766),
#  (116, 410),
#  (116, 1581),
#  (117, 494),
#  (117, 270),
#  (117, 157),
#  (117, 620),
#  (117, 92),
#  (117, 974),
#  (118, 499),
#  (118, 89),
#  (118, 4),
#  (118, 264),
#  (118, 335),
#  (118, 2853),
#  (119, 69),
#  (119, 269),
#  (119, 358),
#  (119, 1995),
#  (119, 145),
#  (119, 390),
#  (120, 1103),
#  (120, 1274),
#  (120, 2342),
#  (120, 744),
#  (120, 1845),
#  (120, 2343),
#  (121, 316),
#  (121, 32),
#  (121, 14),
#  (121, 900),
#  (121, 1118),
#  (121, 843),
#  (122, 92),
#  (122, 67),
#  (122, 29),
#  (122, 540),
#  (122, 836),
#  (122, 818),
#  (123, 361),
#  (123, 162),
#  (123, 144),
#  (123, 996),
#  (123, 936),
#  (123, 1432),
#  (124, 374),
#  (124, 87),
#  (124, 22),
#  (124, 2000),
#  (124, 2792),
#  (124, 1508),
#  (125, 331),
#  (125, 35),
#  (125, 40),
#  (125, 1187),
#  (125, 2052),
#  (125, 1882),
#  (126, 204),
#  (126, 201),
#  (126, 21),
#  (126, 1652),
#  (126, 2046),
#  (126, 1421),
#  (127, 152),
#  (127, 157),
#  (127, 159),
#  (127, 154),
#  (127, 2462),
#  (127, 2560),
#  (128, 91),
#  (128, 159),
#  (128, 270),
#  (128, 2560),
#  (128, 127),
#  (128, 2213),
#  (129, 156),
#  (129, 299),
#  (129, 2),
#  (129, 642),
#  (129, 1134),
#  (129, 2180),
#  (130, 127),
#  (130, 185),
#  (130, 156),
#  (130, 151),
#  (130, 2560),
#  (130, 2462),
#  (131, 153),
#  (131, 66),
#  (131, 558),
#  (131, 2113),
#  (131, 1930),
#  (131, 151),
#  (132, 386),
#  (132, 330),
#  (132, 204),
#  (132, 652),
#  (132, 59),
#  (132, 2462),
#  (133, 270),
#  (133, 127),
#  (133, 75),
#  (133, 91),
#  (133, 644),
#  (133, 2213),
#  (134, 169),
#  (134, 119),
#  (134, 186),
#  (134, 1912),
#  (134, 2538),
#  (134, 2345),
#  (135, 158),
#  (135, 188),
#  (135, 265),
#  (136, 205),
#  (136, 171),
#  (136, 56),
#  (136, 403),
#  (136, 55),
#  (136, 2694),
#  (137, 142),
#  (137, 195),
#  (137, 171),
#  (137, 819),
#  (137, 1251),
#  (137, 1148),
#  (138, 69),
#  (138, 194),
#  (138, 148),
#  (138, 2022),
#  (138, 2158),
#  (138, 2709),
#  (139, 152),
#  (139, 157),
#  (139, 151),
#  (139, 2560),
#  (139, 1929),
#  (139, 127),
#  (140, 267),
#  (140, 32),
#  (140, 1164),
#  (140, 345),
#  (140, 343),
#  (140, 830),
#  (141, 163),
#  (141, 276),
#  (141, 69),
#  (141, 2595),
#  (141, 1670),
#  (141, 2028),
#  (142, 68),
#  (142, 29),
#  (142, 140),
#  (142, 1948),
#  (142, 1342),
#  (142, 2779),
#  (143, 386),
#  (143, 84),
#  (143, 170),
#  (143, 1999),
#  (143, 2008),
#  (143, 2374),
#  (144, 323),
#  (144, 315),
#  (144, 69),
#  (144, 340),
#  (144, 11),
#  (144, 607),
#  (145, 2),
#  (145, 845),
#  (145, 7),
#  (145, 427),
#  (145, 1571),
#  (145, 2043),
#  (146, 163),
#  (146, 68),
#  (146, 42),
#  (146, 1280),
#  (146, 2491),
#  (146, 2230),
#  (147, 4),
#  (147, 5),
#  (147, 264),
#  (147, 379),
#  (147, 492),
#  (147, 1402),
#  (148, 141),
#  (148, 4),
#  (148, 264),
#  (148, 551),
#  (148, 2550),
#  (148, 876),
#  (149, 24),
#  (149, 260),
#  (149, 287),
#  (149, 1464),
#  (149, 2273),
#  (149, 2147),
#  (150, 20),
#  (150, 28),
#  (150, 118),
#  (150, 2259),
#  (150, 2460),
#  (150, 2728),
#  (151, 195),
#  (151, 146),
#  (151, 147),
#  (151, 2781),
#  (151, 2825),
#  (151, 355),
#  (152, 396),
#  (152, 172),
#  (152, 414),
#  (152, 2801),
#  (152, 436),
#  (152, 489),
#  (153, 19),
#  (153, 372),
#  (153, 79),
#  (153, 495),
#  (153, 964),
#  (153, 439),
#  (154, 236),
#  (154, 78),
#  (154, 163),
#  (154, 1251),
#  (154, 2244),
#  (154, 1148),
#  (155, 156),
#  (155, 157),
#  (155, 127),
#  (155, 2065),
#  (155, 2522),
#  (155, 644),
#  (156, 441),
#  (156, 1894),
#  (156, 1494),
#  (156, 1830),
#  (156, 2786),
#  (156, 1178),
#  (157, 130),
#  (157, 308),
#  (157, 234),
#  (157, 570),
#  (157, 1607),
#  (157, 97),
#  (158, 63),
#  (158, 72),
#  (158, 216),
#  (158, 871),
#  (158, 1390),
#  (158, 1329),
#  (159, 147),
#  (159, 35),
#  (159, 227),
#  (159, 331),
#  (159, 1322),
#  (159, 2570),
#  (160, 193),
#  (160, 128),
#  (160, 74),
#  (160, 2339),
#  (160, 1380),
#  (160, 2331),
#  (161, 192),
#  (161, 128),
#  (161, 74),
#  (161, 1394),
#  (161, 862),
#  (161, 940),
#  (162, 58),
#  (162, 163),
#  (162, 68),
#  (162, 2441),
#  (162, 2177),
#  (162, 529),
#  (163, 280),
#  (163, 165),
#  (163, 18),
#  (163, 2014),
#  (163, 571),
#  (163, 2170),
#  (164, 258),
#  (164, 18),
#  (164, 321),
#  (164, 909),
#  (164, 232),
#  (164, 2518),
#  (165, 50),
#  (165, 27),
#  (165, 396),
#  (165, 2810),
#  (165, 372),
#  (165, 207),
#  (166, 35),
#  (166, 253),
#  (166, 47),
#  (166, 251),
#  (166, 371),
#  (166, 670),
#  (167, 192),
#  (167, 193),
#  (167, 128),
#  (167, 940),
#  (167, 1394),
#  (167, 862),
#  (168, 78),
#  ...]

# %%
stmt = ''' SELECT videos.title, related_videos.related_id FROM videos, related_videos WHERE videos.id = related_videos.video_id; '''

connection.execute(stmt).fetchall()
# Out:
# [('Do schools kill creativity?', 865),
#  ('Do schools kill creativity?', 1738),
#  ('Do schools kill creativity?', 2276),
#  ('Do schools kill creativity?', 892),
#  ('Do schools kill creativity?', 1232),
#  ('Do schools kill creativity?', 2616),
#  ('Averting the climate crisis', 243),
#  ('Averting the climate crisis', 547),
#  ('Averting the climate crisis', 2093),
#  ('Averting the climate crisis', 2784),
#  ('Averting the climate crisis', 2339),
#  ('Averting the climate crisis', 2331),
#  ('Simplicity sells', 1725),
#  ('Simplicity sells', 2274),
#  ('Simplicity sells', 172),
#  ('Simplicity sells', 2664),
#  ('Simplicity sells', 436),
#  ('Simplicity sells', 1546),
#  ('Greening the ghetto', 1041),
#  ('Greening the ghetto', 1892),
#  ('Greening the ghetto', 2078),
#  ('Greening the ghetto', 2873),
#  ('Greening the ghetto', 2840),
#  ('Greening the ghetto', 2839),
#  ("The best stats you've ever seen", 2056),
#  ("The best stats you've ever seen", 2296),
#  ("The best stats you've ever seen", 620),
#  ("The best stats you've ever seen", 974),
#  ("The best stats you've ever seen", 140),
#  ("The best stats you've ever seen", 912),
#  ('Why we do what we do', 229),
#  ('Why we do what we do', 70),
#  ('Why we do what we do', 97),
#  ('Why we do what we do', 1094),
#  ('Why we do what we do', 2861),
#  ('Why we do what we do', 2279),
#  ('Letting go of God', 22),
#  ('Letting go of God', 94),
#  ('Letting go of God', 856),
#  ('Letting go of God', 112),
#  ('Letting go of God', 71),
#  ('Letting go of God', 308),
#  ("Behind the design of Seattle's library", 750),
#  ("Behind the design of Seattle's library", 2092),
#  ("Behind the design of Seattle's library", 2183),
#  ("Behind the design of Seattle's library", 359),
#  ("Behind the design of Seattle's library", 231),
#  ("Behind the design of Seattle's library", 31),
#  ("Let's teach religion -- all religion -- in schools", 71),
#  ("Let's teach religion -- all religion -- in schools", 2011),
#  ("Let's teach religion -- all religion -- in schools", 234),
#  ("Let's teach religion -- all religion -- in schools", 113),
#  ("Let's teach religion -- all religion -- in schools", 301),
#  ("Let's teach religion -- all religion -- in schools", 1327),
#  ('A life of purpose', 94),
#  ('A life of purpose', 676),
#  ('A life of purpose', 2011),
#  ('A life of purpose', 301),
#  ('A life of purpose', 86),
#  ('A life of purpose', 308),
#  ('My wish: A call for open-source architecture', 1749),
#  ('My wish: A call for open-source architecture', 2183),
#  ('My wish: A call for open-source architecture', 31),
#  ('My wish: A call for open-source architecture', 646),
#  ('My wish: A call for open-source architecture', 2532),
#  ('My wish: A call for open-source architecture', 266),
#  ('My wish: A global day of film', 2228),
#  ('My wish: A global day of film', 1476),
#  ('My wish: A global day of film', 800),
#  ('My wish: A global day of film', 403),
#  ('My wish: A global day of film', 170),
#  ('My wish: A global day of film', 282),
#  ('My wish: Help me stop pandemics', 1153),
#  ('My wish: Help me stop pandemics', 869),
#  ('My wish: Help me stop pandemics', 1905),
#  ('My wish: Help me stop pandemics', 529),
#  ('My wish: Help me stop pandemics', 177),
#  ('My wish: Help me stop pandemics', 2185),
#  ('The radical promise of the multi-touch interface', 685),
#  ('The radical promise of the multi-touch interface', 872),
#  ('The radical promise of the multi-touch interface', 1984),
#  ('The radical promise of the multi-touch interface', 2410),
#  ('The radical promise of the multi-touch interface', 260),
#  ('The radical promise of the multi-touch interface', 230),
#  ('One Laptop per Child', 2043),
#  ('One Laptop per Child', 255),
#  ('One Laptop per Child', 1678),
#  ('One Laptop per Child', 288),
#  ('One Laptop per Child', 423),
#  ('One Laptop per Child', 230),
#  ("An 11-year-old's magical violin", 2273),
#  ("An 11-year-old's magical violin", 2242),
#  ("An 11-year-old's magical violin", 1156),
#  ("An 11-year-old's magical violin", 805),
#  ("An 11-year-old's magical violin", 1440),
#  ("An 11-year-old's magical violin", 2033),
#  ('Improvising on piano, aged 14', 2273),
#  ('Improvising on piano, aged 14', 2100),
#  ('Improvising on piano, aged 14', 1298),
#  ('Improvising on piano, aged 14', 1526),
#  ('Improvising on piano, aged 14', 883),
#  ('Improvising on piano, aged 14', 246),
#  ('Simple designs to save a life', 1561),
#  ('Simple designs to save a life', 1072),
#  ('Simple designs to save a life', 1184),
#  ('Simple designs to save a life', 1020),
#  ('Simple designs to save a life', 1041),
#  ('Simple designs to save a life', 85),
#  ('Organic design, inspired by nature', 2251),
#  ('Organic design, inspired by nature', 174),
#  ('Organic design, inspired by nature', 614),
#  ('Organic design, inspired by nature', 5),
#  ('Organic design, inspired by nature', 431),
#  ('Organic design, inspired by nature', 207),
#  ('The birth of Wikipedia', 640),
#  ('The birth of Wikipedia', 362),
#  ('The birth of Wikipedia', 1295),
#  ('The birth of Wikipedia', 247),
#  ('The birth of Wikipedia', 783),
#  ('The birth of Wikipedia', 1091),
#  ('The birth of the open-source learning revolution', 1913),
#  ('The birth of the open-source learning revolution', 1531),
#  ('The birth of the open-source learning revolution', 1570),
#  ('The birth of the open-source learning revolution', 346),
#  ('The birth of the open-source learning revolution', 2382),
#  ('The birth of the open-source learning revolution', 2180),
#  ('Nerdcore comedy', 148),
#  ('Nerdcore comedy', 981),
#  ('Nerdcore comedy', 2049),
#  ('Nerdcore comedy', 2792),
#  ('Nerdcore comedy', 1152),
#  ('Nerdcore comedy', 2838),
#  ('Meet the founder of the blog revolution', 144),
#  ('Meet the founder of the blog revolution', 1282),
#  ('Meet the founder of the blog revolution', 1379),
#  ('Meet the founder of the blog revolution', 118),
#  ('Meet the founder of the blog revolution', 641),
#  ('Meet the founder of the blog revolution', 1416),
#  ('Why we love, why we cheat', 307),
#  ('Why we love, why we cheat', 374),
#  ('Why we love, why we cheat', 1669),
#  ('Why we love, why we cheat', 2590),
#  ('Why we love, why we cheat', 2661),
#  ('Why we love, why we cheat', 2330),
#  ('Happiness in body and soul', 217),
#  ('Happiness in body and soul', 751),
#  ('Happiness in body and soul', 1753),
#  ('Happiness in body and soul', 1205),
#  ('Happiness in body and soul', 2175),
#  ('Happiness in body and soul', 842),
#  ('Chemical scum that dream of distant quasars', 2237),
#  ('Chemical scum that dream of distant quasars', 701),
#  ('Chemical scum that dream of distant quasars', 1095),
#  ('Chemical scum that dream of distant quasars', 42),
#  ('Chemical scum that dream of distant quasars', 1426),
#  ('Chemical scum that dream of distant quasars', 242),
#  ('Why the universe seems so strange', 1276),
#  ('Why the universe seems so strange', 1160),
#  ('Why the universe seems so strange', 516),
#  ('Why the universe seems so strange', 2862),
#  ('Why the universe seems so strange', 42),
#  ('Why the universe seems so strange', 394),
#  ('The freakonomics of crack dealing', 20),
#  ('The freakonomics of crack dealing', 2247),
#  ('The freakonomics of crack dealing', 1897),
#  ('The freakonomics of crack dealing', 1859),
#  ('The freakonomics of crack dealing', 2261),
#  ('The freakonomics of crack dealing', 2299),
#  ('Choice, happiness and spaghetti sauce', 93),
#  ('Choice, happiness and spaghetti sauce', 28),
#  ('Choice, happiness and spaghetti sauce', 1831),
#  ('Choice, happiness and spaghetti sauce', 263),
#  ('Choice, happiness and spaghetti sauce', 1306),
#  ('Choice, happiness and spaghetti sauce', 765),
#  ('The surprising science of happiness', 944),
#  ('The surprising science of happiness', 1880),
#  ('The surprising science of happiness', 2162),
#  ('The surprising science of happiness', 1607),
#  ('The surprising science of happiness', 570),
#  ('The surprising science of happiness', 779),
#  ('The paradox of choice', 2023),
#  ('The paradox of choice', 924),
#  ('The paradox of choice', 2044),
#  ('The paradox of choice', 1330),
#  ('The paradox of choice', 2799),
#  ('The paradox of choice', 420),
#  ('Meet the future of cancer research', 2109),
#  ('Meet the future of cancer research', 859),
#  ('Meet the future of cancer research', 1498),
#  ('Meet the future of cancer research', 1229),
#  ('Meet the future of cancer research', 2599),
#  ('Meet the future of cancer research', 1343),
#  ('A roadmap to end aging', 252),
#  ('A roadmap to end aging', 142),
#  ('A roadmap to end aging', 12),
#  ('A roadmap to end aging', 2315),
#  ('A roadmap to end aging', 44),
#  ('A roadmap to end aging', 515),
#  ('How mobile phones can fight poverty', 270),
#  ('How mobile phones can fight poverty', 157),
#  ('How mobile phones can fight poverty', 288),
#  ('How mobile phones can fight poverty', 1599),
#  ('How mobile phones can fight poverty', 2105),
#  ('How mobile phones can fight poverty', 2114),
#  ("Invest in Africa's own solutions", 2213),
#  ("Invest in Africa's own solutions", 154),
#  ("Invest in Africa's own solutions", 127),
#  ("Invest in Africa's own solutions", 157),
#  ("Invest in Africa's own solutions", 847),
#  ("Invest in Africa's own solutions", 644),
#  ('Why we should invest in a free press', 91),
#  ('Why we should invest in a free press', 170),
#  ('Why we should invest in a free press', 23),
#  ('Why we should invest in a free press', 1066),
#  ('Why we should invest in a free press', 983),
#  ('Why we should invest in a free press', 2835),
#  ('How to rebuild a broken state', 127),
#  ('How to rebuild a broken state', 1929),
#  ('How to rebuild a broken state', 584),
#  ('How to rebuild a broken state', 1196),
#  ('How to rebuild a broken state', 270),
#  ('How to rebuild a broken state', 2806),
#  ('The real future of space exploration', 141),
#  ('The real future of space exploration', 264),
#  ('The real future of space exploration', 335),
#  ('The real future of space exploration', 1260),
#  ('The real future of space exploration', 1402),
#  ('The real future of space exploration', 176),
#  ('Why did I ski to the North Pole?', 2292),
#  ('Why did I ski to the North Pole?', 627),
#  ('Why did I ski to the North Pole?', 2255),
#  ('Why did I ski to the North Pole?', 2143),
#  ('Why did I ski to the North Pole?', 1631),
#  ('Why did I ski to the North Pole?', 2165),
#  ('My wish: Three actions for Africa', 156),
#  ('My wish: Three actions for Africa', 157),
#  ('My wish: Three actions for Africa', 127),
#  ('My wish: Three actions for Africa', 330),
#  ('My wish: Three actions for Africa', 154),
#  ('My wish: Three actions for Africa', 2560),
#  ('My wish: Manufactured landscapes and green education', 279),
#  ('My wish: Manufactured landscapes and green education', 84),
#  ('My wish: Manufactured landscapes and green education', 40),
#  ('My wish: Manufactured landscapes and green education', 1236),
#  ('My wish: Manufactured landscapes and green education', 1554),
#  ('My wish: Manufactured landscapes and green education', 634),
#  ('My wish: Three unusual medical inventions', 82),
#  ('My wish: Three unusual medical inventions', 142),
#  ('My wish: Three unusual medical inventions', 280),
#  ('My wish: Three unusual medical inventions', 1717),
#  ('My wish: Three unusual medical inventions', 1297),
#  ('My wish: Three unusual medical inventions', 2555),
#  ('How juries are fooled by statistics', 92),
#  ('How juries are fooled by statistics', 22),
#  ('How juries are fooled by statistics', 143),
#  ('How juries are fooled by statistics', 571),
#  ('How juries are fooled by statistics', 2004),
#  ('How juries are fooled by statistics', 2835),
#  ('Why people believe weird things', 666),
#  ('Why people believe weird things', 2178),
#  ('Why people believe weird things', 333),
#  ('Why people believe weird things', 426),
#  ('Why people believe weird things', 2032),
#  ('Why people believe weird things', 1827),
#  ('The accelerating power of technology', 19),
#  ('The accelerating power of technology', 129),
#  ('The accelerating power of technology', 351),
#  ('The accelerating power of technology', 560),
#  ('The accelerating power of technology', 2858),
#  ('The accelerating power of technology', 1346),
#  ('How technology evolves', 319),
#  ('How technology evolves', 38),
#  ('How technology evolves', 190),
#  ('How technology evolves', 770),
#  ('How technology evolves', 1131),
#  ('How technology evolves', 72),
#  ('Fight injustice with raw video', 75),
#  ('Fight injustice with raw video', 170),
#  ('Fight injustice with raw video', 84),
#  ('Fight injustice with raw video', 171),
#  ('Fight injustice with raw video', 2142),
#  ('Fight injustice with raw video', 386),
#  ('8 secrets of success', 66),
#  ('8 secrets of success', 202),
#  ('8 secrets of success', 93),
#  ('8 secrets of success', 572),
#  ('8 secrets of success', 2638),
#  ('8 secrets of success', 2182),
#  ('If I controlled the Internet', 148),
#  ('If I controlled the Internet', 383),
#  ('If I controlled the Internet', 981),
#  ('If I controlled the Internet', 1693),
#  ('If I controlled the Internet', 640),
#  ('If I controlled the Internet', 1436),
#  ("The killer American diet that's sweeping the planet", 263),
#  ("The killer American diet that's sweeping the planet", 348),
#  ("The killer American diet that's sweeping the planet", 248),
#  ("The killer American diet that's sweeping the planet", 377),
#  ("The killer American diet that's sweeping the planet", 727),
#  ("The killer American diet that's sweeping the planet", 1900),
#  ('The hidden world of shadow cities', 643),
#  ('The hidden world of shadow cities', 1846),
#  ('The hidden world of shadow cities', 2128),
#  ('The hidden world of shadow cities', 2873),
#  ('The hidden world of shadow cities', 53),
#  ('The hidden world of shadow cities', 2840),
#  ('Global priorities bigger than climate change', 248),
#  ('Global priorities bigger than climate change', 92),
#  ('Global priorities bigger than climate change', 143),
#  ('Global priorities bigger than climate change', 85),
#  ('Global priorities bigger than climate change', 2480),
#  ('Global priorities bigger than climate change', 2806),
#  ('Dreams from endangered cultures', 273),
#  ('Dreams from endangered cultures', 40),
#  ('Dreams from endangered cultures', 34),
#  ('Dreams from endangered cultures', 2141),
#  ('Dreams from endangered cultures', 2551),
#  ('Dreams from endangered cultures', 2088),
#  ('Photos of endangered cultures', 2264),
#  ('Photos of endangered cultures', 2141),
#  ('Photos of endangered cultures', 1789),
#  ('Photos of endangered cultures', 651),
#  ('Photos of endangered cultures', 2152),
#  ('Photos of endangered cultures', 538),
#  ('Is this our final century?', 167),
#  ('Is this our final century?', 68),
#  ('Is this our final century?', 365),
#  ('Is this our final century?', 47),
#  ('Is this our final century?', 468),
#  ('Is this our final century?', 876),
#  ('Progress is not a zero-sum game', 163),
#  ('Progress is not a zero-sum game', 42),
#  ('Progress is not a zero-sum game', 341),
#  ('Progress is not a zero-sum game', 801),
#  ('Progress is not a zero-sum game', 2669),
#  ('Progress is not a zero-sum game', 1463),
#  ('How the "ghost map" helped end a killer disease', 58),
#  ('How the "ghost map" helped end a killer disease', 29),
#  ('How the "ghost map" helped end a killer disease', 20),
#  ('How the "ghost map" helped end a killer disease', 1582),
#  ('How the "ghost map" helped end a killer disease', 655),
#  ('How the "ghost map" helped end a killer disease', 2591),
#  ('The era of open innovation', 216),
#  ('The era of open innovation', 247),
#  ('The era of open innovation', 274),
#  ('The era of open innovation', 1492),
#  ('The era of open innovation', 2470),
#  ('The era of open innovation', 661),
#  ('A dance of "Symbiosis"', 40),
#  ('A dance of "Symbiosis"', 188),
#  ('A dance of "Symbiosis"', 60),
#  ('Four American characters', 86),
#  ('Four American characters', 26),
#  ('Four American characters', 374),
#  ('Four American characters', 2801),
#  ('Four American characters', 2887),
#  ('Four American characters', 2769),
#  ('Everyday inventions', 90),
#  ('Everyday inventions', 2),
#  ('Everyday inventions', 266),
#  ('Everyday inventions', 1215),
#  ('Everyday inventions', 1707),
#  ('Everyday inventions', 843),
#  ('Unleash your creativity in a Fab Lab', 2),
#  ('Unleash your creativity in a Fab Lab', 48),
#  ('Unleash your creativity in a Fab Lab', 288),
#  ('Unleash your creativity in a Fab Lab', 2664),
#  ('Unleash your creativity in a Fab Lab', 1570),
#  ('Unleash your creativity in a Fab Lab', 872),
#  ('In praise of slowness', 93),
#  ('In praise of slowness', 263),
#  ('In praise of slowness', 201),
#  ('In praise of slowness', 2025),
#  ('In praise of slowness', 2815),
#  ('In praise of slowness', 1069),
#  ('My wish: Rebuilding Rwanda', 59),
#  ('My wish: Rebuilding Rwanda', 127),
#  ('My wish: Rebuilding Rwanda', 268),
#  ('My wish: Rebuilding Rwanda', 2806),
#  ('My wish: Rebuilding Rwanda', 249),
#  ('My wish: Rebuilding Rwanda', 2789),
#  ('My wish: Build the Encyclopedia of Life', 340),
#  ('My wish: Build the Encyclopedia of Life', 40),
#  ('My wish: Build the Encyclopedia of Life', 299),
#  ('My wish: Build the Encyclopedia of Life', 2833),
#  ('My wish: Build the Encyclopedia of Life', 1131),
#  ('My wish: Build the Encyclopedia of Life', 509),
#  ('My wish: Let my photographs bear witness', 56),
#  ('My wish: Let my photographs bear witness', 69),
#  ('My wish: Let my photographs bear witness', 279),
#  ('My wish: Let my photographs bear witness', 1651),
#  ('My wish: Let my photographs bear witness', 395),
#  ('My wish: Let my photographs bear witness', 1003),
#  ('What separates us from chimpanzees?', 76),
#  ('What separates us from chimpanzees?', 145),
#  ('What separates us from chimpanzees?', 77),
#  ('What separates us from chimpanzees?', 340),
#  ('What separates us from chimpanzees?', 2307),
#  ('What separates us from chimpanzees?', 1417),
#  ('How to get your ideas to spread', 20),
#  ('How to get your ideas to spread', 72),
#  ('How to get your ideas to spread', 266),
#  ('How to get your ideas to spread', 2274),
#  ('How to get your ideas to spread', 848),
#  ('How to get your ideas to spread', 353),
#  ('How we discovered DNA', 83),
#  ('How we discovered DNA', 194),
#  ('How we discovered DNA', 147),
#  ('How we discovered DNA', 1322),
#  ('How we discovered DNA', 2570),
#  ('How we discovered DNA', 2354),
#  ('Visual illusions that show how we (mis)think', 32),
#  ('Visual illusions that show how we (mis)think', 22),
#  ('Visual illusions that show how we (mis)think', 310),
#  ('Visual illusions that show how we (mis)think', 1334),
#  ('Visual illusions that show how we (mis)think', 1607),
#  ('Visual illusions that show how we (mis)think', 97),
#  ('To invent is to give', 2),
#  ('To invent is to give', 54),
#  ('To invent is to give', 90),
#  ('To invent is to give', 1559),
#  ('To invent is to give', 2839),
#  ('To invent is to give', 1174),
#  ('The life code that will reshape the future', 227),
#  ('The life code that will reshape the future', 35),
#  ('The life code that will reshape the future', 331),
#  ('The life code that will reshape the future', 6),
#  ('The life code that will reshape the future', 1274),
#  ('The life code that will reshape the future', 863),
#  ('Happiness by design', 356),
#  ('Happiness by design', 182),
#  ('Happiness by design', 172),
#  ('Happiness by design', 97),
#  ('Happiness by design', 1607),
#  ('Happiness by design', 570),
#  ('The route to a sustainable future', 104),
#  ('The route to a sustainable future', 18),
#  ('The route to a sustainable future', 266),
#  ('The route to a sustainable future', 2855),
#  ('The route to a sustainable future', 174),
#  ('The route to a sustainable future', 439),
#  ('How architecture can connect us', 27),
#  ('How architecture can connect us', 359),
#  ('How architecture can connect us', 54),
#  ('How architecture can connect us', 2375),
#  ('How architecture can connect us', 2797),
#  ('How architecture can connect us', 589),
#  ('Great cars are great art', 4),
#  ('Great cars are great art', 266),
#  ('Great cars are great art', 27),
#  ('Great cars are great art', 1506),
#  ('Great cars are great art', 1724),
#  ('Great cars are great art', 2443),
#  ('Singing "What I Want"', 158),
#  ('Singing "What I Want"', 110),
#  ('Singing "What I Want"', 117),
#  ('Singing "What I Want"', 241),
#  ('Singing "What I Want"', 298),
#  ('Singing "What I Want"', 2770),
#  ('Design is in the details', 392),
#  ('Design is in the details', 266),
#  ('Design is in the details', 172),
#  ('Design is in the details', 646),
#  ('Design is in the details', 2810),
#  ('Design is in the details', 122),
#  ('Art with wire, sugar, chocolate and string', 162),
#  ('Art with wire, sugar, chocolate and string', 267),
#  ('Art with wire, sugar, chocolate and string', 78),
#  ('Art with wire, sugar, chocolate and string', 210),
#  ('Art with wire, sugar, chocolate and string', 488),
#  ('Art with wire, sugar, chocolate and string', 2264),
#  ('A philosophical quest for our biggest problems', 42),
#  ('A philosophical quest for our biggest problems', 19),
#  ('A philosophical quest for our biggest problems', 68),
#  ('A philosophical quest for our biggest problems', 2858),
#  ('A philosophical quest for our biggest problems', 39),
#  ('A philosophical quest for our biggest problems', 515),
#  ("Biomimicry's surprising lessons from nature's engineers", 280),
#  ("Biomimicry's surprising lessons from nature's engineers", 198),
#  ("Biomimicry's surprising lessons from nature's engineers", 258),
#  ("Biomimicry's surprising lessons from nature's engineers", 614),
#  ("Biomimicry's surprising lessons from nature's engineers", 1072),
#  ("Biomimicry's surprising lessons from nature's engineers", 1561),
#  ("Sampling the ocean's DNA", 227),
#  ("Sampling the ocean's DNA", 323),
#  ("Sampling the ocean's DNA", 331),
#  ("Sampling the ocean's DNA", 437),
#  ("Sampling the ocean's DNA", 863),
#  ("Sampling the ocean's DNA", 1223),
#  ('Software (as) art', 144),
#  ('Software (as) art', 241),
#  ('Software (as) art', 32),
#  ('Software (as) art', 427),
#  ('Software (as) art', 1571),
#  ('Software (as) art', 606),
#  ('The gentle genius of bonobos', 340),
#  ('The gentle genius of bonobos', 77),
#  ('The gentle genius of bonobos', 145),
#  ('The gentle genius of bonobos', 1102),
#  ('The gentle genius of bonobos', 2539),
#  ('The gentle genius of bonobos', 11),
#  ('The story of life in photographs', 69),
#  ('The story of life in photographs', 324),
#  ('The story of life in photographs', 147),
#  ('The story of life in photographs', 573),
#  ('The story of life in photographs', 2088),
#  ('The story of life in photographs', 2471),
#  ('The shrimp with a kick!', 126),
#  ('The shrimp with a kick!', 76),
#  ('The shrimp with a kick!', 145),
#  ('The shrimp with a kick!', 280),
#  ('The shrimp with a kick!', 1959),
#  ('The shrimp with a kick!', 2014),
#  ('Global warming\'s theme song, "Manhattan in January"', 222),
#  ('Global warming\'s theme song, "Manhattan in January"', 119),
#  ('Global warming\'s theme song, "Manhattan in January"', 1),
#  ('Global warming\'s theme song, "Manhattan in January"', 1073),
#  ('Global warming\'s theme song, "Manhattan in January"', 688),
#  ('Global warming\'s theme song, "Manhattan in January"', 1797),
#  ('Casting a spell on the cello', 117),
#  ('Casting a spell on the cello', 109),
#  ('Casting a spell on the cello', 218),
#  ('Casting a spell on the cello', 849),
#  ('Casting a spell on the cello', 1001),
#  ('Casting a spell on the cello', 2849),
#  ('The illusion of consciousness', 116),
#  ('The illusion of consciousness', 125),
#  ('The illusion of consciousness', 229),
#  ('The illusion of consciousness', 1794),
#  ('The illusion of consciousness', 2045),
#  ('The illusion of consciousness', 2817),
#  ('How to truly listen', 286),
#  ('How to truly listen', 246),
#  ('How to truly listen', 218),
#  ('How to truly listen', 2033),
#  ('How to truly listen', 883),
#  ('How to truly listen', 1526),
#  ('Cradle to cradle design', 74),
#  ('Cradle to cradle design', 359),
#  ('Cradle to cradle design', 174),
#  ('Cradle to cradle design', 2855),
#  ('Cradle to cradle design', 2128),
#  ('Cradle to cradle design', 1072),
#  ("The electricity metaphor for the web's future", 319),
#  ("The electricity metaphor for the web's future", 118),
#  ("The electricity metaphor for the web's future", 362),
#  ("The electricity metaphor for the web's future", 619),
#  ("The electricity metaphor for the web's future", 566),
#  ("The electricity metaphor for the web's future", 1695),
#  ('A mockingbird remix of TED2006', 148),
#  ('A mockingbird remix of TED2006', 2281),
#  ('A mockingbird remix of TED2006', 2049),
#  ('A mockingbird remix of TED2006', 981),
#  ('A mockingbird remix of TED2006', 413),
#  ('A mockingbird remix of TED2006', 114),
#  ('"Kiteflyer\'s Hill"', 109),
#  ('"Kiteflyer\'s Hill"', 101),
#  ('"Kiteflyer\'s Hill"', 117),
#  ('"Kiteflyer\'s Hill"', 2345),
#  ('"Kiteflyer\'s Hill"', 2801),
#  ('"Kiteflyer\'s Hill"', 849),
#  ('"What You\'ve Got"', 110),
#  ('"What You\'ve Got"', 81),
#  ('"What You\'ve Got"', 186),
#  ('"What You\'ve Got"', 1959),
#  ('"What You\'ve Got"', 1121),
#  ('"What You\'ve Got"', 482),
#  ('Why would God create a tsunami?', 234),
#  ('Why would God create a tsunami?', 308),
#  ('Why would God create a tsunami?', 71),
#  ('Why would God create a tsunami?', 86),
#  ('Why would God create a tsunami?', 673),
#  ('Why would God create a tsunami?', 676),
#  ('Militant atheism', 86),
#  ('Militant atheism', 94),
#  ('Militant atheism', 22),
#  ('Militant atheism', 2011),
#  ('Militant atheism', 1327),
#  ('Militant atheism', 2643),
#  ('A comic sendup of TED2006', 108),
#  ('A comic sendup of TED2006', 87),
#  ('A comic sendup of TED2006', 99),
#  ('A comic sendup of TED2006', 22),
#  ('A comic sendup of TED2006', 426),
#  ('A comic sendup of TED2006', 2855),
#  ('"La Vie en Rose"', 108),
#  ('"La Vie en Rose"', 87),
#  ('"La Vie en Rose"', 99),
#  ('"La Vie en Rose"', 2256),
#  ('"La Vie en Rose"', 110),
#  ('"La Vie en Rose"', 1605),
#  ("Technology's long tail", 319),
#  ("Technology's long tail", 118),
#  ("Technology's long tail", 216),
#  ("Technology's long tail", 770),
#  ("Technology's long tail", 19),
#  ("Technology's long tail", 1574),
#  ('Cape Breton fiddling in reel time', 45),
#  ('Cape Breton fiddling in reel time', 296),
#  ('Cape Breton fiddling in reel time', 138),
#  ('Cape Breton fiddling in reel time', 2424),
#  ('Cape Breton fiddling in reel time', 2814),
#  ('Cape Breton fiddling in reel time', 2064),
#  ('The genesis of Google', 319),
#  ('The genesis of Google', 1109),
#  ('The genesis of Google', 1113),
#  ('The genesis of Google', 2369),
#  ('The genesis of Google', 362),
#  ('The genesis of Google', 1091),
#  ('"Black Men Ski"', 158),
#  ('"Black Men Ski"', 99),
#  ('"Black Men Ski"', 254),
#  ('"Black Men Ski"', 2151),
#  ('"Black Men Ski"', 2691),
#  ('"Black Men Ski"', 2634),
#  ('The ghastly tragedy of the suburbs', 123),
#  ('The ghastly tragedy of the suburbs', 36),
#  ('The ghastly tragedy of the suburbs', 33),
#  ('The ghastly tragedy of the suburbs', 2797),
#  ('The ghastly tragedy of the suburbs', 2092),
#  ('The ghastly tragedy of the suburbs', 1854),
#  ('Human-centered design', 266),
#  ('Human-centered design', 43),
#  ('Human-centered design', 172),
#  ('Human-centered design', 646),
#  ('Human-centered design', 372),
#  ('Human-centered design', 2039),
#  ('What squatter cities can teach us', 36),
#  ('What squatter cities can teach us', 121),
#  ('What squatter cities can teach us', 213),
#  ('What squatter cities can teach us', 1865),
#  ('What squatter cities can teach us', 1429),
#  ('What squatter cities can teach us', 1892),
#  ('How brain science will change computing', 184),
#  ('How brain science will change computing', 236),
#  ('How brain science will change computing', 320),
#  ('How brain science will change computing', 2798),
#  ('How brain science will change computing', 2015),
#  ('How brain science will change computing', 2495),
#  ('Swim with the giant sunfish', 206),
#  ('Swim with the giant sunfish', 77),
#  ('Swim with the giant sunfish', 145),
#  ('Swim with the giant sunfish', 973),
#  ('Swim with the giant sunfish', 1373),
#  ('Swim with the giant sunfish', 2389),
#  ("How PhotoSynth can connect the world's images", 147),
#  ("How PhotoSynth can connect the world's images", 245),
#  ("How PhotoSynth can connect the world's images", 131),
#  ("How PhotoSynth can connect the world's images", 139),
#  ("How PhotoSynth can connect the world's images", 826),
#  ("How PhotoSynth can connect the world's images", 766),
#  ('Salvation (and profit) in greentech', 192),
#  ('Salvation (and profit) in greentech', 243),
#  ('Salvation (and profit) in greentech', 91),
#  ('Salvation (and profit) in greentech', 2784),
#  ('Salvation (and profit) in greentech', 1),
#  ('Salvation (and profit) in greentech', 2339),
#  ('Want to help Africa? Do business here', 185),
#  ('Want to help Africa? Do business here', 270),
#  ('Want to help Africa? Do business here', 91),
#  ('Want to help Africa? Do business here', 2560),
#  ('Want to help Africa? Do business here', 154),
#  ('Want to help Africa? Do business here', 151),
#  ('Rethink the desktop with BumpTop', 129),
#  ('Rethink the desktop with BumpTop', 245),
#  ('Rethink the desktop with BumpTop', 224),
#  ('Rethink the desktop with BumpTop', 65),
#  ('Rethink the desktop with BumpTop', 685),
#  ('Rethink the desktop with BumpTop', 872),
#  ('We can be Buddhas', 234),
#  ('We can be Buddhas', 191),
#  ('We can be Buddhas', 208),
#  ('We can be Buddhas', 677),
#  ('We can be Buddhas', 1074),
#  ('We can be Buddhas', 1216),
#  ('A memorial at Ground Zero', 49),
#  ('A memorial at Ground Zero', 359),
#  ('A memorial at Ground Zero', 31),
#  ('A memorial at Ground Zero', 2797),
#  ('A memorial at Ground Zero', 1182),
#  ('A memorial at Ground Zero', 121),
#  ("Let's rethink America's military strategy", 121),
#  ("Let's rethink America's military strategy", 167),
#  ("Let's rethink America's military strategy", 39),
#  ("Let's rethink America's military strategy", 1999),
#  ("Let's rethink America's military strategy", 2515),
#  ("Let's rethink America's military strategy", 2008),
#  ('A string quartet plays "Blue Room"', 103),
#  ('A string quartet plays "Blue Room"', 117),
#  ('A string quartet plays "Blue Room"', 218),
#  ("Tour Microsoft's Virtual Earth", 245),
#  ("Tour Microsoft's Virtual Earth", 129),
#  ("Tour Microsoft's Virtual Earth", 131),
#  ("Tour Microsoft's Virtual Earth", 766),
#  ("Tour Microsoft's Virtual Earth", 410),
#  ("Tour Microsoft's Virtual Earth", 1581),
#  ('New insights on poverty', 494),
#  ('New insights on poverty', 270),
#  ('New insights on poverty', 157),
#  ('New insights on poverty', 620),
#  ('New insights on poverty', 92),
#  ('New insights on poverty', 974),
#  ("I'm going to the moon. Who's with me?", 499),
#  ("I'm going to the moon. Who's with me?", 89),
#  ("I'm going to the moon. Who's with me?", 4),
#  ("I'm going to the moon. Who's with me?", 264),
#  ("I'm going to the moon. Who's with me?", 335),
#  ("I'm going to the moon. Who's with me?", 2853),
#  ('Dangerous memes', 69),
#  ('Dangerous memes', 269),
#  ('Dangerous memes', 358),
#  ('Dangerous memes', 1995),
#  ('Dangerous memes', 145),
#  ('Dangerous memes', 390),
#  ('The potential of regenerative medicine', 1103),
#  ('The potential of regenerative medicine', 1274),
#  ('The potential of regenerative medicine', 2342),
#  ('The potential of regenerative medicine', 744),
#  ('The potential of regenerative medicine', 1845),
#  ('The potential of regenerative medicine', 2343),
#  ("The Web's secret stories", 316),
#  ("The Web's secret stories", 32),
#  ("The Web's secret stories", 14),
#  ("The Web's secret stories", 900),
#  ("The Web's secret stories", 1118),
#  ("The Web's secret stories", 843),
#  ('Flip your thinking on AIDS in Africa', 92),
#  ('Flip your thinking on AIDS in Africa', 67),
#  ('Flip your thinking on AIDS in Africa', 29),
#  ('Flip your thinking on AIDS in Africa', 540),
#  ('Flip your thinking on AIDS in Africa', 836),
#  ('Flip your thinking on AIDS in Africa', 818),
#  ('Spore, birth of a game', 361),
#  ('Spore, birth of a game', 162),
#  ('Spore, birth of a game', 144),
#  ('Spore, birth of a game', 996),
#  ('Spore, birth of a game', 936),
#  ('Spore, birth of a game', 1432),
#  ('The  4 a.m. mystery', 374),
#  ('The  4 a.m. mystery', 87),
#  ('The  4 a.m. mystery', 22),
#  ('The  4 a.m. mystery', 2000),
#  ('The  4 a.m. mystery', 2792),
#  ('The  4 a.m. mystery', 1508),
#  ('Visualizing the wonder of a living cell', 331),
#  ('Visualizing the wonder of a living cell', 35),
#  ('Visualizing the wonder of a living cell', 40),
#  ('Visualizing the wonder of a living cell', 1187),
#  ('Visualizing the wonder of a living cell', 2052),
#  ('Visualizing the wonder of a living cell', 1882),
#  ('How to get (a new) hip', 204),
#  ('How to get (a new) hip', 201),
#  ('How to get (a new) hip', 21),
#  ('How to get (a new) hip', 1652),
#  ('How to get (a new) hip', 2046),
#  ('How to get (a new) hip', 1421),
#  ("Africa's cheetahs versus hippos", 152),
#  ("Africa's cheetahs versus hippos", 157),
#  ("Africa's cheetahs versus hippos", 159),
#  ("Africa's cheetahs versus hippos", 154),
#  ("Africa's cheetahs versus hippos", 2462),
#  ("Africa's cheetahs versus hippos", 2560),
#  ('Aid versus trade', 91),
#  ('Aid versus trade', 159),
#  ('Aid versus trade', 270),
#  ('Aid versus trade', 2560),
#  ('Aid versus trade', 127),
#  ('Aid versus trade', 2213),
#  ('How I built a windmill', 156),
#  ('How I built a windmill', 299),
#  ('How I built a windmill', 2),
#  ('How I built a windmill', 642),
#  ('How I built a windmill', 1134),
#  ('How I built a windmill', 2180),
#  ('Why invest in Africa', 127),
#  ('Why invest in Africa', 185),
#  ('Why invest in Africa', 156),
#  ('Why invest in Africa', 151),
#  ('Why invest in Africa', 2560),
#  ('Why invest in Africa', 2462),
#  ('How to educate leaders? Liberal arts', 153),
#  ('How to educate leaders? Liberal arts', 66),
#  ('How to educate leaders? Liberal arts', 558),
#  ('How to educate leaders? Liberal arts', 2113),
#  ('How to educate leaders? Liberal arts', 1930),
#  ('How to educate leaders? Liberal arts', 151),
#  ('Telling stories from Africa', 386),
#  ('Telling stories from Africa', 330),
#  ('Telling stories from Africa', 204),
#  ('Telling stories from Africa', 652),
#  ('Telling stories from Africa', 59),
#  ('Telling stories from Africa', 2462),
#  ('Patient capitalism', 270),
#  ('Patient capitalism', 127),
#  ('Patient capitalism', 75),
#  ('Patient capitalism', 91),
#  ('Patient capitalism', 644),
#  ('Patient capitalism', 2213),
#  ('"Thula Mama"', 169),
#  ('"Thula Mama"', 119),
#  ('"Thula Mama"', 186),
#  ('"Thula Mama"', 1912),
#  ('"Thula Mama"', 2538),
#  ('"Thula Mama"', 2345),
#  ('"Woza"', 158),
#  ('"Woza"', 188),
#  ('"Woza"', 265),
#  ('My journey into movies that matter', 205),
#  ('My journey into movies that matter', 171),
#  ('My journey into movies that matter', 56),
#  ('My journey into movies that matter', 403),
#  ('My journey into movies that matter', 55),
#  ('My journey into movies that matter', 2694),
#  ('Luke, a new prosthetic arm for soldiers', 142),
#  ('Luke, a new prosthetic arm for soldiers', 195),
#  ('Luke, a new prosthetic arm for soldiers', 171),
#  ('Luke, a new prosthetic arm for soldiers', 819),
#  ('Luke, a new prosthetic arm for soldiers', 1251),
#  ('Luke, a new prosthetic arm for soldiers', 1148),
#  ('The joy of lexicography', 69),
#  ('The joy of lexicography', 194),
#  ('The joy of lexicography', 148),
#  ('The joy of lexicography', 2022),
#  ('The joy of lexicography', 2158),
#  ('The joy of lexicography', 2709),
#  ('Aid for Africa? No thanks.', 152),
#  ('Aid for Africa? No thanks.', 157),
#  ('Aid for Africa? No thanks.', 151),
#  ('Aid for Africa? No thanks.', 2560),
#  ('Aid for Africa? No thanks.', 1929),
#  ('Aid for Africa? No thanks.', 127),
#  ('My creations, a new form of life', 267),
#  ('My creations, a new form of life', 32),
#  ('My creations, a new form of life', 1164),
#  ('My creations, a new form of life', 345),
#  ('My creations, a new form of life', 343),
#  ('My creations, a new form of life', 830),
#  ('What our language habits reveal', 163),
#  ('What our language habits reveal', 276),
#  ('What our language habits reveal', 69),
#  ('What our language habits reveal', 2595),
#  ('What our language habits reveal', 1670),
#  ('What our language habits reveal', 2028),
#  ('The surprising decline in violence', 68),
#  ('The surprising decline in violence', 29),
#  ('The surprising decline in violence', 140),
#  ('The surprising decline in violence', 1948),
#  ('The surprising decline in violence', 1342),
#  ('The surprising decline in violence', 2779),
#  ('An Iraq war movie crowd-sourced from soldiers', 386),
#  ('An Iraq war movie crowd-sourced from soldiers', 84),
#  ('An Iraq war movie crowd-sourced from soldiers', 170),
#  ('An Iraq war movie crowd-sourced from soldiers', 1999),
#  ('An Iraq war movie crowd-sourced from soldiers', 2008),
#  ('An Iraq war movie crowd-sourced from soldiers', 2374),
#  ("The search for humanity's roots", 323),
#  ("The search for humanity's roots", 315),
#  ("The search for humanity's roots", 69),
#  ("The search for humanity's roots", 340),
#  ("The search for humanity's roots", 11),
#  ("The search for humanity's roots", 607),
#  ('Designing for simplicity', 2),
#  ('Designing for simplicity', 845),
#  ('Designing for simplicity', 7),
#  ('Designing for simplicity', 427),
#  ('Designing for simplicity', 1571),
#  ('Designing for simplicity', 2043),
#  ('10 ways the world could end', 163),
#  ('10 ways the world could end', 68),
#  ('10 ways the world could end', 42),
#  ('10 ways the world could end', 1280),
#  ('10 ways the world could end', 2491),
#  ('10 ways the world could end', 2230),
#  ('A flight on solar wings', 4),
#  ('A flight on solar wings', 5),
#  ('A flight on solar wings', 264),
#  ('A flight on solar wings', 379),
#  ('A flight on solar wings', 492),
#  ('A flight on solar wings', 1402),
#  ('This is Saturn', 141),
#  ('This is Saturn', 4),
#  ('This is Saturn', 264),
#  ('This is Saturn', 551),
#  ('This is Saturn', 2550),
#  ('This is Saturn', 876),
#  ('My magic moves', 24),
#  ('My magic moves', 260),
#  ('My magic moves', 287),
#  ('My magic moves', 1464),
#  ('My magic moves', 2273),
#  ('My magic moves', 2147),
#  ('Life at 30,000 feet', 20),
#  ('Life at 30,000 feet', 28),
#  ('Life at 30,000 feet', 118),
#  ('Life at 30,000 feet', 2259),
#  ('Life at 30,000 feet', 2460),
#  ('Life at 30,000 feet', 2728),
#  ('Building "self-aware" robots', 195),
#  ('Building "self-aware" robots', 146),
#  ('Building "self-aware" robots', 147),
#  ('Building "self-aware" robots', 2781),
#  ('Building "self-aware" robots', 2825),
#  ('Building "self-aware" robots', 355),
#  ('The illustrated woman', 396),
#  ('The illustrated woman', 172),
#  ('The illustrated woman', 414),
#  ('The illustrated woman', 2801),
#  ('The illustrated woman', 436),
#  ('The illustrated woman', 489),
#  ('The anthropology of mobile phones', 19),
#  ('The anthropology of mobile phones', 372),
#  ('The anthropology of mobile phones', 79),
#  ('The anthropology of mobile phones', 495),
#  ('The anthropology of mobile phones', 964),
#  ('The anthropology of mobile phones', 439),
#  ('3 clues to understanding your brain', 236),
#  ('3 clues to understanding your brain', 78),
#  ('3 clues to understanding your brain', 163),
#  ('3 clues to understanding your brain', 1251),
#  ('3 clues to understanding your brain', 2244),
#  ('3 clues to understanding your brain', 1148),
#  ('A commodities exchange for Ethiopia', 156),
#  ('A commodities exchange for Ethiopia', 157),
#  ('A commodities exchange for Ethiopia', 127),
#  ('A commodities exchange for Ethiopia', 2065),
#  ('A commodities exchange for Ethiopia', 2522),
#  ('A commodities exchange for Ethiopia', 644),
#  ('How electroshock therapy changed me', 441),
#  ('How electroshock therapy changed me', 1894),
#  ('How electroshock therapy changed me', 1494),
#  ('How electroshock therapy changed me', 1830),
#  ('How electroshock therapy changed me', 2786),
#  ('How electroshock therapy changed me', 1178),
#  ('The habits of happiness', 130),
#  ('The habits of happiness', 308),
#  ('The habits of happiness', 234),
#  ('The habits of happiness', 570),
#  ('The habits of happiness', 1607),
#  ('The habits of happiness', 97),
#  ('Laws that choke creativity', 63),
#  ('Laws that choke creativity', 72),
#  ('Laws that choke creativity', 216),
#  ('Laws that choke creativity', 871),
#  ('Laws that choke creativity', 1390),
#  ('Laws that choke creativity', 1329),
#  ('Playing with DNA that self-assembles', 147),
#  ('Playing with DNA that self-assembles', 35),
#  ('Playing with DNA that self-assembles', 227),
#  ('Playing with DNA that self-assembles', 331),
#  ('Playing with DNA that self-assembles', 1322),
#  ('Playing with DNA that self-assembles', 2570),
#  ('A critical look at geoengineering against climate change', 193),
#  ('A critical look at geoengineering against climate change', 128),
#  ('A critical look at geoengineering against climate change', 74),
#  ('A critical look at geoengineering against climate change', 2339),
#  ('A critical look at geoengineering against climate change', 1380),
#  ('A critical look at geoengineering against climate change', 2331),
#  ('Using biology to rethink the energy challenge', 192),
#  ('Using biology to rethink the energy challenge', 128),
#  ('Using biology to rethink the energy challenge', 74),
#  ('Using biology to rethink the energy challenge', 1394),
#  ('Using biology to rethink the energy challenge', 862),
#  ('Using biology to rethink the energy challenge', 940),
#  ('The case for optimism', 58),
#  ('The case for optimism', 163),
#  ('The case for optimism', 68),
#  ('The case for optimism', 2441),
#  ('The case for optimism', 2177),
#  ('The case for optimism', 529),
#  ('The sticky wonder of gecko feet', 280),
#  ('The sticky wonder of gecko feet', 165),
#  ('The sticky wonder of gecko feet', 18),
#  ('The sticky wonder of gecko feet', 2014),
#  ('The sticky wonder of gecko feet', 571),
#  ('The sticky wonder of gecko feet', 2170),
#  ('The fractals at the heart of African designs', 258),
#  ('The fractals at the heart of African designs', 18),
#  ('The fractals at the heart of African designs', 321),
#  ('The fractals at the heart of African designs', 909),
#  ('The fractals at the heart of African designs', 232),
#  ('The fractals at the heart of African designs', 2518),
#  ('Design and destiny', 50),
#  ('Design and destiny', 27),
#  ('Design and destiny', 396),
#  ('Design and destiny', 2810),
#  ('Design and destiny', 372),
#  ('Design and destiny', 207),
#  ('Beauty, truth and ... physics?', 35),
#  ('Beauty, truth and ... physics?', 253),
#  ('Beauty, truth and ... physics?', 47),
#  ('Beauty, truth and ... physics?', 251),
#  ('Beauty, truth and ... physics?', 371),
#  ('Beauty, truth and ... physics?', 670),
#  ('Winning the oil endgame', 192),
#  ('Winning the oil endgame', 193),
#  ('Winning the oil endgame', 128),
#  ('Winning the oil endgame', 940),
#  ('Winning the oil endgame', 1394),
#  ('Winning the oil endgame', 862),
#  ('A performance of "Mathemagic"', 78),
#  ...]

# %%
stmt = ''' SELECT videos.title, video_ratings.rating_id, ratings.rating FROM videos, video_ratings, ratings
            WHERE videos.id = video_ratings.video_id AND video_ratings.rating_id = ratings.id
            ORDER BY videos.title, video_ratings.rating_id; '''

connection.execute(stmt).fetchall()
# Out:
# [(' Hidden miracles of the natural world', 1, 'Beautiful'),
#  (' Hidden miracles of the natural world', 2, 'Confusing'),
#  (' Hidden miracles of the natural world', 3, 'Courageous'),
#  (' Hidden miracles of the natural world', 7, 'Funny'),
#  (' Hidden miracles of the natural world', 8, 'Informative'),
#  (' Hidden miracles of the natural world', 9, 'Ingenious'),
#  (' Hidden miracles of the natural world', 10, 'Inspiring'),
#  (' Hidden miracles of the natural world', 11, 'Longwinded'),
#  (' Hidden miracles of the natural world', 21, 'Unconvincing'),
#  (' Hidden miracles of the natural world', 22, 'Fascinating'),
#  (' Hidden miracles of the natural world', 23, 'Jaw-dropping'),
#  (' Hidden miracles of the natural world', 24, 'Persuasive'),
#  (' Hidden miracles of the natural world', 25, 'OK'),
#  (' Hidden miracles of the natural world', 26, 'Obnoxious'),
#  (' How CRISPR lets us edit our DNA', 1, 'Beautiful'),
#  (' How CRISPR lets us edit our DNA', 2, 'Confusing'),
#  (' How CRISPR lets us edit our DNA', 3, 'Courageous'),
#  (' How CRISPR lets us edit our DNA', 7, 'Funny'),
#  (' How CRISPR lets us edit our DNA', 8, 'Informative'),
#  (' How CRISPR lets us edit our DNA', 9, 'Ingenious'),
#  (' How CRISPR lets us edit our DNA', 10, 'Inspiring'),
#  (' How CRISPR lets us edit our DNA', 11, 'Longwinded'),
#  (' How CRISPR lets us edit our DNA', 21, 'Unconvincing'),
#  (' How CRISPR lets us edit our DNA', 22, 'Fascinating'),
#  (' How CRISPR lets us edit our DNA', 23, 'Jaw-dropping'),
#  (' How CRISPR lets us edit our DNA', 24, 'Persuasive'),
#  (' How CRISPR lets us edit our DNA', 25, 'OK'),
#  (' How CRISPR lets us edit our DNA', 26, 'Obnoxious'),
#  ('"(Nothing But) Flowers" with string quartet', 1, 'Beautiful'),
#  ('"(Nothing But) Flowers" with string quartet', 2, 'Confusing'),
#  ('"(Nothing But) Flowers" with string quartet', 3, 'Courageous'),
#  ('"(Nothing But) Flowers" with string quartet', 7, 'Funny'),
#  ('"(Nothing But) Flowers" with string quartet', 8, 'Informative'),
#  ('"(Nothing But) Flowers" with string quartet', 9, 'Ingenious'),
#  ('"(Nothing But) Flowers" with string quartet', 10, 'Inspiring'),
#  ('"(Nothing But) Flowers" with string quartet', 11, 'Longwinded'),
#  ('"(Nothing But) Flowers" with string quartet', 21, 'Unconvincing'),
#  ('"(Nothing But) Flowers" with string quartet', 22, 'Fascinating'),
#  ('"(Nothing But) Flowers" with string quartet', 23, 'Jaw-dropping'),
#  ('"(Nothing But) Flowers" with string quartet', 24, 'Persuasive'),
#  ('"(Nothing But) Flowers" with string quartet', 25, 'OK'),
#  ('"(Nothing But) Flowers" with string quartet', 26, 'Obnoxious'),
#  ('"Awoo"', 1, 'Beautiful'),
#  ('"Awoo"', 2, 'Confusing'),
#  ('"Awoo"', 3, 'Courageous'),
#  ('"Awoo"', 7, 'Funny'),
#  ('"Awoo"', 8, 'Informative'),
#  ('"Awoo"', 9, 'Ingenious'),
#  ('"Awoo"', 10, 'Inspiring'),
#  ('"Awoo"', 11, 'Longwinded'),
#  ('"Awoo"', 21, 'Unconvincing'),
#  ('"Awoo"', 22, 'Fascinating'),
#  ('"Awoo"', 23, 'Jaw-dropping'),
#  ('"Awoo"', 24, 'Persuasive'),
#  ('"Awoo"', 25, 'OK'),
#  ('"Awoo"', 26, 'Obnoxious'),
#  ('"Black Men Ski"', 1, 'Beautiful'),
#  ('"Black Men Ski"', 2, 'Confusing'),
#  ('"Black Men Ski"', 3, 'Courageous'),
#  ('"Black Men Ski"', 7, 'Funny'),
#  ('"Black Men Ski"', 8, 'Informative'),
#  ('"Black Men Ski"', 9, 'Ingenious'),
#  ('"Black Men Ski"', 10, 'Inspiring'),
#  ('"Black Men Ski"', 11, 'Longwinded'),
#  ('"Black Men Ski"', 21, 'Unconvincing'),
#  ('"Black Men Ski"', 22, 'Fascinating'),
#  ('"Black Men Ski"', 23, 'Jaw-dropping'),
#  ('"Black Men Ski"', 24, 'Persuasive'),
#  ('"Black Men Ski"', 25, 'OK'),
#  ('"Black Men Ski"', 26, 'Obnoxious'),
#  ('"Clonie"', 1, 'Beautiful'),
#  ('"Clonie"', 2, 'Confusing'),
#  ('"Clonie"', 3, 'Courageous'),
#  ('"Clonie"', 7, 'Funny'),
#  ('"Clonie"', 8, 'Informative'),
#  ('"Clonie"', 9, 'Ingenious'),
#  ('"Clonie"', 10, 'Inspiring'),
#  ('"Clonie"', 11, 'Longwinded'),
#  ('"Clonie"', 21, 'Unconvincing'),
#  ('"Clonie"', 22, 'Fascinating'),
#  ('"Clonie"', 23, 'Jaw-dropping'),
#  ('"Clonie"', 24, 'Persuasive'),
#  ('"Clonie"', 25, 'OK'),
#  ('"Clonie"', 26, 'Obnoxious'),
#  ('"Family Tree"', 1, 'Beautiful'),
#  ('"Family Tree"', 2, 'Confusing'),
#  ('"Family Tree"', 3, 'Courageous'),
#  ('"Family Tree"', 7, 'Funny'),
#  ('"Family Tree"', 8, 'Informative'),
#  ('"Family Tree"', 9, 'Ingenious'),
#  ('"Family Tree"', 10, 'Inspiring'),
#  ('"Family Tree"', 11, 'Longwinded'),
#  ('"Family Tree"', 21, 'Unconvincing'),
#  ('"Family Tree"', 22, 'Fascinating'),
#  ('"Family Tree"', 23, 'Jaw-dropping'),
#  ('"Family Tree"', 24, 'Persuasive'),
#  ('"Family Tree"', 25, 'OK'),
#  ('"Family Tree"', 26, 'Obnoxious'),
#  ('"High School Training Ground"', 1, 'Beautiful'),
#  ('"High School Training Ground"', 2, 'Confusing'),
#  ('"High School Training Ground"', 3, 'Courageous'),
#  ('"High School Training Ground"', 7, 'Funny'),
#  ('"High School Training Ground"', 8, 'Informative'),
#  ('"High School Training Ground"', 9, 'Ingenious'),
#  ('"High School Training Ground"', 10, 'Inspiring'),
#  ('"High School Training Ground"', 11, 'Longwinded'),
#  ('"High School Training Ground"', 21, 'Unconvincing'),
#  ('"High School Training Ground"', 22, 'Fascinating'),
#  ('"High School Training Ground"', 23, 'Jaw-dropping'),
#  ('"High School Training Ground"', 24, 'Persuasive'),
#  ('"High School Training Ground"', 25, 'OK'),
#  ('"High School Training Ground"', 26, 'Obnoxious'),
#  ('"Kiteflyer\'s Hill"', 1, 'Beautiful'),
#  ('"Kiteflyer\'s Hill"', 2, 'Confusing'),
#  ('"Kiteflyer\'s Hill"', 3, 'Courageous'),
#  ('"Kiteflyer\'s Hill"', 7, 'Funny'),
#  ('"Kiteflyer\'s Hill"', 8, 'Informative'),
#  ('"Kiteflyer\'s Hill"', 9, 'Ingenious'),
#  ('"Kiteflyer\'s Hill"', 10, 'Inspiring'),
#  ('"Kiteflyer\'s Hill"', 11, 'Longwinded'),
#  ('"Kiteflyer\'s Hill"', 21, 'Unconvincing'),
#  ('"Kiteflyer\'s Hill"', 22, 'Fascinating'),
#  ('"Kiteflyer\'s Hill"', 23, 'Jaw-dropping'),
#  ('"Kiteflyer\'s Hill"', 24, 'Persuasive'),
#  ('"Kiteflyer\'s Hill"', 25, 'OK'),
#  ('"Kiteflyer\'s Hill"', 26, 'Obnoxious'),
#  ('"Kounandi"', 1, 'Beautiful'),
#  ('"Kounandi"', 2, 'Confusing'),
#  ('"Kounandi"', 3, 'Courageous'),
#  ('"Kounandi"', 7, 'Funny'),
#  ('"Kounandi"', 8, 'Informative'),
#  ('"Kounandi"', 9, 'Ingenious'),
#  ('"Kounandi"', 10, 'Inspiring'),
#  ('"Kounandi"', 11, 'Longwinded'),
#  ('"Kounandi"', 21, 'Unconvincing'),
#  ('"Kounandi"', 22, 'Fascinating'),
#  ('"Kounandi"', 23, 'Jaw-dropping'),
#  ('"Kounandi"', 24, 'Persuasive'),
#  ('"Kounandi"', 25, 'OK'),
#  ('"Kounandi"', 26, 'Obnoxious'),
#  ('"La Vie en Rose"', 1, 'Beautiful'),
#  ('"La Vie en Rose"', 2, 'Confusing'),
#  ('"La Vie en Rose"', 3, 'Courageous'),
#  ('"La Vie en Rose"', 7, 'Funny'),
#  ('"La Vie en Rose"', 8, 'Informative'),
#  ('"La Vie en Rose"', 9, 'Ingenious'),
#  ('"La Vie en Rose"', 10, 'Inspiring'),
#  ('"La Vie en Rose"', 11, 'Longwinded'),
#  ('"La Vie en Rose"', 21, 'Unconvincing'),
#  ('"La Vie en Rose"', 22, 'Fascinating'),
#  ('"La Vie en Rose"', 23, 'Jaw-dropping'),
#  ('"La Vie en Rose"', 24, 'Persuasive'),
#  ('"La Vie en Rose"', 25, 'OK'),
#  ('"La Vie en Rose"', 26, 'Obnoxious'),
#  ('"Love Is a Loaded Pistol"', 1, 'Beautiful'),
#  ('"Love Is a Loaded Pistol"', 2, 'Confusing'),
#  ('"Love Is a Loaded Pistol"', 3, 'Courageous'),
#  ('"Love Is a Loaded Pistol"', 7, 'Funny'),
#  ('"Love Is a Loaded Pistol"', 8, 'Informative'),
#  ('"Love Is a Loaded Pistol"', 9, 'Ingenious'),
#  ('"Love Is a Loaded Pistol"', 10, 'Inspiring'),
#  ('"Love Is a Loaded Pistol"', 11, 'Longwinded'),
#  ('"Love Is a Loaded Pistol"', 21, 'Unconvincing'),
#  ('"Love Is a Loaded Pistol"', 22, 'Fascinating'),
#  ('"Love Is a Loaded Pistol"', 23, 'Jaw-dropping'),
#  ('"Love Is a Loaded Pistol"', 24, 'Persuasive'),
#  ('"Love Is a Loaded Pistol"', 25, 'OK'),
#  ('"Love Is a Loaded Pistol"', 26, 'Obnoxious'),
#  ('"M\'Bifo"', 1, 'Beautiful'),
#  ('"M\'Bifo"', 2, 'Confusing'),
#  ('"M\'Bifo"', 3, 'Courageous'),
#  ('"M\'Bifo"', 7, 'Funny'),
#  ('"M\'Bifo"', 8, 'Informative'),
#  ('"M\'Bifo"', 9, 'Ingenious'),
#  ('"M\'Bifo"', 10, 'Inspiring'),
#  ('"M\'Bifo"', 11, 'Longwinded'),
#  ('"M\'Bifo"', 21, 'Unconvincing'),
#  ('"M\'Bifo"', 22, 'Fascinating'),
#  ('"M\'Bifo"', 23, 'Jaw-dropping'),
#  ('"M\'Bifo"', 24, 'Persuasive'),
#  ('"M\'Bifo"', 25, 'OK'),
#  ('"M\'Bifo"', 26, 'Obnoxious'),
#  ('"Mother of Pearl," "If I Had You"', 1, 'Beautiful'),
#  ('"Mother of Pearl," "If I Had You"', 2, 'Confusing'),
#  ('"Mother of Pearl," "If I Had You"', 3, 'Courageous'),
#  ('"Mother of Pearl," "If I Had You"', 7, 'Funny'),
#  ('"Mother of Pearl," "If I Had You"', 8, 'Informative'),
#  ('"Mother of Pearl," "If I Had You"', 9, 'Ingenious'),
#  ('"Mother of Pearl," "If I Had You"', 10, 'Inspiring'),
#  ('"Mother of Pearl," "If I Had You"', 11, 'Longwinded'),
#  ('"Mother of Pearl," "If I Had You"', 21, 'Unconvincing'),
#  ('"Mother of Pearl," "If I Had You"', 22, 'Fascinating'),
#  ('"Mother of Pearl," "If I Had You"', 23, 'Jaw-dropping'),
#  ('"Mother of Pearl," "If I Had You"', 24, 'Persuasive'),
#  ('"Mother of Pearl," "If I Had You"', 25, 'OK'),
#  ('"Mother of Pearl," "If I Had You"', 26, 'Obnoxious'),
#  ('"Music for Wood and Strings"', 1, 'Beautiful'),
#  ('"Music for Wood and Strings"', 2, 'Confusing'),
#  ('"Music for Wood and Strings"', 3, 'Courageous'),
#  ('"Music for Wood and Strings"', 7, 'Funny'),
#  ('"Music for Wood and Strings"', 8, 'Informative'),
#  ('"Music for Wood and Strings"', 9, 'Ingenious'),
#  ('"Music for Wood and Strings"', 10, 'Inspiring'),
#  ('"Music for Wood and Strings"', 11, 'Longwinded'),
#  ('"Music for Wood and Strings"', 21, 'Unconvincing'),
#  ('"Music for Wood and Strings"', 22, 'Fascinating'),
#  ('"Music for Wood and Strings"', 23, 'Jaw-dropping'),
#  ('"Music for Wood and Strings"', 24, 'Persuasive'),
#  ('"Music for Wood and Strings"', 25, 'OK'),
#  ('"Music for Wood and Strings"', 26, 'Obnoxious'),
#  ('"Peace on Earth"', 1, 'Beautiful'),
#  ('"Peace on Earth"', 2, 'Confusing'),
#  ('"Peace on Earth"', 3, 'Courageous'),
#  ('"Peace on Earth"', 7, 'Funny'),
#  ('"Peace on Earth"', 8, 'Informative'),
#  ('"Peace on Earth"', 9, 'Ingenious'),
#  ('"Peace on Earth"', 10, 'Inspiring'),
#  ('"Peace on Earth"', 11, 'Longwinded'),
#  ('"Peace on Earth"', 21, 'Unconvincing'),
#  ('"Peace on Earth"', 22, 'Fascinating'),
#  ('"Peace on Earth"', 23, 'Jaw-dropping'),
#  ('"Peace on Earth"', 24, 'Persuasive'),
#  ('"Peace on Earth"', 25, 'OK'),
#  ('"Peace on Earth"', 26, 'Obnoxious'),
#  ('"Put the financial aid in the bag"', 1, 'Beautiful'),
#  ('"Put the financial aid in the bag"', 2, 'Confusing'),
#  ('"Put the financial aid in the bag"', 3, 'Courageous'),
#  ('"Put the financial aid in the bag"', 7, 'Funny'),
#  ('"Put the financial aid in the bag"', 8, 'Informative'),
#  ('"Put the financial aid in the bag"', 9, 'Ingenious'),
#  ('"Put the financial aid in the bag"', 10, 'Inspiring'),
#  ('"Put the financial aid in the bag"', 11, 'Longwinded'),
#  ('"Put the financial aid in the bag"', 21, 'Unconvincing'),
#  ('"Put the financial aid in the bag"', 22, 'Fascinating'),
#  ('"Put the financial aid in the bag"', 23, 'Jaw-dropping'),
#  ('"Put the financial aid in the bag"', 24, 'Persuasive'),
#  ('"Put the financial aid in the bag"', 25, 'OK'),
#  ('"Put the financial aid in the bag"', 26, 'Obnoxious'),
#  ('"Redemption Song"', 1, 'Beautiful'),
#  ('"Redemption Song"', 2, 'Confusing'),
#  ('"Redemption Song"', 3, 'Courageous'),
#  ('"Redemption Song"', 7, 'Funny'),
#  ('"Redemption Song"', 8, 'Informative'),
#  ('"Redemption Song"', 9, 'Ingenious'),
#  ('"Redemption Song"', 10, 'Inspiring'),
#  ('"Redemption Song"', 11, 'Longwinded'),
#  ('"Redemption Song"', 21, 'Unconvincing'),
#  ('"Redemption Song"', 22, 'Fascinating'),
#  ('"Redemption Song"', 23, 'Jaw-dropping'),
#  ('"Redemption Song"', 24, 'Persuasive'),
#  ('"Redemption Song"', 25, 'OK'),
#  ('"Redemption Song"', 26, 'Obnoxious'),
#  ('"Rollercoaster"', 1, 'Beautiful'),
#  ('"Rollercoaster"', 2, 'Confusing'),
#  ('"Rollercoaster"', 3, 'Courageous'),
#  ('"Rollercoaster"', 7, 'Funny'),
#  ('"Rollercoaster"', 8, 'Informative'),
#  ('"Rollercoaster"', 9, 'Ingenious'),
#  ('"Rollercoaster"', 10, 'Inspiring'),
#  ('"Rollercoaster"', 11, 'Longwinded'),
#  ('"Rollercoaster"', 21, 'Unconvincing'),
#  ('"Rollercoaster"', 22, 'Fascinating'),
#  ('"Rollercoaster"', 23, 'Jaw-dropping'),
#  ('"Rollercoaster"', 24, 'Persuasive'),
#  ('"Rollercoaster"', 25, 'OK'),
#  ('"Rollercoaster"', 26, 'Obnoxious'),
#  ('"Space Oddity"', 1, 'Beautiful'),
#  ('"Space Oddity"', 2, 'Confusing'),
#  ('"Space Oddity"', 3, 'Courageous'),
#  ('"Space Oddity"', 7, 'Funny'),
#  ('"Space Oddity"', 8, 'Informative'),
#  ('"Space Oddity"', 9, 'Ingenious'),
#  ('"Space Oddity"', 10, 'Inspiring'),
#  ('"Space Oddity"', 11, 'Longwinded'),
#  ('"Space Oddity"', 21, 'Unconvincing'),
#  ('"Space Oddity"', 22, 'Fascinating'),
#  ('"Space Oddity"', 23, 'Jaw-dropping'),
#  ('"Space Oddity"', 24, 'Persuasive'),
#  ('"Space Oddity"', 25, 'OK'),
#  ('"Space Oddity"', 26, 'Obnoxious'),
#  ('"St. James Infirmary Blues"', 1, 'Beautiful'),
#  ('"St. James Infirmary Blues"', 2, 'Confusing'),
#  ('"St. James Infirmary Blues"', 3, 'Courageous'),
#  ('"St. James Infirmary Blues"', 7, 'Funny'),
#  ('"St. James Infirmary Blues"', 8, 'Informative'),
#  ('"St. James Infirmary Blues"', 9, 'Ingenious'),
#  ('"St. James Infirmary Blues"', 10, 'Inspiring'),
#  ('"St. James Infirmary Blues"', 11, 'Longwinded'),
#  ('"St. James Infirmary Blues"', 21, 'Unconvincing'),
#  ('"St. James Infirmary Blues"', 22, 'Fascinating'),
#  ('"St. James Infirmary Blues"', 23, 'Jaw-dropping'),
#  ('"St. James Infirmary Blues"', 24, 'Persuasive'),
#  ('"St. James Infirmary Blues"', 25, 'OK'),
#  ('"St. James Infirmary Blues"', 26, 'Obnoxious'),
#  ('"Tembererana"', 1, 'Beautiful'),
#  ('"Tembererana"', 2, 'Confusing'),
#  ('"Tembererana"', 3, 'Courageous'),
#  ('"Tembererana"', 7, 'Funny'),
#  ('"Tembererana"', 8, 'Informative'),
#  ('"Tembererana"', 9, 'Ingenious'),
#  ('"Tembererana"', 10, 'Inspiring'),
#  ('"Tembererana"', 11, 'Longwinded'),
#  ('"Tembererana"', 21, 'Unconvincing'),
#  ('"Tembererana"', 22, 'Fascinating'),
#  ('"Tembererana"', 23, 'Jaw-dropping'),
#  ('"Tembererana"', 24, 'Persuasive'),
#  ('"Tembererana"', 25, 'OK'),
#  ('"Tembererana"', 26, 'Obnoxious'),
#  ('"The Dog Song"', 1, 'Beautiful'),
#  ('"The Dog Song"', 2, 'Confusing'),
#  ('"The Dog Song"', 3, 'Courageous'),
#  ('"The Dog Song"', 7, 'Funny'),
#  ('"The Dog Song"', 8, 'Informative'),
#  ('"The Dog Song"', 9, 'Ingenious'),
#  ('"The Dog Song"', 10, 'Inspiring'),
#  ('"The Dog Song"', 11, 'Longwinded'),
#  ('"The Dog Song"', 21, 'Unconvincing'),
#  ('"The Dog Song"', 22, 'Fascinating'),
#  ('"The Dog Song"', 23, 'Jaw-dropping'),
#  ('"The Dog Song"', 24, 'Persuasive'),
#  ('"The Dog Song"', 25, 'OK'),
#  ('"The Dog Song"', 26, 'Obnoxious'),
#  ('"The Sacred Art of the Ori"', 1, 'Beautiful'),
#  ('"The Sacred Art of the Ori"', 2, 'Confusing'),
#  ('"The Sacred Art of the Ori"', 3, 'Courageous'),
#  ('"The Sacred Art of the Ori"', 7, 'Funny'),
#  ('"The Sacred Art of the Ori"', 8, 'Informative'),
#  ('"The Sacred Art of the Ori"', 9, 'Ingenious'),
#  ('"The Sacred Art of the Ori"', 10, 'Inspiring'),
#  ('"The Sacred Art of the Ori"', 11, 'Longwinded'),
#  ('"The Sacred Art of the Ori"', 21, 'Unconvincing'),
#  ('"The Sacred Art of the Ori"', 22, 'Fascinating'),
#  ('"The Sacred Art of the Ori"', 23, 'Jaw-dropping'),
#  ('"The Sacred Art of the Ori"', 24, 'Persuasive'),
#  ('"The Sacred Art of the Ori"', 25, 'OK'),
#  ('"The Sacred Art of the Ori"', 26, 'Obnoxious'),
#  ('"Thula Mama"', 1, 'Beautiful'),
#  ('"Thula Mama"', 2, 'Confusing'),
#  ('"Thula Mama"', 3, 'Courageous'),
#  ('"Thula Mama"', 7, 'Funny'),
#  ('"Thula Mama"', 8, 'Informative'),
#  ('"Thula Mama"', 9, 'Ingenious'),
#  ('"Thula Mama"', 10, 'Inspiring'),
#  ('"Thula Mama"', 11, 'Longwinded'),
#  ('"Thula Mama"', 21, 'Unconvincing'),
#  ('"Thula Mama"', 22, 'Fascinating'),
#  ('"Thula Mama"', 23, 'Jaw-dropping'),
#  ('"Thula Mama"', 24, 'Persuasive'),
#  ('"Thula Mama"', 25, 'OK'),
#  ('"Thula Mama"', 26, 'Obnoxious'),
#  ('"Turceasca"', 1, 'Beautiful'),
#  ('"Turceasca"', 2, 'Confusing'),
#  ('"Turceasca"', 3, 'Courageous'),
#  ('"Turceasca"', 7, 'Funny'),
#  ('"Turceasca"', 8, 'Informative'),
#  ('"Turceasca"', 9, 'Ingenious'),
#  ('"Turceasca"', 10, 'Inspiring'),
#  ('"Turceasca"', 11, 'Longwinded'),
#  ('"Turceasca"', 21, 'Unconvincing'),
#  ('"Turceasca"', 22, 'Fascinating'),
#  ('"Turceasca"', 23, 'Jaw-dropping'),
#  ('"Turceasca"', 24, 'Persuasive'),
#  ('"Turceasca"', 25, 'OK'),
#  ('"Turceasca"', 26, 'Obnoxious'),
#  ('"Wait It Out"', 1, 'Beautiful'),
#  ('"Wait It Out"', 2, 'Confusing'),
#  ('"Wait It Out"', 3, 'Courageous'),
#  ('"Wait It Out"', 7, 'Funny'),
#  ('"Wait It Out"', 8, 'Informative'),
#  ('"Wait It Out"', 9, 'Ingenious'),
#  ('"Wait It Out"', 10, 'Inspiring'),
#  ('"Wait It Out"', 11, 'Longwinded'),
#  ('"Wait It Out"', 21, 'Unconvincing'),
#  ('"Wait It Out"', 22, 'Fascinating'),
#  ('"Wait It Out"', 23, 'Jaw-dropping'),
#  ('"Wait It Out"', 24, 'Persuasive'),
#  ('"Wait It Out"', 25, 'OK'),
#  ('"Wait It Out"', 26, 'Obnoxious'),
#  ('"What You\'ve Got"', 1, 'Beautiful'),
#  ('"What You\'ve Got"', 2, 'Confusing'),
#  ('"What You\'ve Got"', 3, 'Courageous'),
#  ('"What You\'ve Got"', 7, 'Funny'),
#  ('"What You\'ve Got"', 8, 'Informative'),
#  ('"What You\'ve Got"', 9, 'Ingenious'),
#  ('"What You\'ve Got"', 10, 'Inspiring'),
#  ('"What You\'ve Got"', 11, 'Longwinded'),
#  ('"What You\'ve Got"', 21, 'Unconvincing'),
#  ('"What You\'ve Got"', 22, 'Fascinating'),
#  ('"What You\'ve Got"', 23, 'Jaw-dropping'),
#  ('"What You\'ve Got"', 24, 'Persuasive'),
#  ('"What You\'ve Got"', 25, 'OK'),
#  ('"What You\'ve Got"', 26, 'Obnoxious'),
#  ('"Women of Hope"', 1, 'Beautiful'),
#  ('"Women of Hope"', 2, 'Confusing'),
#  ('"Women of Hope"', 3, 'Courageous'),
#  ('"Women of Hope"', 7, 'Funny'),
#  ('"Women of Hope"', 8, 'Informative'),
#  ('"Women of Hope"', 9, 'Ingenious'),
#  ('"Women of Hope"', 10, 'Inspiring'),
#  ('"Women of Hope"', 11, 'Longwinded'),
#  ('"Women of Hope"', 21, 'Unconvincing'),
#  ('"Women of Hope"', 22, 'Fascinating'),
#  ('"Women of Hope"', 23, 'Jaw-dropping'),
#  ('"Women of Hope"', 24, 'Persuasive'),
#  ('"Women of Hope"', 25, 'OK'),
#  ('"Women of Hope"', 26, 'Obnoxious'),
#  ('"Woza"', 1, 'Beautiful'),
#  ('"Woza"', 2, 'Confusing'),
#  ('"Woza"', 3, 'Courageous'),
#  ('"Woza"', 7, 'Funny'),
#  ('"Woza"', 8, 'Informative'),
#  ('"Woza"', 9, 'Ingenious'),
#  ('"Woza"', 10, 'Inspiring'),
#  ('"Woza"', 11, 'Longwinded'),
#  ('"Woza"', 21, 'Unconvincing'),
#  ('"Woza"', 22, 'Fascinating'),
#  ('"Woza"', 23, 'Jaw-dropping'),
#  ('"Woza"', 24, 'Persuasive'),
#  ('"Woza"', 25, 'OK'),
#  ('"Woza"', 26, 'Obnoxious'),
#  ('(Re)touching lives through photos', 1, 'Beautiful'),
#  ('(Re)touching lives through photos', 2, 'Confusing'),
#  ('(Re)touching lives through photos', 3, 'Courageous'),
#  ('(Re)touching lives through photos', 7, 'Funny'),
#  ('(Re)touching lives through photos', 8, 'Informative'),
#  ('(Re)touching lives through photos', 9, 'Ingenious'),
#  ('(Re)touching lives through photos', 10, 'Inspiring'),
#  ('(Re)touching lives through photos', 11, 'Longwinded'),
#  ('(Re)touching lives through photos', 21, 'Unconvincing'),
#  ('(Re)touching lives through photos', 22, 'Fascinating'),
#  ('(Re)touching lives through photos', 23, 'Jaw-dropping'),
#  ('(Re)touching lives through photos', 24, 'Persuasive'),
#  ('(Re)touching lives through photos', 25, 'OK'),
#  ('(Re)touching lives through photos', 26, 'Obnoxious'),
#  ('“Am I dying?” The honest answer.', 1, 'Beautiful'),
#  ('“Am I dying?” The honest answer.', 2, 'Confusing'),
#  ('“Am I dying?” The honest answer.', 3, 'Courageous'),
#  ('“Am I dying?” The honest answer.', 7, 'Funny'),
#  ('“Am I dying?” The honest answer.', 8, 'Informative'),
#  ('“Am I dying?” The honest answer.', 9, 'Ingenious'),
#  ('“Am I dying?” The honest answer.', 10, 'Inspiring'),
#  ('“Am I dying?” The honest answer.', 11, 'Longwinded'),
#  ('“Am I dying?” The honest answer.', 21, 'Unconvincing'),
#  ('“Am I dying?” The honest answer.', 22, 'Fascinating'),
#  ('“Am I dying?” The honest answer.', 23, 'Jaw-dropping'),
#  ('“Am I dying?” The honest answer.', 24, 'Persuasive'),
#  ('“Am I dying?” The honest answer.', 25, 'OK'),
#  ('“Am I dying?” The honest answer.', 26, 'Obnoxious'),
#  ('1,000 TED Talks in six words', 1, 'Beautiful'),
#  ('1,000 TED Talks in six words', 2, 'Confusing'),
#  ('1,000 TED Talks in six words', 3, 'Courageous'),
#  ('1,000 TED Talks in six words', 7, 'Funny'),
#  ('1,000 TED Talks in six words', 8, 'Informative'),
#  ('1,000 TED Talks in six words', 9, 'Ingenious'),
#  ('1,000 TED Talks in six words', 10, 'Inspiring'),
#  ('1,000 TED Talks in six words', 11, 'Longwinded'),
#  ('1,000 TED Talks in six words', 21, 'Unconvincing'),
#  ('1,000 TED Talks in six words', 22, 'Fascinating'),
#  ('1,000 TED Talks in six words', 23, 'Jaw-dropping'),
#  ('1,000 TED Talks in six words', 24, 'Persuasive'),
#  ('1,000 TED Talks in six words', 25, 'OK'),
#  ('1,000 TED Talks in six words', 26, 'Obnoxious'),
#  ('1.3m reasons to re-invent the syringe', 1, 'Beautiful'),
#  ('1.3m reasons to re-invent the syringe', 2, 'Confusing'),
#  ('1.3m reasons to re-invent the syringe', 3, 'Courageous'),
#  ('1.3m reasons to re-invent the syringe', 7, 'Funny'),
#  ('1.3m reasons to re-invent the syringe', 8, 'Informative'),
#  ('1.3m reasons to re-invent the syringe', 9, 'Ingenious'),
#  ('1.3m reasons to re-invent the syringe', 10, 'Inspiring'),
#  ('1.3m reasons to re-invent the syringe', 11, 'Longwinded'),
#  ('1.3m reasons to re-invent the syringe', 21, 'Unconvincing'),
#  ('1.3m reasons to re-invent the syringe', 22, 'Fascinating'),
#  ('1.3m reasons to re-invent the syringe', 23, 'Jaw-dropping'),
#  ('1.3m reasons to re-invent the syringe', 24, 'Persuasive'),
#  ('1.3m reasons to re-invent the syringe', 25, 'OK'),
#  ('1.3m reasons to re-invent the syringe', 26, 'Obnoxious'),
#  ('10 myths about psychology, debunked', 1, 'Beautiful'),
#  ('10 myths about psychology, debunked', 2, 'Confusing'),
#  ('10 myths about psychology, debunked', 3, 'Courageous'),
#  ('10 myths about psychology, debunked', 7, 'Funny'),
#  ('10 myths about psychology, debunked', 8, 'Informative'),
#  ('10 myths about psychology, debunked', 9, 'Ingenious'),
#  ('10 myths about psychology, debunked', 10, 'Inspiring'),
#  ('10 myths about psychology, debunked', 11, 'Longwinded'),
#  ('10 myths about psychology, debunked', 21, 'Unconvincing'),
#  ('10 myths about psychology, debunked', 22, 'Fascinating'),
#  ('10 myths about psychology, debunked', 23, 'Jaw-dropping'),
#  ('10 myths about psychology, debunked', 24, 'Persuasive'),
#  ('10 myths about psychology, debunked', 25, 'OK'),
#  ('10 myths about psychology, debunked', 26, 'Obnoxious'),
#  ("10 things you didn't know about orgasm", 1, 'Beautiful'),
#  ("10 things you didn't know about orgasm", 2, 'Confusing'),
#  ("10 things you didn't know about orgasm", 3, 'Courageous'),
#  ("10 things you didn't know about orgasm", 7, 'Funny'),
#  ("10 things you didn't know about orgasm", 8, 'Informative'),
#  ("10 things you didn't know about orgasm", 9, 'Ingenious'),
#  ("10 things you didn't know about orgasm", 10, 'Inspiring'),
#  ("10 things you didn't know about orgasm", 11, 'Longwinded'),
#  ("10 things you didn't know about orgasm", 21, 'Unconvincing'),
#  ("10 things you didn't know about orgasm", 22, 'Fascinating'),
#  ("10 things you didn't know about orgasm", 23, 'Jaw-dropping'),
#  ("10 things you didn't know about orgasm", 24, 'Persuasive'),
#  ("10 things you didn't know about orgasm", 25, 'OK'),
#  ("10 things you didn't know about orgasm", 26, 'Obnoxious'),
#  ('10 top time-saving tech tips', 1, 'Beautiful'),
#  ('10 top time-saving tech tips', 2, 'Confusing'),
#  ('10 top time-saving tech tips', 3, 'Courageous'),
#  ('10 top time-saving tech tips', 7, 'Funny'),
#  ('10 top time-saving tech tips', 8, 'Informative'),
#  ('10 top time-saving tech tips', 9, 'Ingenious'),
#  ('10 top time-saving tech tips', 10, 'Inspiring'),
#  ('10 top time-saving tech tips', 11, 'Longwinded'),
#  ('10 top time-saving tech tips', 21, 'Unconvincing'),
#  ('10 top time-saving tech tips', 22, 'Fascinating'),
#  ('10 top time-saving tech tips', 23, 'Jaw-dropping'),
#  ('10 top time-saving tech tips', 24, 'Persuasive'),
#  ('10 top time-saving tech tips', 25, 'OK'),
#  ('10 top time-saving tech tips', 26, 'Obnoxious'),
#  ('10 ways the world could end', 1, 'Beautiful'),
#  ('10 ways the world could end', 2, 'Confusing'),
#  ('10 ways the world could end', 3, 'Courageous'),
#  ('10 ways the world could end', 7, 'Funny'),
#  ('10 ways the world could end', 8, 'Informative'),
#  ('10 ways the world could end', 9, 'Ingenious'),
#  ('10 ways the world could end', 10, 'Inspiring'),
#  ('10 ways the world could end', 11, 'Longwinded'),
#  ('10 ways the world could end', 21, 'Unconvincing'),
#  ('10 ways the world could end', 22, 'Fascinating'),
#  ('10 ways the world could end', 23, 'Jaw-dropping'),
#  ('10 ways the world could end', 24, 'Persuasive'),
#  ('10 ways the world could end', 25, 'OK'),
#  ('10 ways the world could end', 26, 'Obnoxious'),
#  ('10 ways to have a better conversation', 1, 'Beautiful'),
#  ('10 ways to have a better conversation', 2, 'Confusing'),
#  ('10 ways to have a better conversation', 3, 'Courageous'),
#  ('10 ways to have a better conversation', 7, 'Funny'),
#  ('10 ways to have a better conversation', 8, 'Informative'),
#  ('10 ways to have a better conversation', 9, 'Ingenious'),
#  ('10 ways to have a better conversation', 10, 'Inspiring'),
#  ('10 ways to have a better conversation', 11, 'Longwinded'),
#  ('10 ways to have a better conversation', 21, 'Unconvincing'),
#  ('10 ways to have a better conversation', 22, 'Fascinating'),
#  ('10 ways to have a better conversation', 23, 'Jaw-dropping'),
#  ('10 ways to have a better conversation', 24, 'Persuasive'),
#  ('10 ways to have a better conversation', 25, 'OK'),
#  ('10 ways to have a better conversation', 26, 'Obnoxious'),
#  ('10 young Indian artists to watch', 1, 'Beautiful'),
#  ('10 young Indian artists to watch', 2, 'Confusing'),
#  ('10 young Indian artists to watch', 3, 'Courageous'),
#  ('10 young Indian artists to watch', 7, 'Funny'),
#  ('10 young Indian artists to watch', 8, 'Informative'),
#  ('10 young Indian artists to watch', 9, 'Ingenious'),
#  ('10 young Indian artists to watch', 10, 'Inspiring'),
#  ('10 young Indian artists to watch', 11, 'Longwinded'),
#  ('10 young Indian artists to watch', 21, 'Unconvincing'),
#  ('10 young Indian artists to watch', 22, 'Fascinating'),
#  ('10 young Indian artists to watch', 23, 'Jaw-dropping'),
#  ('10 young Indian artists to watch', 24, 'Persuasive'),
#  ('10 young Indian artists to watch', 25, 'OK'),
#  ('10 young Indian artists to watch', 26, 'Obnoxious'),
#  ('12 truths I learned from life and writing', 1, 'Beautiful'),
#  ('12 truths I learned from life and writing', 2, 'Confusing'),
#  ('12 truths I learned from life and writing', 3, 'Courageous'),
#  ('12 truths I learned from life and writing', 7, 'Funny'),
#  ('12 truths I learned from life and writing', 8, 'Informative'),
#  ('12 truths I learned from life and writing', 9, 'Ingenious'),
#  ('12 truths I learned from life and writing', 10, 'Inspiring'),
#  ('12 truths I learned from life and writing', 11, 'Longwinded'),
#  ('12 truths I learned from life and writing', 21, 'Unconvincing'),
#  ('12 truths I learned from life and writing', 22, 'Fascinating'),
#  ('12 truths I learned from life and writing', 23, 'Jaw-dropping'),
#  ('12 truths I learned from life and writing', 24, 'Persuasive'),
#  ('12 truths I learned from life and writing', 25, 'OK'),
#  ('12 truths I learned from life and writing', 26, 'Obnoxious'),
#  ('17 words of architectural inspiration', 1, 'Beautiful'),
#  ('17 words of architectural inspiration', 2, 'Confusing'),
#  ('17 words of architectural inspiration', 3, 'Courageous'),
#  ('17 words of architectural inspiration', 7, 'Funny'),
#  ('17 words of architectural inspiration', 8, 'Informative'),
#  ('17 words of architectural inspiration', 9, 'Ingenious'),
#  ('17 words of architectural inspiration', 10, 'Inspiring'),
#  ('17 words of architectural inspiration', 11, 'Longwinded'),
#  ('17 words of architectural inspiration', 21, 'Unconvincing'),
#  ('17 words of architectural inspiration', 22, 'Fascinating'),
#  ('17 words of architectural inspiration', 23, 'Jaw-dropping'),
#  ('17 words of architectural inspiration', 24, 'Persuasive'),
#  ('17 words of architectural inspiration', 25, 'OK'),
#  ('17 words of architectural inspiration', 26, 'Obnoxious'),
#  ('2600 years of history in one object', 1, 'Beautiful'),
#  ('2600 years of history in one object', 2, 'Confusing'),
#  ('2600 years of history in one object', 3, 'Courageous'),
#  ('2600 years of history in one object', 7, 'Funny'),
#  ('2600 years of history in one object', 8, 'Informative'),
#  ('2600 years of history in one object', 9, 'Ingenious'),
#  ('2600 years of history in one object', 10, 'Inspiring'),
#  ('2600 years of history in one object', 11, 'Longwinded'),
#  ('2600 years of history in one object', 21, 'Unconvincing'),
#  ('2600 years of history in one object', 22, 'Fascinating'),
#  ('2600 years of history in one object', 23, 'Jaw-dropping'),
#  ('2600 years of history in one object', 24, 'Persuasive'),
#  ('2600 years of history in one object', 25, 'OK'),
#  ('2600 years of history in one object', 26, 'Obnoxious'),
#  ('3 clues to understanding your brain', 1, 'Beautiful'),
#  ('3 clues to understanding your brain', 2, 'Confusing'),
#  ('3 clues to understanding your brain', 3, 'Courageous'),
#  ('3 clues to understanding your brain', 7, 'Funny'),
#  ('3 clues to understanding your brain', 8, 'Informative'),
#  ('3 clues to understanding your brain', 9, 'Ingenious'),
#  ('3 clues to understanding your brain', 10, 'Inspiring'),
#  ('3 clues to understanding your brain', 11, 'Longwinded'),
#  ('3 clues to understanding your brain', 21, 'Unconvincing'),
#  ('3 clues to understanding your brain', 22, 'Fascinating'),
#  ('3 clues to understanding your brain', 23, 'Jaw-dropping'),
#  ('3 clues to understanding your brain', 24, 'Persuasive'),
#  ('3 clues to understanding your brain', 25, 'OK'),
#  ('3 clues to understanding your brain', 26, 'Obnoxious'),
#  ('3 lessons on success from an Arab businesswoman', 1, 'Beautiful'),
#  ('3 lessons on success from an Arab businesswoman', 2, 'Confusing'),
#  ('3 lessons on success from an Arab businesswoman', 3, 'Courageous'),
#  ('3 lessons on success from an Arab businesswoman', 7, 'Funny'),
#  ('3 lessons on success from an Arab businesswoman', 8, 'Informative'),
#  ('3 lessons on success from an Arab businesswoman', 9, 'Ingenious'),
#  ('3 lessons on success from an Arab businesswoman', 10, 'Inspiring'),
#  ('3 lessons on success from an Arab businesswoman', 11, 'Longwinded'),
#  ('3 lessons on success from an Arab businesswoman', 21, 'Unconvincing'),
#  ('3 lessons on success from an Arab businesswoman', 22, 'Fascinating'),
#  ('3 lessons on success from an Arab businesswoman', 23, 'Jaw-dropping'),
#  ('3 lessons on success from an Arab businesswoman', 24, 'Persuasive'),
#  ('3 lessons on success from an Arab businesswoman', 25, 'OK'),
#  ('3 lessons on success from an Arab businesswoman', 26, 'Obnoxious'),
#  ('3 moons and a planet that could have alien life', 1, 'Beautiful'),
#  ('3 moons and a planet that could have alien life', 2, 'Confusing'),
#  ('3 moons and a planet that could have alien life', 3, 'Courageous'),
#  ('3 moons and a planet that could have alien life', 7, 'Funny'),
#  ('3 moons and a planet that could have alien life', 8, 'Informative'),
#  ('3 moons and a planet that could have alien life', 9, 'Ingenious'),
#  ('3 moons and a planet that could have alien life', 10, 'Inspiring'),
#  ('3 moons and a planet that could have alien life', 11, 'Longwinded'),
#  ('3 moons and a planet that could have alien life', 21, 'Unconvincing'),
#  ('3 moons and a planet that could have alien life', 22, 'Fascinating'),
#  ('3 moons and a planet that could have alien life', 23, 'Jaw-dropping'),
#  ('3 moons and a planet that could have alien life', 24, 'Persuasive'),
#  ('3 moons and a planet that could have alien life', 25, 'OK'),
#  ('3 moons and a planet that could have alien life', 26, 'Obnoxious'),
#  ('3 new ways to kill mosquitoes', 1, 'Beautiful'),
#  ('3 new ways to kill mosquitoes', 2, 'Confusing'),
#  ('3 new ways to kill mosquitoes', 3, 'Courageous'),
#  ('3 new ways to kill mosquitoes', 7, 'Funny'),
#  ('3 new ways to kill mosquitoes', 8, 'Informative'),
#  ('3 new ways to kill mosquitoes', 9, 'Ingenious'),
#  ('3 new ways to kill mosquitoes', 10, 'Inspiring'),
#  ('3 new ways to kill mosquitoes', 11, 'Longwinded'),
#  ('3 new ways to kill mosquitoes', 21, 'Unconvincing'),
#  ('3 new ways to kill mosquitoes', 22, 'Fascinating'),
#  ('3 new ways to kill mosquitoes', 23, 'Jaw-dropping'),
#  ('3 new ways to kill mosquitoes', 24, 'Persuasive'),
#  ('3 new ways to kill mosquitoes', 25, 'OK'),
#  ('3 new ways to kill mosquitoes', 26, 'Obnoxious'),
#  ('3 principles for creating safer AI', 1, 'Beautiful'),
#  ('3 principles for creating safer AI', 2, 'Confusing'),
#  ('3 principles for creating safer AI', 3, 'Courageous'),
#  ('3 principles for creating safer AI', 7, 'Funny'),
#  ('3 principles for creating safer AI', 8, 'Informative'),
#  ('3 principles for creating safer AI', 9, 'Ingenious'),
#  ('3 principles for creating safer AI', 10, 'Inspiring'),
#  ('3 principles for creating safer AI', 11, 'Longwinded'),
#  ('3 principles for creating safer AI', 21, 'Unconvincing'),
#  ('3 principles for creating safer AI', 22, 'Fascinating'),
#  ('3 principles for creating safer AI', 23, 'Jaw-dropping'),
#  ('3 principles for creating safer AI', 24, 'Persuasive'),
#  ('3 principles for creating safer AI', 25, 'OK'),
#  ('3 principles for creating safer AI', 26, 'Obnoxious'),
#  ('3 reasons we still haven’t gotten rid of malaria', 1, 'Beautiful'),
#  ('3 reasons we still haven’t gotten rid of malaria', 2, 'Confusing'),
#  ('3 reasons we still haven’t gotten rid of malaria', 3, 'Courageous'),
#  ('3 reasons we still haven’t gotten rid of malaria', 7, 'Funny'),
#  ('3 reasons we still haven’t gotten rid of malaria', 8, 'Informative'),
#  ('3 reasons we still haven’t gotten rid of malaria', 9, 'Ingenious'),
#  ('3 reasons we still haven’t gotten rid of malaria', 10, 'Inspiring'),
#  ('3 reasons we still haven’t gotten rid of malaria', 11, 'Longwinded'),
#  ('3 reasons we still haven’t gotten rid of malaria', 21, 'Unconvincing'),
#  ('3 reasons we still haven’t gotten rid of malaria', 22, 'Fascinating'),
#  ('3 reasons we still haven’t gotten rid of malaria', 23, 'Jaw-dropping'),
#  ('3 reasons we still haven’t gotten rid of malaria', 24, 'Persuasive'),
#  ('3 reasons we still haven’t gotten rid of malaria', 25, 'OK'),
#  ('3 reasons we still haven’t gotten rid of malaria', 26, 'Obnoxious'),
#  ('3 reasons why we can win the fight against poverty', 1, 'Beautiful'),
#  ('3 reasons why we can win the fight against poverty', 2, 'Confusing'),
#  ('3 reasons why we can win the fight against poverty', 3, 'Courageous'),
#  ('3 reasons why we can win the fight against poverty', 7, 'Funny'),
#  ('3 reasons why we can win the fight against poverty', 8, 'Informative'),
#  ('3 reasons why we can win the fight against poverty', 9, 'Ingenious'),
#  ('3 reasons why we can win the fight against poverty', 10, 'Inspiring'),
#  ('3 reasons why we can win the fight against poverty', 11, 'Longwinded'),
#  ('3 reasons why we can win the fight against poverty', 21, 'Unconvincing'),
#  ('3 reasons why we can win the fight against poverty', 22, 'Fascinating'),
#  ('3 reasons why we can win the fight against poverty', 23, 'Jaw-dropping'),
#  ('3 reasons why we can win the fight against poverty', 24, 'Persuasive'),
#  ('3 reasons why we can win the fight against poverty', 25, 'OK'),
#  ('3 reasons why we can win the fight against poverty', 26, 'Obnoxious'),
#  ('3 rules to spark learning', 1, 'Beautiful'),
#  ('3 rules to spark learning', 2, 'Confusing'),
#  ('3 rules to spark learning', 3, 'Courageous'),
#  ('3 rules to spark learning', 7, 'Funny'),
#  ('3 rules to spark learning', 8, 'Informative'),
#  ('3 rules to spark learning', 9, 'Ingenious'),
#  ('3 rules to spark learning', 10, 'Inspiring'),
#  ('3 rules to spark learning', 11, 'Longwinded'),
#  ('3 rules to spark learning', 21, 'Unconvincing'),
#  ('3 rules to spark learning', 22, 'Fascinating'),
#  ('3 rules to spark learning', 23, 'Jaw-dropping'),
#  ('3 rules to spark learning', 24, 'Persuasive'),
#  ('3 rules to spark learning', 25, 'OK'),
#  ('3 rules to spark learning', 26, 'Obnoxious'),
#  ('3 stories of local eco-entrepreneurship', 1, 'Beautiful'),
#  ('3 stories of local eco-entrepreneurship', 2, 'Confusing'),
#  ('3 stories of local eco-entrepreneurship', 3, 'Courageous'),
#  ('3 stories of local eco-entrepreneurship', 7, 'Funny'),
#  ('3 stories of local eco-entrepreneurship', 8, 'Informative'),
#  ('3 stories of local eco-entrepreneurship', 9, 'Ingenious'),
#  ('3 stories of local eco-entrepreneurship', 10, 'Inspiring'),
#  ('3 stories of local eco-entrepreneurship', 11, 'Longwinded'),
#  ('3 stories of local eco-entrepreneurship', 21, 'Unconvincing'),
#  ('3 stories of local eco-entrepreneurship', 22, 'Fascinating'),
#  ('3 stories of local eco-entrepreneurship', 23, 'Jaw-dropping'),
#  ('3 stories of local eco-entrepreneurship', 24, 'Persuasive'),
#  ('3 stories of local eco-entrepreneurship', 25, 'OK'),
#  ('3 stories of local eco-entrepreneurship', 26, 'Obnoxious'),
#  ('3 things I learned while my plane crashed', 1, 'Beautiful'),
#  ('3 things I learned while my plane crashed', 2, 'Confusing'),
#  ('3 things I learned while my plane crashed', 3, 'Courageous'),
#  ('3 things I learned while my plane crashed', 7, 'Funny'),
#  ('3 things I learned while my plane crashed', 8, 'Informative'),
#  ('3 things I learned while my plane crashed', 9, 'Ingenious'),
#  ('3 things I learned while my plane crashed', 10, 'Inspiring'),
#  ('3 things I learned while my plane crashed', 11, 'Longwinded'),
#  ('3 things I learned while my plane crashed', 21, 'Unconvincing'),
#  ('3 things I learned while my plane crashed', 22, 'Fascinating'),
#  ('3 things I learned while my plane crashed', 23, 'Jaw-dropping'),
#  ('3 things I learned while my plane crashed', 24, 'Persuasive'),
#  ('3 things I learned while my plane crashed', 25, 'OK'),
#  ('3 things I learned while my plane crashed', 26, 'Obnoxious'),
#  ('3 warp-speed architecture tales', 1, 'Beautiful'),
#  ('3 warp-speed architecture tales', 2, 'Confusing'),
#  ('3 warp-speed architecture tales', 3, 'Courageous'),
#  ('3 warp-speed architecture tales', 7, 'Funny'),
#  ('3 warp-speed architecture tales', 8, 'Informative'),
#  ('3 warp-speed architecture tales', 9, 'Ingenious'),
#  ('3 warp-speed architecture tales', 10, 'Inspiring'),
#  ('3 warp-speed architecture tales', 11, 'Longwinded'),
#  ('3 warp-speed architecture tales', 21, 'Unconvincing'),
#  ('3 warp-speed architecture tales', 22, 'Fascinating'),
#  ('3 warp-speed architecture tales', 23, 'Jaw-dropping'),
#  ('3 warp-speed architecture tales', 24, 'Persuasive'),
#  ('3 warp-speed architecture tales', 25, 'OK'),
#  ('3 warp-speed architecture tales', 26, 'Obnoxious'),
#  ('3 ways good design makes you happy', 1, 'Beautiful'),
#  ('3 ways good design makes you happy', 2, 'Confusing'),
#  ('3 ways good design makes you happy', 3, 'Courageous'),
#  ('3 ways good design makes you happy', 7, 'Funny'),
#  ('3 ways good design makes you happy', 8, 'Informative'),
#  ('3 ways good design makes you happy', 9, 'Ingenious'),
#  ('3 ways good design makes you happy', 10, 'Inspiring'),
#  ('3 ways good design makes you happy', 11, 'Longwinded'),
#  ('3 ways good design makes you happy', 21, 'Unconvincing'),
#  ('3 ways good design makes you happy', 22, 'Fascinating'),
#  ('3 ways good design makes you happy', 23, 'Jaw-dropping'),
#  ('3 ways good design makes you happy', 24, 'Persuasive'),
#  ('3 ways good design makes you happy', 25, 'OK'),
#  ('3 ways good design makes you happy', 26, 'Obnoxious'),
#  ('3 ways the brain creates meaning', 1, 'Beautiful'),
#  ('3 ways the brain creates meaning', 2, 'Confusing'),
#  ('3 ways the brain creates meaning', 3, 'Courageous'),
#  ('3 ways the brain creates meaning', 7, 'Funny'),
#  ('3 ways the brain creates meaning', 8, 'Informative'),
#  ('3 ways the brain creates meaning', 9, 'Ingenious'),
#  ('3 ways the brain creates meaning', 10, 'Inspiring'),
#  ('3 ways the brain creates meaning', 11, 'Longwinded'),
#  ('3 ways the brain creates meaning', 21, 'Unconvincing'),
#  ('3 ways the brain creates meaning', 22, 'Fascinating'),
#  ('3 ways the brain creates meaning', 23, 'Jaw-dropping'),
#  ('3 ways the brain creates meaning', 24, 'Persuasive'),
#  ('3 ways the brain creates meaning', 25, 'OK'),
#  ('3 ways the brain creates meaning', 26, 'Obnoxious'),
#  ('3 ways to (usefully) lose control of your brand', 1, 'Beautiful'),
#  ('3 ways to (usefully) lose control of your brand', 2, 'Confusing'),
#  ('3 ways to (usefully) lose control of your brand', 3, 'Courageous'),
#  ('3 ways to (usefully) lose control of your brand', 7, 'Funny'),
#  ('3 ways to (usefully) lose control of your brand', 8, 'Informative'),
#  ('3 ways to (usefully) lose control of your brand', 9, 'Ingenious'),
#  ('3 ways to (usefully) lose control of your brand', 10, 'Inspiring'),
#  ('3 ways to (usefully) lose control of your brand', 11, 'Longwinded'),
#  ('3 ways to (usefully) lose control of your brand', 21, 'Unconvincing'),
#  ('3 ways to (usefully) lose control of your brand', 22, 'Fascinating'),
#  ('3 ways to (usefully) lose control of your brand', 23, 'Jaw-dropping'),
#  ('3 ways to (usefully) lose control of your brand', 24, 'Persuasive'),
#  ('3 ways to (usefully) lose control of your brand', 25, 'OK'),
#  ('3 ways to (usefully) lose control of your brand', 26, 'Obnoxious'),
#  ('3 ways to fix a broken news industry', 1, 'Beautiful'),
#  ('3 ways to fix a broken news industry', 2, 'Confusing'),
#  ('3 ways to fix a broken news industry', 3, 'Courageous'),
#  ('3 ways to fix a broken news industry', 7, 'Funny'),
#  ('3 ways to fix a broken news industry', 8, 'Informative'),
#  ('3 ways to fix a broken news industry', 9, 'Ingenious'),
#  ('3 ways to fix a broken news industry', 10, 'Inspiring'),
#  ('3 ways to fix a broken news industry', 11, 'Longwinded'),
#  ('3 ways to fix a broken news industry', 21, 'Unconvincing'),
#  ('3 ways to fix a broken news industry', 22, 'Fascinating'),
#  ('3 ways to fix a broken news industry', 23, 'Jaw-dropping'),
#  ('3 ways to fix a broken news industry', 24, 'Persuasive'),
#  ('3 ways to fix a broken news industry', 25, 'OK'),
#  ('3 ways to fix a broken news industry', 26, 'Obnoxious'),
#  ('3 ways to plan for the (very) long term', 1, 'Beautiful'),
#  ('3 ways to plan for the (very) long term', 2, 'Confusing'),
#  ('3 ways to plan for the (very) long term', 3, 'Courageous'),
#  ('3 ways to plan for the (very) long term', 7, 'Funny'),
#  ('3 ways to plan for the (very) long term', 8, 'Informative'),
#  ('3 ways to plan for the (very) long term', 9, 'Ingenious'),
#  ('3 ways to plan for the (very) long term', 10, 'Inspiring'),
#  ('3 ways to plan for the (very) long term', 11, 'Longwinded'),
#  ('3 ways to plan for the (very) long term', 21, 'Unconvincing'),
#  ('3 ways to plan for the (very) long term', 22, 'Fascinating'),
#  ('3 ways to plan for the (very) long term', 23, 'Jaw-dropping'),
#  ('3 ways to plan for the (very) long term', 24, 'Persuasive'),
#  ('3 ways to plan for the (very) long term', 25, 'OK'),
#  ('3 ways to plan for the (very) long term', 26, 'Obnoxious'),
#  ('3 ways to speak English', 1, 'Beautiful'),
#  ('3 ways to speak English', 2, 'Confusing'),
#  ('3 ways to speak English', 3, 'Courageous'),
#  ('3 ways to speak English', 7, 'Funny'),
#  ('3 ways to speak English', 8, 'Informative'),
#  ('3 ways to speak English', 9, 'Ingenious'),
#  ('3 ways to speak English', 10, 'Inspiring'),
#  ('3 ways to speak English', 11, 'Longwinded'),
#  ('3 ways to speak English', 21, 'Unconvincing'),
#  ('3 ways to speak English', 22, 'Fascinating'),
#  ('3 ways to speak English', 23, 'Jaw-dropping'),
#  ('3 ways to speak English', 24, 'Persuasive'),
#  ('3 ways to speak English', 25, 'OK'),
#  ('3 ways to speak English', 26, 'Obnoxious'),
#  ('3 ways to spot a bad statistic', 1, 'Beautiful'),
#  ('3 ways to spot a bad statistic', 2, 'Confusing'),
#  ('3 ways to spot a bad statistic', 3, 'Courageous'),
#  ('3 ways to spot a bad statistic', 7, 'Funny'),
#  ('3 ways to spot a bad statistic', 8, 'Informative'),
#  ('3 ways to spot a bad statistic', 9, 'Ingenious'),
#  ('3 ways to spot a bad statistic', 10, 'Inspiring'),
#  ('3 ways to spot a bad statistic', 11, 'Longwinded'),
#  ('3 ways to spot a bad statistic', 21, 'Unconvincing'),
#  ('3 ways to spot a bad statistic', 22, 'Fascinating'),
#  ('3 ways to spot a bad statistic', 23, 'Jaw-dropping'),
#  ('3 ways to spot a bad statistic', 24, 'Persuasive'),
#  ('3 ways to spot a bad statistic', 25, 'OK'),
#  ('3 ways to spot a bad statistic', 26, 'Obnoxious'),
#  ("4 environmental 'heresies'", 1, 'Beautiful'),
#  ("4 environmental 'heresies'", 2, 'Confusing'),
#  ("4 environmental 'heresies'", 3, 'Courageous'),
#  ("4 environmental 'heresies'", 7, 'Funny'),
#  ("4 environmental 'heresies'", 8, 'Informative'),
#  ("4 environmental 'heresies'", 9, 'Ingenious'),
#  ("4 environmental 'heresies'", 10, 'Inspiring'),
#  ("4 environmental 'heresies'", 11, 'Longwinded'),
#  ("4 environmental 'heresies'", 21, 'Unconvincing'),
#  ("4 environmental 'heresies'", 22, 'Fascinating'),
#  ("4 environmental 'heresies'", 23, 'Jaw-dropping'),
#  ("4 environmental 'heresies'", 24, 'Persuasive'),
#  ("4 environmental 'heresies'", 25, 'OK'),
#  ("4 environmental 'heresies'", 26, 'Obnoxious'),
#  ('4 larger-than-life lessons from soap operas', 1, 'Beautiful'),
#  ('4 larger-than-life lessons from soap operas', 2, 'Confusing'),
#  ('4 larger-than-life lessons from soap operas', 3, 'Courageous'),
#  ('4 larger-than-life lessons from soap operas', 7, 'Funny'),
#  ('4 larger-than-life lessons from soap operas', 8, 'Informative'),
#  ('4 larger-than-life lessons from soap operas', 9, 'Ingenious'),
#  ('4 larger-than-life lessons from soap operas', 10, 'Inspiring'),
#  ('4 larger-than-life lessons from soap operas', 11, 'Longwinded'),
#  ('4 larger-than-life lessons from soap operas', 21, 'Unconvincing'),
#  ('4 larger-than-life lessons from soap operas', 22, 'Fascinating'),
#  ('4 larger-than-life lessons from soap operas', 23, 'Jaw-dropping'),
#  ('4 larger-than-life lessons from soap operas', 24, 'Persuasive'),
#  ('4 larger-than-life lessons from soap operas', 25, 'OK'),
#  ('4 larger-than-life lessons from soap operas', 26, 'Obnoxious'),
#  ('4 lessons from robots about being human', 1, 'Beautiful'),
#  ('4 lessons from robots about being human', 2, 'Confusing'),
#  ('4 lessons from robots about being human', 3, 'Courageous'),
#  ('4 lessons from robots about being human', 7, 'Funny'),
#  ('4 lessons from robots about being human', 8, 'Informative'),
#  ('4 lessons from robots about being human', 9, 'Ingenious'),
#  ('4 lessons from robots about being human', 10, 'Inspiring'),
#  ('4 lessons from robots about being human', 11, 'Longwinded'),
#  ('4 lessons from robots about being human', 21, 'Unconvincing'),
#  ('4 lessons from robots about being human', 22, 'Fascinating'),
#  ('4 lessons from robots about being human', 23, 'Jaw-dropping'),
#  ('4 lessons from robots about being human', 24, 'Persuasive'),
#  ('4 lessons from robots about being human', 25, 'OK'),
#  ('4 lessons from robots about being human', 26, 'Obnoxious'),
#  ('4 lessons I learned from taking a stand against drugs and gun violence', 1, 'Beautiful'),
#  ('4 lessons I learned from taking a stand against drugs and gun violence', 2, 'Confusing'),
#  ('4 lessons I learned from taking a stand against drugs and gun violence', 3, 'Courageous'),
#  ('4 lessons I learned from taking a stand against drugs and gun violence', 7, 'Funny'),
#  ('4 lessons I learned from taking a stand against drugs and gun violence', 8, 'Informative'),
#  ('4 lessons I learned from taking a stand against drugs and gun violence', 9, 'Ingenious'),
#  ('4 lessons I learned from taking a stand against drugs and gun violence', 10, 'Inspiring'),
#  ('4 lessons I learned from taking a stand against drugs and gun violence', 11, 'Longwinded'),
#  ('4 lessons I learned from taking a stand against drugs and gun violence', 21, 'Unconvincing'),
#  ('4 lessons I learned from taking a stand against drugs and gun violence', 22, 'Fascinating'),
#  ('4 lessons I learned from taking a stand against drugs and gun violence', 23, 'Jaw-dropping'),
#  ('4 lessons I learned from taking a stand against drugs and gun violence', 24, 'Persuasive'),
#  ('4 lessons I learned from taking a stand against drugs and gun violence', 25, 'OK'),
#  ('4 lessons I learned from taking a stand against drugs and gun violence', 26, 'Obnoxious'),
#  ('4 lessons in creativity', 1, 'Beautiful'),
#  ('4 lessons in creativity', 2, 'Confusing'),
#  ('4 lessons in creativity', 3, 'Courageous'),
#  ('4 lessons in creativity', 7, 'Funny'),
#  ('4 lessons in creativity', 8, 'Informative'),
#  ('4 lessons in creativity', 9, 'Ingenious'),
#  ('4 lessons in creativity', 10, 'Inspiring'),
#  ('4 lessons in creativity', 11, 'Longwinded'),
#  ('4 lessons in creativity', 21, 'Unconvincing'),
#  ('4 lessons in creativity', 22, 'Fascinating'),
#  ('4 lessons in creativity', 23, 'Jaw-dropping'),
#  ('4 lessons in creativity', 24, 'Persuasive'),
#  ('4 lessons in creativity', 25, 'OK'),
#  ('4 lessons in creativity', 26, 'Obnoxious'),
#  ('4 pillars of college success in science', 1, 'Beautiful'),
#  ('4 pillars of college success in science', 2, 'Confusing'),
#  ('4 pillars of college success in science', 3, 'Courageous'),
#  ('4 pillars of college success in science', 7, 'Funny'),
#  ('4 pillars of college success in science', 8, 'Informative'),
#  ('4 pillars of college success in science', 9, 'Ingenious'),
#  ('4 pillars of college success in science', 10, 'Inspiring'),
#  ('4 pillars of college success in science', 11, 'Longwinded'),
#  ('4 pillars of college success in science', 21, 'Unconvincing'),
#  ('4 pillars of college success in science', 22, 'Fascinating'),
#  ('4 pillars of college success in science', 23, 'Jaw-dropping'),
#  ('4 pillars of college success in science', 24, 'Persuasive'),
#  ('4 pillars of college success in science', 25, 'OK'),
#  ('4 pillars of college success in science', 26, 'Obnoxious'),
#  ("4 powerful poems about Parkinson's and growing older", 1, 'Beautiful'),
#  ("4 powerful poems about Parkinson's and growing older", 2, 'Confusing'),
#  ("4 powerful poems about Parkinson's and growing older", 3, 'Courageous'),
#  ("4 powerful poems about Parkinson's and growing older", 7, 'Funny'),
#  ("4 powerful poems about Parkinson's and growing older", 8, 'Informative'),
#  ("4 powerful poems about Parkinson's and growing older", 9, 'Ingenious'),
#  ("4 powerful poems about Parkinson's and growing older", 10, 'Inspiring'),
#  ("4 powerful poems about Parkinson's and growing older", 11, 'Longwinded'),
#  ("4 powerful poems about Parkinson's and growing older", 21, 'Unconvincing'),
#  ("4 powerful poems about Parkinson's and growing older", 22, 'Fascinating'),
#  ("4 powerful poems about Parkinson's and growing older", 23, 'Jaw-dropping'),
#  ("4 powerful poems about Parkinson's and growing older", 24, 'Persuasive'),
#  ("4 powerful poems about Parkinson's and growing older", 25, 'OK'),
#  ("4 powerful poems about Parkinson's and growing older", 26, 'Obnoxious'),
#  ('4 reasons to learn a new language', 1, 'Beautiful'),
#  ('4 reasons to learn a new language', 2, 'Confusing'),
#  ('4 reasons to learn a new language', 3, 'Courageous'),
#  ('4 reasons to learn a new language', 7, 'Funny'),
#  ('4 reasons to learn a new language', 8, 'Informative'),
#  ('4 reasons to learn a new language', 9, 'Ingenious'),
#  ('4 reasons to learn a new language', 10, 'Inspiring'),
#  ('4 reasons to learn a new language', 11, 'Longwinded'),
#  ('4 reasons to learn a new language', 21, 'Unconvincing'),
#  ('4 reasons to learn a new language', 22, 'Fascinating'),
#  ('4 reasons to learn a new language', 23, 'Jaw-dropping'),
#  ('4 reasons to learn a new language', 24, 'Persuasive'),
#  ('4 reasons to learn a new language', 25, 'OK'),
#  ('4 reasons to learn a new language', 26, 'Obnoxious'),
#  ('4 ways to build a human company in the age of machines', 1, 'Beautiful'),
#  ('4 ways to build a human company in the age of machines', 2, 'Confusing'),
#  ('4 ways to build a human company in the age of machines', 3, 'Courageous'),
#  ('4 ways to build a human company in the age of machines', 7, 'Funny'),
#  ('4 ways to build a human company in the age of machines', 8, 'Informative'),
#  ('4 ways to build a human company in the age of machines', 9, 'Ingenious'),
#  ('4 ways to build a human company in the age of machines', 10, 'Inspiring'),
#  ('4 ways to build a human company in the age of machines', 11, 'Longwinded'),
#  ('4 ways to build a human company in the age of machines', 21, 'Unconvincing'),
#  ('4 ways to build a human company in the age of machines', 22, 'Fascinating'),
#  ('4 ways to build a human company in the age of machines', 23, 'Jaw-dropping'),
#  ('4 ways to build a human company in the age of machines', 24, 'Persuasive'),
#  ('4 ways to build a human company in the age of machines', 25, 'OK'),
#  ('4 ways to build a human company in the age of machines', 26, 'Obnoxious'),
#  ('4 ways to make a city more walkable', 1, 'Beautiful'),
#  ('4 ways to make a city more walkable', 2, 'Confusing'),
#  ('4 ways to make a city more walkable', 3, 'Courageous'),
#  ('4 ways to make a city more walkable', 7, 'Funny'),
#  ('4 ways to make a city more walkable', 8, 'Informative'),
#  ('4 ways to make a city more walkable', 9, 'Ingenious'),
#  ('4 ways to make a city more walkable', 10, 'Inspiring'),
#  ('4 ways to make a city more walkable', 11, 'Longwinded'),
#  ('4 ways to make a city more walkable', 21, 'Unconvincing'),
#  ('4 ways to make a city more walkable', 22, 'Fascinating'),
#  ('4 ways to make a city more walkable', 23, 'Jaw-dropping'),
#  ('4 ways to make a city more walkable', 24, 'Persuasive'),
#  ('4 ways to make a city more walkable', 25, 'OK'),
#  ('4 ways to make a city more walkable', 26, 'Obnoxious'),
#  ('4 ways we can avoid a catastrophic drought', 1, 'Beautiful'),
#  ('4 ways we can avoid a catastrophic drought', 2, 'Confusing'),
#  ('4 ways we can avoid a catastrophic drought', 3, 'Courageous'),
#  ('4 ways we can avoid a catastrophic drought', 7, 'Funny'),
#  ('4 ways we can avoid a catastrophic drought', 8, 'Informative'),
#  ('4 ways we can avoid a catastrophic drought', 9, 'Ingenious'),
#  ...]

# %%
stmt = ''' SELECT tag FROM tags; '''

connection.execute(stmt).fetchall()
# Out:
# [('children',),
#  (' creativity',),
#  (' culture',),
#  (' dance',),
#  (' education',),
#  (' parenting',),
#  (' teaching',),
#  ('alternative energy',),
#  (' cars',),
#  (' climate change',),
#  (' environment',),
#  (' global issues',),
#  (' science',),
#  (' sustainability',),
#  (' technology',),
#  ('computers',),
#  (' entertainment',),
#  (' interface design',),
#  (' media',),
#  (' music',),
#  (' performance',),
#  (' simplicity',),
#  (' software',),
#  ('MacArthur grant',),
#  (' activism',),
#  (' business',),
#  (' cities',),
#  (' green',),
#  (' inequality',),
#  (' politics',),
#  (' pollution',),
#  ('Africa',),
#  (' Asia',),
#  (' Google',),
#  (' demo',),
#  (' economics',),
#  (' global development',),
#  (' health',),
#  (' math',),
#  (' statistics',),
#  (' visualizations',),
#  ('business',),
#  (' goalsetting',),
#  (' motivation',),
#  (' potential',),
#  (' psychology',),
#  ('Christianity',),
#  (' God',),
#  (' atheism',),
#  (' comedy',),
#  (' humor',),
#  (' religion',),
#  (' storytelling',),
#  ('architecture',),
#  (' collaboration',),
#  (' design',),
#  (' library',),
#  ('God',),
#  (' TED Brain Trust',),
#  (' brain',),
#  (' cognitive science',),
#  (' consciousness',),
#  (' evolution',),
#  (' philosophy',),
#  (' happiness',),
#  (' leadership',),
#  (' philanthropy',),
#  ('activism',),
#  (' architecture',),
#  (' disaster relief',),
#  (' invention',),
#  (' opensource',),
#  ('TED Prize',),
#  (' art',),
#  (' film',),
#  (' movies',),
#  (' peace',),
#  (' social change',),
#  (' disease',),
#  (' ebola',),
#  ('demo',),
#  (' entrepreneur',),
#  ('entertainment',),
#  (' violin',),
#  (' wunderkind',),
#  (' youth',),
#  ('creativity',),
#  (' piano',),
#  (' alternative energy',),
#  (' engineering',),
#  (' industrial design',),
#  ('DNA',),
#  (' biology',),
#  (' nature',),
#  (' product design',),
#  (' science and art',),
#  (' wikipedia',),
#  ('collaboration',),
#  (' community',),
#  (' communication',),
#  ('cognitive science',),
#  (' gender',),
#  (' love',),
#  (' relationships',),
#  ('culture',),
#  (' theater',),
#  (' women',),
#  ('climate change',),
#  (' cosmos',),
#  (' physics',),
#  (' universe',),
#  ('astronomy',),
#  (' narcotics',),
#  (' race',),
#  (' choice',),
#  (' consumerism',),
#  (' food',),
#  (' marketing',),
#  ('TED Brain Trust',),
#  (' decisionmaking',),
#  (' personal growth',),
#  ('cancer',),
#  ('aging',),
#  (' biotech',),
#  (' future',),
#  (' health care',),
#  (' investment',),
#  (' microfinance',),
#  (' poverty',),
#  (' telecom',),
#  (' transportation',),
#  (' corruption',),
#  (' military',),
#  (' policy',),
#  ('NASA',),
#  (' aircraft',),
#  (' flight',),
#  (' rocket science',),
#  (' exploration',),
#  (' sports',),
#  (' travel',),
#  ('AIDS',),
#  (' Africa',),
#  (' photography',),
#  (' medicine',),
#  (' genetics',),
#  (' faith',),
#  (' illusion',),
#  (' robots',),
#  ('choice',),
#  (' history',),
#  (' success',),
#  (' work',),
#  (' poetry',),
#  (' obesity',),
#  ('anthropology',),
#  (' language',),
#  (' complexity',),
#  (' time',),
#  (' evolutionary psychology',),
#  (' war',),
#  ('cities',),
#  (' map',),
#  (' urban planning',),
#  (' innovation',),
#  ('dance',),
#  (' United States',),
#  (' interview',),
#  (' performance art',),
#  (' materials',),
#  ('code',),
#  (' computers',),
#  (' worklife balance',),
#  (' TED Prize',),
#  (' ants',),
#  (' biodiversity',),
#  (' ecology',),
#  (' insects',),
#  (' animals',),
#  (' primates',),
#  ('brain',),
#  (' typography',),
#  ('art',),
#  (' live music',),
#  (' singer',),
#  ('Brazil',),
#  (' animation',),
#  ('biotech',),
#  (' biomimicry',),
#  (' fish',),
#  (' oceans',),
#  ('animals',),
#  (' apes',),
#  (' intelligence',),
#  ('biology',),
#  (' biomechanics',),
#  (' online video',),
#  (' guitar',),
#  (' vocals',),
#  ('cello',),
#  (' self',),
#  (' china',),
#  (' web',),
#  (' memory',),
#  (' spoken word',),
#  ('composing',),
#  (' natural disaster',),
#  ('comedy',),
#  ('Google',),
#  (' energy',),
#  (' museums',),
#  (' water',),
#  ('AI',),
#  (' microsoft',),
#  (' virtual reality',),
#  (' women in business',),
#  ('Buddhism',),
#  ('New York',),
#  (' death',),
#  (' terrorism',),
#  ('design',),
#  ('Moon',),
#  (' NASA',),
#  (' Planets',),
#  (' adventure',),
#  (' mining',),
#  (' space',),
#  (' meme',),
#  ('Bioethics',),
#  (' cancer',),
#  (' gaming',),
#  ('animation',),
#  (' literature',),
#  (' prosthetics',),
#  ('books',),
#  (' sociology',),
#  (' violence',),
#  (' anthropology',),
#  (' human origins',),
#  (' humanity',),
#  (' paleontology',),
#  ('asteroid',),
#  (' solar system',),
#  (' drones',),
#  (' solar energy',),
#  ('aircraft',),
#  (' children',),
#  (' illness',),
#  (' depression',),
#  (' mental health',),
#  (' suicide',),
#  (' law',),
#  (' MacArthur grant',),
#  ('String theory',),
#  ('education',),
#  (' magic',),
#  (' compassion',),
#  (' empathy',),
#  ('communication',),
#  (' writing',),
#  (' play',),
#  ('South America',),
#  (' world cultures',),
#  ('ants',),
#  (' South America',),
#  (' infrastructure',),
#  (' ancient world',),
#  (' books',),
#  (' bees',),
#  (' garden',),
#  (' plants',),
#  ('live music',),
#  (' toy',),
#  (' telescopes',),
#  (' hack',),
#  (' heart health',),
#  (' public health',),
#  (' big bang',),
#  ('bacteria',),
#  (' microbiology',),
#  (' news',),
#  ('environment',),
#  ('adventure',),
#  (' submarine',),
#  (' sex',),
#  (' society',),
#  (' archaeology',),
#  (' dinosaurs',),
#  (' beauty',),
#  (' plastic',),
#  ('Vaccines',),
#  ('conducting',),
#  (' family',),
#  (' trees',),
#  ('Planets',),
#  (' astrobiology',),
#  (' astronomy',),
#  (' extraterrestrial life',),
#  (' introvert',),
#  (' personality',),
#  (' origami',),
#  (' dark matter',),
#  (' DNA',),
#  (' identity',),
#  (' nanoscale',),
#  ('global issues',),
#  (' geology',),
#  (' life',),
#  (' morality',),
#  (' presentation',),
#  (' crime',),
#  (' evil',),
#  (' prison',),
#  (' democracy',),
#  ('physics',),
#  ('beauty',),
#  ('health',),
#  (' smell',),
#  ('charter for compassion',),
#  (' social media',),
#  ('Senses',),
#  ('Mars',),
#  (' fashion',),
#  ('Alzheimers',),
#  (' aging',),
#  ('complexity',),
#  ('Asia',),
#  (' curiosity',),
#  (' programming',),
#  (' chemistry',),
#  (' shopping',),
#  ('philanthropy',),
#  ('dinosaurs',),
#  (' body language',),
#  (' virus',),
#  ('energy',),
#  (' conducting',),
#  ('biodiversity',),
#  (' fear',),
#  ('economics',),
#  (' birds',),
#  (' wind energy',),
#  (' bacteria',),
#  (' extreme sports',),
#  (' prediction',),
#  (' productivity',),
#  (' mind',),
#  ('TED Fellows',),
#  ('Natural resources',),
#  (' agriculture',),
#  (' india',),
#  ('cars',),
#  ('United States',),
#  ('guitar',),
#  ('community',),
#  (' neuroscience',),
#  ('TEDx',),
#  (' money',),
#  (' statebuilding',),
#  ('Anthropocene',),
#  ('Europe',),
#  ('apes',),
#  ('engineering',),
#  (' data',),
#  ('global development',),
#  (' sight',),
#  ('Internet',),
#  (' government',),
#  ('ancient world',),
#  (' men',),
#  ('body language',),
#  ('advertising',),
#  ('birds',),
#  (' advertising',),
#  (' sanitation',),
#  ('depression',),
#  ('chemistry',),
#  (' weather',),
#  ('biomimicry',),
#  ('big problems',),
#  (' big problems',),
#  (' rivers',),
#  (' Slavery',),
#  (' sexual violence',),
#  (' trafficking',),
#  ('Egypt',),
#  ('corruption',),
#  (' TED Fellows',),
#  ('government',),
#  (' novel',),
#  (' feminism',),
#  ('TEDMED',),
#  ('Autism spectrum disorder',),
#  ('data',),
#  ('agriculture',),
#  (' TEDx',),
#  ('humanity',),
#  ('Slavery',),
#  ('future',),
#  ('bees',),
#  (' botany',),
#  ('literature',),
#  (' mission blue',),
#  ('fish',),
#  ('evolution',),
#  (' friendship',),
#  (' student',),
#  (' HIV',),
#  (' Vaccines',),
#  ('curiosity',),
#  ('democracy',),
#  (' nuclear weapons',),
#  ('math',),
#  ('crime',),
#  (' oil',),
#  ('Surveillance',),
#  (' iraq',),
#  ('Islam',),
#  ('mission blue',),
#  (' monkeys',),
#  (' LGBT',),
#  ('Iran',),
#  (' Middle East',),
#  ('goalsetting',),
#  ('friendship',),
#  (' sound',),
#  ('decisionmaking',),
#  ('PTSD',),
#  (' population',),
#  (' manufacturing',),
#  ('LGBT',),
#  (' TEDYouth',),
#  ('china',),
#  ('drones',),
#  ('Gender equality',),
#  (' bullying',),
#  (' trust',),
#  (' sleep',),
#  (' journalism',),
#  (' cyborg',),
#  ('health care',),
#  ('Foreign Policy',),
#  (' Gender equality',),
#  ('Surgery',),
#  (' medical research',),
#  (' protests',),
#  ('dark matter',),
#  (' deextinction',),
#  (' disability',),
#  (' exoskeleton',),
#  (' nuclear energy',),
#  (' driverless cars',),
#  (' crowdsourcing',),
#  (' charter for compassion',),
#  ('Brand',),
#  (' speech',),
#  (' failure',),
#  ('exploration',),
#  (' security',),
#  (' pain',),
#  (' Islam',),
#  ('Blindness',),
#  (' Senses',),
#  ('philosophy',),
#  ('consumerism',),
#  ('Gender spectrum',),
#  (' glacier',),
#  (' mobility',),
#  ('TED en Español',),
#  (' public spaces',),
#  ('consciousness',),
#  ('happiness',),
#  ('Human body',),
#  (' nonviolence',),
#  (' pharmaceuticals',),
#  (' molecular biology',),
#  ('behavioral economics',),
#  ('archaeology',),
#  (' medical imaging',),
#  (' physiology',),
#  (' pregnancy',),
#  (' code',),
#  (' synthetic biology',),
#  (' asteroid',),
#  (' hearing',),
#  (' jazz',),
#  ('Nobel prize',),
#  (' Surgery',),
#  (' finance',),
#  (' Foreign Policy',),
#  ('atheism',),
#  (' Surveillance',),
#  (' algorithm',),
#  (' composing',),
#  ('TEDYouth',),
#  ('3d printing',),
#  ('Guns',),
#  ('algorithm',),
#  (' conservation',),
#  (' immigration',),
#  ('Criminal Justice',),
#  (' TEDEd',),
#  (' String theory',),
#  ('TEDEd',),
#  (' privacy',),
#  ('marketing',),
#  (' microbes',),
#  (' Internet',),
#  (' machine learning',),
#  (' Bioethics',),
#  (' Egypt',),
#  (' skateboarding',),
#  (' augmented reality',),
#  ('innovation',),
#  (' behavioral economics',),
#  (' forensics',),
#  (' painting',),
#  ('illusion',),
#  (' pandemic',),
#  ('Middle East',),
#  (' meditation',),
#  (' mindfulness',),
#  (' Syria',),
#  (' Gender spectrum',),
#  (' Transgender',),
#  ('compassion',),
#  ('oceans',),
#  ('bullying',),
#  ('technology',),
#  ('robots',),
#  (' testing',),
#  ('family',),
#  ('humor',),
#  ('death',),
#  ('Debate',),
#  (' Iran',),
#  ('disease',),
#  (' farming',),
#  (' Natural resources',),
#  ('gender',),
#  ('map',),
#  ('disability',),
#  ('security',),
#  ('introvert',),
#  ('sports',),
#  (' cloud',),
#  ('history',),
#  ('poetry',),
#  (' TED Books',),
#  ('manufacturing',),
#  ('Syria',),
#  ('medicine',),
#  ('TED Books',),
#  (' television',),
#  (' street art',),
#  (' Guns',),
#  ('entrepreneur',),
#  ('investment',),
#  ('inequality',),
#  ('politics',),
#  ('empathy',),
#  ('peace',),
#  ('Addiction',),
#  ('disaster relief',),
#  ('leadership',),
#  ('human origins',),
#  (' CRISPR',),
#  (' vulnerability',),
#  (' Blindness',),
#  ('big bang',),
#  (' capitalism',),
#  (' TEDMED',),
#  (' refugees',),
#  (' grammar',),
#  (' Debate',),
#  (' Buddhism',),
#  (' resources',),
#  (' discovery',),
#  (' TED en Español',),
#  (' blockchain',),
#  ('TEDNYC',),
#  (' urban',),
#  ('CRISPR',),
#  (' Europe',),
#  (' New York',),
#  ('TED Residency',),
#  (' Human body',),
#  (' biosphere',),
#  ('media',),
#  (' TEDNYC',),
#  ('capitalism',),
#  (' epidemiology',),
#  (' TED Residency',),
#  (' funny',)]

# %%
stmt = ''' SELECT rating FROM ratings; '''

connection.execute(stmt).fetchall()
# Out:
# [('Funny',),
#  ('Beautiful',),
#  ('Ingenious',),
#  ('Courageous',),
#  ('Longwinded',),
#  ('Confusing',),
#  ('Informative',),
#  ('Fascinating',),
#  ('Unconvincing',),
#  ('Persuasive',),
#  ('Jaw-dropping',),
#  ('OK',),
#  ('Obnoxious',),
#  ('Inspiring',)]
